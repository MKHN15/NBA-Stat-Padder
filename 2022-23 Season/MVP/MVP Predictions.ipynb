# %% [markdown]
# # MVP Predictions #

# %%
# -*- coding: utf-8 -*-#
"""
Created by MinhKhang Nguyen
July 27 2021 7:37 PM - August 6 2021 2:08 AM
"""
# Out:
# '\nCreated by MinhKhang Nguyen\nJuly 27 2021 7:37 PM - August 6 2021 2:08 AM\n'

# %%
import pandas as pd 
import random as rnd
import numpy as np
import matplotlib.pyplot as plt

# %%
import ssl
ssl._create_default_https_econtext = ssl._create_unverified_context

# %% [markdown]
# #### Importing Data ####

# %% [markdown]
# ###### Importing Normal Stats ######

# %%
year = "2023"

# %%
html_url = "https://www.basketball-reference.com/leagues/NBA_"+year+"_per_game.html"
nba_tables = pd.read_html(html_url)
len(nba_tables)
nba = nba_tables[0]
nba.head(30)
# Out:
#     Rk                    Player  Pos  Age   Tm   G  GS    MP    FG   FGA  \
# 0    1          Precious Achiuwa    C   23  TOR  53  11  20.5   3.5   7.2
# 1    2              Steven Adams    C   29  MEM  42  42  27.0   3.7   6.3
# 2    3               Bam Adebayo    C   25  MIA  74  74  35.0   8.1  15.0
# 3    4              Ochai Agbaji   SG   22  UTA  57  20  20.1   2.6   6.1
# 4    5              Santi Aldama   PF   22  MEM  77  20  21.8   3.2   6.8
# 5    6  Nickeil Alexander-Walker   SG   24  TOT  57   3  14.9   2.2   5.0
# 6    6  Nickeil Alexander-Walker   SG   24  UTA  36   3  14.7   2.3   4.7
# 7    6  Nickeil Alexander-Walker   SG   24  MIN  21   0  15.4   2.0   5.4
# 8    7             Grayson Allen   SG   27  MIL  72  70  27.4   3.4   7.7
# 9    8             Jarrett Allen    C   24  CLE  67  67  33.0   6.0   9.3
# 10   9             Jose Alvarado   PG   24  NOP  61  10  21.5   3.3   8.0
# 11  10             Kyle Anderson   PF   29  MIN  67  46  28.3   3.7   7.2
# 12  11     Giannis Antetokounmpo   PF   28  MIL  63  63  32.1  11.2  20.3
# 13  12    Thanasis Antetokounmpo   SF   30  MIL  35   0   4.0   0.3   0.8
# 14  13              Cole Anthony   PG   22  ORL  59   3  25.8   4.6  10.1
# 15  14                OG Anunoby   SF   25  TOR  66  66  35.7   6.3  13.3
# 16  15          Ryan Arcidiacono   PG   28  TOT  20   4   8.6   0.5   1.9
# 17  15          Ryan Arcidiacono   PG   28  NYK  11   0   2.4   0.1   0.5
# 18  15          Ryan Arcidiacono   PG   28  POR   9   4  16.2   0.9   3.6
# 19  16               Deni Avdija   SF   22  WAS  76  40  26.6   3.3   7.6
# 20  17             Deandre Ayton    C   24  PHO  67  67  30.4   7.8  13.2
# 21  18            Udoka Azubuike    C   23  UTA  34   2   8.9   1.5   1.8
# 22  19         Marvin Bagley III    C   23  DET  40  25  23.7   4.8   9.0
# 23  20       Patrick Baldwin Jr.   SF   20  GSW  29   0   7.4   1.4   3.5
# 24  Rk                    Player  Pos  Age   Tm   G  GS    MP    FG   FGA
# 25  21               LaMelo Ball   PG   21  CHO  36  36  35.2   8.2  20.0
# 26  22                  Mo Bamba    C   24  TOT  47   7  16.2   2.5   5.1
# 27  22                  Mo Bamba    C   24  ORL  40   6  17.0   2.7   5.4
# 28  22                  Mo Bamba    C   24  LAL   7   1  11.6   1.4   3.4
# 29  23            Paolo Banchero   PF   20  ORL  72  72  33.8   6.7  15.6
#
#     ...   FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0   ...  .694  1.8  4.0   5.8  0.9  0.5  0.6  1.1  1.8   9.0
# 1   ...  .364  5.1  6.5  11.5  2.3  0.9  1.1  1.9  2.3   8.6
# 2   ...  .806  2.5  6.8   9.3  3.2  1.2  0.8  2.5  2.8  20.6
# 3   ...  .797  0.7  1.3   2.1  1.0  0.2  0.3  0.6  1.7   7.6
# 4   ...  .750  1.1  3.7   4.8  1.3  0.6  0.6  0.8  1.9   9.0
# 5   ...  .667  0.2  1.5   1.8  1.8  0.5  0.4  0.9  1.5   6.0
# 6   ...  .692  0.2  1.4   1.6  2.1  0.7  0.4  1.3  1.6   6.3
# 7   ...  .619  0.3  1.7   2.0  1.3  0.3  0.3  0.4  1.2   5.5
# 8   ...  .905  0.8  2.4   3.3  2.3  0.9  0.2  1.0  1.6  10.4
# 9   ...  .733  3.3  6.6   9.9  1.7  0.8  1.2  1.4  2.3  14.4
# 10  ...  .813  0.5  1.9   2.3  3.0  1.1  0.2  1.3  2.0   9.0
# 11  ...  .735  1.0  4.4   5.3  4.9  1.1  0.9  1.5  2.2   9.4
# 12  ...  .645  2.2  9.6  11.8  5.7  0.8  0.8  3.9  3.1  31.1
# 13  ...  .417  0.3  0.6   0.9  0.2  0.1  0.1  0.3  0.5   0.7
# 14  ...  .894  0.8  4.0   4.7  3.9  0.6  0.5  1.5  2.7  13.0
# 15  ...  .838  1.4  3.6   5.0  2.0  1.9  0.8  2.0  3.0  16.9
# 16  ...   NaN  0.0  0.8   0.8  1.2  0.3  0.0  0.4  0.9   1.3
# 17  ...   NaN  0.0  0.4   0.4  0.2  0.2  0.0  0.1  0.3   0.3
# 18  ...   NaN  0.0  1.2   1.2  2.3  0.3  0.0  0.7  1.6   2.6
# 19  ...  .739  1.0  5.4   6.4  2.8  0.9  0.4  1.6  2.8   9.2
# 20  ...  .760  2.6  7.4  10.0  1.7  0.6  0.8  1.8  2.8  18.0
# 21  ...  .313  0.8  2.2   3.0  0.3  0.2  0.4  0.5  0.9   3.1
# 22  ...  .752  2.3  4.1   6.4  0.9  0.5  0.7  1.1  2.0  12.0
# 23  ...  .667  0.0  1.2   1.3  0.3  0.2  0.1  0.4  0.5   3.9
# 24  ...   FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 25  ...  .836  1.2  5.3   6.4  8.4  1.3  0.3  3.6  3.3  23.3
# 26  ...  .661  1.2  3.5   4.7  1.0  0.3  0.9  0.6  2.2   6.8
# 27  ...  .686  1.2  3.4   4.6  1.1  0.3  1.0  0.6  2.2   7.3
# 28  ...  .545  1.3  4.0   5.3  0.6  0.1  0.6  1.1  2.4   4.4
# 29  ...  .738  1.2  5.7   6.9  3.7  0.8  0.5  2.8  2.2  20.0
#
# [30 rows x 30 columns]

# %%
nba.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %% [markdown]
# ###### Importing Advanced Stats ######

# %%
html_url = "https://www.basketball-reference.com/leagues/NBA_"+year+"_advanced.html"
advanced_tables = pd.read_html(html_url)
len(advanced_tables)
advanced = advanced_tables[0]
advanced.head(30)
# Out:
#     Rk                    Player  Pos  Age   Tm   G    MP   PER   TS%  3PAr  \
# 0    1          Precious Achiuwa    C   23  TOR  53  1089  14.8  .548  .261
# 1    2              Steven Adams    C   29  MEM  42  1133  17.5  .564  .004
# 2    3               Bam Adebayo    C   25  MIA  74  2590  20.0  .592  .011
# 3    4              Ochai Agbaji   SG   22  UTA  57  1147   9.5  .573  .615
# 4    5              Santi Aldama   PF   22  MEM  77  1682  13.9  .591  .507
# 5    6  Nickeil Alexander-Walker   SG   24  TOT  57   851  11.3  .556  .530
# 6    6  Nickeil Alexander-Walker   SG   24  UTA  36   528  13.0  .609  .512
# 7    6  Nickeil Alexander-Walker   SG   24  MIN  21   323   8.5  .474  .558
# 8    7             Grayson Allen   SG   27  MIL  72  1972  12.3  .612  .657
# 9    8             Jarrett Allen    C   24  CLE  67  2208  19.9  .671  .014
# 10   9             Jose Alvarado   PG   24  NOP  61  1310  11.8  .525  .505
# 11  10             Kyle Anderson   PF   29  MIN  67  1896  15.0  .584  .210
# 12  11     Giannis Antetokounmpo   PF   28  MIL  63  2024  29.0  .605  .134
# 13  12    Thanasis Antetokounmpo   SF   30  MIL  35   140   3.4  .387  .185
# 14  13              Cole Anthony   PG   22  ORL  59  1522  16.1  .573  .337
# 15  14                OG Anunoby   SF   25  TOR  66  2355  14.7  .589  .415
# 16  15          Ryan Arcidiacono   PG   28  TOT  20   172   2.7  .351  .622
# 17  15          Ryan Arcidiacono   PG   28  NYK  11    26   3.1  .300  .600
# 18  15          Ryan Arcidiacono   PG   28  POR   9   146   2.6  .359  .625
# 19  16               Deni Avdija   SF   22  WAS  76  2020  11.2  .535  .401
# 20  17             Deandre Ayton    C   24  PHO  67  2035  19.9  .617  .027
# 21  18            Udoka Azubuike    C   23  UTA  34   302  15.9  .760  .000
# 22  19         Marvin Bagley III    C   23  DET  40   949  17.3  .589  .169
# 23  20       Patrick Baldwin Jr.   SF   20  GSW  29   214  11.0  .550  .772
# 24  Rk                    Player  Pos  Age   Tm   G    MP   PER   TS%  3PAr
# 25  21               LaMelo Ball   PG   21  CHO  36  1268  17.9  .541  .531
# 26  22                  Mo Bamba    C   24  TOT  47   762  15.8  .605  .517
# 27  22                  Mo Bamba    C   24  ORL  40   681  16.3  .613  .505
# 28  22                  Mo Bamba    C   24  LAL   7    81  11.1  .537  .625
# 29  23            Paolo Banchero   PF   20  ORL  72  2430  14.9  .529  .254
#
#     ... Unnamed: 19   OWS  DWS    WS   WS/48 Unnamed: 24  OBPM  DBPM   BPM  \
# 0   ...         NaN   0.7  1.3   2.0    .089         NaN  -1.6  -0.8  -2.5
# 1   ...         NaN   1.3  2.1   3.4    .144         NaN  -0.3   0.9   0.5
# 2   ...         NaN   3.5  3.8   7.4    .136         NaN   0.7   0.8   1.5
# 3   ...         NaN   1.0  0.4   1.4    .060         NaN  -1.5  -1.4  -2.9
# 4   ...         NaN   2.1  2.4   4.6    .131         NaN  -0.3   0.8   0.4
# 5   ...         NaN   0.2  0.8   1.0    .056         NaN  -1.6   0.5  -1.1
# 6   ...         NaN   0.3  0.5   0.8    .074         NaN  -0.6   1.1   0.4
# 7   ...         NaN  -0.1  0.3   0.2    .027         NaN  -3.1  -0.6  -3.7
# 8   ...         NaN   2.9  2.3   5.2    .125         NaN  -0.6   0.7   0.1
# 9   ...         NaN   5.5  3.9   9.5    .206         NaN   1.3   1.0   2.4
# 10  ...         NaN   0.1  1.7   1.8    .065         NaN  -2.0   0.7  -1.2
# 11  ...         NaN   2.5  2.5   5.0    .127         NaN   0.2   2.4   2.6
# 12  ...         NaN   4.9  3.8   8.7    .207         NaN   5.8   2.8   8.5
# 13  ...         NaN  -0.3  0.2  -0.1  -0.032         NaN  -8.3  -0.5  -8.8
# 14  ...         NaN   2.1  1.6   3.8    .119         NaN   0.7   0.5   1.2
# 15  ...         NaN   1.8  2.9   4.7    .096         NaN  -0.3   0.8   0.5
# 16  ...         NaN  -0.2  0.1  -0.1  -0.040         NaN  -7.3  -1.5  -8.8
# 17  ...         NaN   0.0  0.0   0.0  -0.010         NaN  -8.9   3.9  -5.1
# 18  ...         NaN  -0.2  0.0  -0.1  -0.045         NaN  -7.0  -2.4  -9.4
# 19  ...         NaN   0.0  2.2   2.2    .053         NaN  -2.8   0.5  -2.3
# 20  ...         NaN   3.3  3.0   6.3    .148         NaN   0.9   0.0   0.9
# 21  ...         NaN   0.4  0.4   0.8    .125         NaN  -1.3   0.5  -0.9
# 22  ...         NaN   1.3  0.6   1.9    .099         NaN   0.4  -1.3  -0.9
# 23  ...         NaN  -0.1  0.2   0.1    .023         NaN  -0.7  -1.3  -2.0
# 24  ...         NaN   OWS  DWS    WS   WS/48         NaN  OBPM  DBPM   BPM
# 25  ...         NaN   0.6  1.2   1.8    .067         NaN   3.2  -0.8   2.4
# 26  ...         NaN   1.1  1.1   2.2    .140         NaN  -0.2   0.7   0.6
# 27  ...         NaN   1.2  0.9   2.1    .151         NaN   0.4   0.9   1.3
# 28  ...         NaN  -0.1  0.1   0.1    .049         NaN  -5.2  -0.2  -5.4
# 29  ...         NaN  -0.3  2.7   2.4    .047         NaN  -0.7  -0.7  -1.5
#
#     VORP
# 0   -0.1
# 1    0.7
# 2    2.3
# 3   -0.3
# 4    1.0
# 5    0.2
# 6    0.3
# 7   -0.1
# 8    1.0
# 9    2.4
# 10   0.3
# 11   2.2
# 12   5.4
# 13  -0.2
# 14   1.2
# 15   1.5
# 16  -0.3
# 17   0.0
# 18  -0.3
# 19  -0.1
# 20   1.5
# 21   0.1
# 22   0.3
# 23   0.0
# 24  VORP
# 25   1.4
# 26   0.5
# 27   0.6
# 28  -0.1
# 29   0.3
#
# [30 rows x 29 columns]

# %%
advanced.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr',
#        'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
#        'Unnamed: 19', 'OWS', 'DWS', 'WS', 'WS/48', 'Unnamed: 24', 'OBPM',
#        'DBPM', 'BPM', 'VORP'],
#       dtype='object')

# %% [markdown]
# #### Cleaning DataFrame ####

# %% [markdown]
# ###### Cleaning Normal Stats ######

# %%
#renames columns to strings only#
nba.rename(
    columns={
        'FG%': 'FGP',
        '3P': 'TP',
        '3PA': 'TPA',
        '3P%': 'TPP',
        '2P': 'TWOP',
        '2PA': 'TWOPA',
        '2P%': 'TWOPP',
        'eFG%': 'eFGP',
        'FT%': 'FTP'
    }, inplace=True)

#removing duplicate players (stats of players that played on different teams)#
nba.drop_duplicates(subset=['Player'], keep=False, inplace=True)
#Dropping "Rk" Column#
nba.drop('Rk', axis=1, inplace=True)

#replacing NaN with 0#
nba.fillna(0, inplace=True)

nba[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]] = nba[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]].apply(pd.to_numeric)

# %% [markdown]
# ###### Cleaning Advanced Stats ######

# %%
advanced.rename(
    columns={
        'WS': 'Win Shares',
        'BPM': 'Avg. Box +/-'
    }, inplace=True)

#removing duplicate players (stats of players that played on different teams)#
advanced.drop_duplicates(subset=['Player'], keep=False, inplace=True)
#Dropping "Rk" Column#
advanced.drop('Rk', axis=1, inplace=True)

#replacing NaN with 0#
advanced.fillna(0, inplace=True)

advanced[['Age', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr','ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%','Unnamed: 19', 'OWS', 'DWS', 'Win Shares', 'WS/48', 'Unnamed: 24', 'OBPM','DBPM', 'Avg. Box +/-', 'VORP']] = advanced[['Age', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr','ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%','Unnamed: 19', 'OWS', 'DWS', 'Win Shares', 'WS/48', 'Unnamed: 24', 'OBPM','DBPM', 'Avg. Box +/-', 'VORP']].apply(pd.to_numeric)
advanced.drop(['Player','Pos','Age','Tm','G','MP','3PAr','FTr','ORB%','DRB%','TRB%','AST%','STL%','BLK%','TOV%','USG%','OWS','DWS','WS/48','OBPM','DBPM','TS%','VORP','Unnamed: 19','Unnamed: 24'], axis=1, inplace=True)
shorter_advanced = advanced
shorter_advanced
# Out:
#       PER  Win Shares  Avg. Box +/-
# 0    14.8         2.0          -2.5
# 1    17.5         3.4           0.5
# 2    20.0         7.4           1.5
# 3     9.5         1.4          -2.9
# 4    13.9         4.6           0.4
# ..    ...         ...           ...
# 693  14.1         1.8           0.0
# 694  21.9         6.6           3.2
# 695  13.0         0.1          -6.5
# 696  15.1         0.5          -3.5
# 697  16.6         6.5          -1.0
#
# [465 rows x 3 columns]

# %%
nba = nba.loc[~nba.index.duplicated(keep='first')]
shorter_advanced = shorter_advanced.loc[~shorter_advanced.index.duplicated(keep='first')]
full = pd.concat([nba, shorter_advanced], axis=1)
full
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA    FGP  ...   TRB  \
# 0    Precious Achiuwa   C  23  TOR  53  11  20.5  3.5   7.2  0.480  ...   5.8
# 1        Steven Adams   C  29  MEM  42  42  27.0  3.7   6.3  0.597  ...  11.5
# 2         Bam Adebayo   C  25  MIA  74  74  35.0  8.1  15.0  0.540  ...   9.3
# 3        Ochai Agbaji  SG  22  UTA  57  20  20.1  2.6   6.1  0.434  ...   2.1
# 4        Santi Aldama  PF  22  MEM  77  20  21.8  3.2   6.8  0.470  ...   4.8
# ..                ...  ..  ..  ...  ..  ..   ...  ...   ...    ...  ...   ...
# 693    Thaddeus Young  PF  34  TOR  54   9  14.7  2.0   3.7  0.545  ...   3.1
# 694        Trae Young  PG  24  ATL  72  72  34.7  8.2  19.1  0.429  ...   3.0
# 695    Omer Yurtseven   C  24  MIA   7   0   6.0  1.0   1.6  0.636  ...   1.4
# 696       Cody Zeller   C  30  MIA  13   1  14.1  2.1   3.6  0.574  ...   4.2
# 697       Ivica Zubac   C  25  LAC  74  74  28.7  4.3   6.7  0.631  ...  10.0
#
#       AST  STL  BLK  TOV   PF   PTS   PER  Win Shares  Avg. Box +/-
# 0     0.9  0.5  0.6  1.1  1.8   9.0  14.8         2.0          -2.5
# 1     2.3  0.9  1.1  1.9  2.3   8.6  17.5         3.4           0.5
# 2     3.2  1.2  0.8  2.5  2.8  20.6  20.0         7.4           1.5
# 3     1.0  0.2  0.3  0.6  1.7   7.6   9.5         1.4          -2.9
# 4     1.3  0.6  0.6  0.8  1.9   9.0  13.9         4.6           0.4
# ..    ...  ...  ...  ...  ...   ...   ...         ...           ...
# 693   1.4  1.0  0.1  0.8  1.6   4.4  14.1         1.8           0.0
# 694  10.0  1.1  0.1  4.0  1.4  26.2  21.9         6.6           3.2
# 695   0.0  0.1  0.1  0.3  1.0   2.3  13.0         0.1          -6.5
# 696   0.5  0.2  0.3  0.8  2.2   5.8  15.1         0.5          -3.5
# 697   1.0  0.4  1.3  1.6  2.9  10.7  16.6         6.5          -1.0
#
# [465 rows x 32 columns]

# %% [markdown]
# #### Filtering DataFrame ####

# %% [markdown]
# ###### Filtering Normal Stats ######

# %%
full.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FGP', 'TP',
#        'TPA', 'TPP', 'TWOP', 'TWOPA', 'TWOPP', 'eFGP', 'FT', 'FTA', 'FTP',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'PER',
#        'Win Shares', 'Avg. Box +/-'],
#       dtype='object')

# %%
full[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]] = nba[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]].apply(pd.to_numeric)

# %%
full.drop(full[full['G'] <= 4].index, inplace = True)
full.drop(full[full['TP'] <= 0.1].index, inplace = True)
full.drop(full[full['TPA'] <= 0.1].index, inplace = True)
full.drop(full[full['TPP'] <= 0.1].index, inplace = True)
full.drop(full[full['PTS'] <= 21.1].index, inplace = True)

# %% [markdown]
# #### Processing the Data ####

# %%
for index, row in full.iterrows():
    full.loc[index, "Score"] = (((row['FGP']*row['TPP']*row['FTP'])*(row['PTS']+row['TRB']+row['STL']+row['AST']+row['BLK']-row['TOV']-(row['FGA']-row['FG']))*(1-row['eFGP']))*(row['PTS']+row['TRB']+row['STL']+(0.5*row['AST'])+(0.5*row['BLK'])-row['FGA']-row['TOV']-(0.5*row['FTA'])-(0.5*row['PF'])))
    
#NBA Efficiency Metric = (Points)+(Rebounds)+(Steals)+(Assists)+(Blocked Shots)-(Turnovers)-(Missed Shots)#
#Win Score = (Points)+(Rebounds)+(Steals)+(½Assists)+(½Blocked Shots)-(Field Goal Attempts)-(Turnovers)-½(Free Throw Attempts)-½Personal Fouls#
#My equation = (((FG%*3P%*FT%)NBA Efficiency)(1-eFG%))(Win Score)#

# %%
full.sort_values(by=['Score'], ascending=False, inplace=True)
full.drop(['GS','MP','FG','FGA','TP','TPA','TWOP','TWOPA','TWOPP','eFGP','FT','FTA','FTP','ORB','DRB','STL','BLK','TOV','PF','Avg. Box +/-'], axis=1, inplace=True)
mvp = full.head(15)
mvp = mvp.copy()
mvp['Advanced Score'] = (mvp['PER']*mvp['Win Shares'])/100
mvp['MVP Score'] = round(mvp['Score']*mvp['Advanced Score'],2)
mvp.drop(['Score', 'Advanced Score'], axis=1, inplace=True)
mvp.sort_values(by=['MVP Score'], ascending=False, inplace=True)
mvp = mvp.rename({'FGP': 'FG%', 'TPP': '3P%', 'TRB': 'REB'}, axis='columns')

# %%
mvp
# Out:
#                       Player Pos Age   Tm   G    FG%    3P%   REB  AST   PTS  \
# 325             Nikola Jokić   C  27  DEN  68  0.633  0.385  11.9  9.8  24.8
# 188              Joel Embiid   C  28  PHI  66  0.548  0.330  10.2  4.2  33.1
# 163              Luka Dončić  PG  23  DAL  65  0.497  0.345   8.7  8.1  32.7
# 103             Jimmy Butler  SF  33  MIA  64  0.539  0.350   5.9  5.3  22.9
# 214  Shai Gilgeous-Alexander  PG  24  OKC  68  0.510  0.345   4.8  5.5  31.4
# 143            Anthony Davis   C  29  LAL  54  0.568  0.260  12.4  2.6  26.3
# 605             Jayson Tatum  PF  24  BOS  73  0.465  0.352   8.8  4.6  30.2
# 381           Damian Lillard  PG  32  POR  58  0.463  0.371   4.8  7.3  32.2
# 12     Giannis Antetokounmpo  PF  28  MIL  63  0.553  0.275  11.8  5.7  31.1
# 141            Stephen Curry  PG  34  GSW  54  0.491  0.426   6.1  6.3  29.6
# 401          Lauri Markkanen  SF  25  UTA  66  0.499  0.391   8.6  1.9  25.6
# 377            Kawhi Leonard  SF  31  LAC  50  0.514  0.423   6.3  3.9  23.7
# 514       Kristaps Porziņģis   C  27  WAS  65  0.498  0.385   8.4  2.7  23.2
# 312             LeBron James  PF  38  LAL  53  0.502  0.309   8.4  6.8  29.0
# 683          Zion Williamson  PF  22  NOP  29  0.608  0.368   7.0  4.6  26.0
#
#       PER  Win Shares  MVP Score
# 325  31.7        14.8     255.15
# 188  31.5        12.3     158.04
# 163  28.8        10.2      89.22
# 103  27.6        12.3      87.13
# 214  27.2        11.4      81.23
# 143  28.0         8.7      70.45
# 605  23.7        10.4      65.66
# 381  26.8         9.2      62.72
# 12   29.0         8.7      59.30
# 141  23.9         7.3      49.38
# 401  22.1         8.2      43.94
# 377  23.9         6.9      41.15
# 514  23.1         7.7      40.79
# 312  24.0         5.5      28.39
# 683  25.2         3.6      19.26

# %% [markdown]
# #### Visualization ####

# %% [markdown]
# ###### PER vs MVP Score Plot ######

# %%
x = mvp['PER']
y = mvp['MVP Score']

plt.scatter(x, y)
plt.title('PER vs. MVP Score', fontdict={'fontsize':16, 'fontweight':'bold'})
plt.xlabel('PER of Player', fontdict={'fontweight':'bold'})
plt.ylabel('MVP Score', fontdict={'fontweight':'bold'})
plt.show()

# %%
#plt.savefig('PER vs. MVP Score.png')

# %%
x = mvp['Win Shares']
y = mvp['MVP Score']

plt.scatter(x, y)
plt.title('Win Shares vs. MVP Score', fontdict={'fontsize':16, 'fontweight':'bold'})
plt.xlabel('Win Shares of Player', fontdict={'fontweight':'bold'})
plt.ylabel('MVP Score', fontdict={'fontweight':'bold'})
plt.show()

# %%
#plt.savefig('Win Shares vs. MVP Score.png')

# %%
mvp.set_index(['Player', 'Pos', 'Age', 'Tm', 'G', 'REB', 'AST', 'PTS', 'FG%', '3P%', 'PER', 'Win Shares', 'MVP Score'], inplace=True)
mvp
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Nikola Jokić, C, 27, DEN, 68, 11.9, 9.8, 24.8, 0.633, 0.385, 31.7, 14.8, 255.15), (Joel Embiid, C, 28, PHI, 66, 10.2, 4.2, 33.1, 0.548, 0.33, 31.5, 12.3, 158.04), (Luka Dončić, PG, 23, DAL, 65, 8.7, 8.1, 32.7, 0.497, 0.345, 28.8, 10.2, 89.22), (Jimmy Butler, SF, 33, MIA, 64, 5.9, 5.3, 22.9, 0.539, 0.35, 27.6, 12.3, 87.13), (Shai Gilgeous-Alexander, PG, 24, OKC, 68, 4.8, 5.5, 31.4, 0.51, 0.345, 27.2, 11.4, 81.23), (Anthony Davis, C, 29, LAL, 54, 12.4, 2.6, 26.3, 0.568, 0.26, 28.0, 8.7, 70.45), (Jayson Tatum, PF, 24, BOS, 73, 8.8, 4.6, 30.2, 0.465, 0.352, 23.7, 10.4, 65.66), (Damian Lillard, PG, 32, POR, 58, 4.8, 7.3, 32.2, 0.463, 0.371, 26.8, 9.2, 62.72), (Giannis Antetokounmpo, PF, 28, MIL, 63, 11.8, 5.7, 31.1, 0.553, 0.275, 29.0, 8.7, 59.3), (Stephen Curry, PG, 34, GSW, 54, 6.1, 6.3, 29.6, 0.491, 0.426, 23.9, 7.3, 49.38), (Lauri Markkanen, SF, 25, UTA, 66, 8.6, 1.9, 25.6, 0.499, 0.391, 22.1, 8.2, 43.94), (Kawhi Leonard, SF, 31, LAC, 50, 6.3, 3.9, 23.7, 0.514, 0.423, 23.9, 6.9, 41.15), (Kristaps Porziņģis, C, 27, WAS, 65, 8.4, 2.7, 23.2, 0.498, 0.385, 23.1, 7.7, 40.79), (LeBron James, PF, 38, LAL, 53, 8.4, 6.8, 29.0, 0.502, 0.309, 24.0, 5.5, 28.39), (Zion Williamson, PF, 22, NOP, 29, 7.0, 4.6, 26.0, 0.608, 0.368, 25.2, 3.6, 19.26)]

# %% [markdown]
# #### Exporting ####

# %% [markdown]
# ###### MVP Table to CSV ######

# %%
import datetime

current_date = datetime.datetime.now()
filename = str(current_date.month)+"-"+str(current_date.day)+"-"+str(current_date.year)
output = mvp.to_csv(str("MVP " + filename))
