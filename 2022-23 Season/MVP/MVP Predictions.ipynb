# %% [markdown]
# # MVP Predictions #

# %%
# -*- coding: utf-8 -*-#
"""
Created by MinhKhang Nguyen
July 27 2021 7:37 PM - August 6 2021 2:08 AM
"""
# Out:
# '\nCreated by MinhKhang Nguyen\nJuly 27 2021 7:37 PM - August 6 2021 2:08 AM\n'

# %%
import pandas as pd 
import random as rnd
import numpy as np
import matplotlib.pyplot as plt

# %%
import ssl
ssl._create_default_https_econtext = ssl._create_unverified_context

# %% [markdown]
# #### Importing Data ####

# %% [markdown]
# ###### Importing Normal Stats ######

# %%
year = "2019"

# %%
html_url = "https://www.basketball-reference.com/leagues/NBA_"+year+"_per_game.html"
nba_tables = pd.read_html(html_url)
len(nba_tables)
nba = nba_tables[0]
nba.head(30)
# Out:
#     Rk                  Player  Pos  Age   Tm   G  GS    MP    FG   FGA  ...  \
# 0    1            Álex Abrines   SG   25  OKC  31   2  19.0   1.8   5.1  ...
# 1    2              Quincy Acy   PF   28  PHO  10   0  12.3   0.4   1.8  ...
# 2    3            Jaylen Adams   PG   22  ATL  34   1  12.6   1.1   3.2  ...
# 3    4            Steven Adams    C   25  OKC  80  80  33.4   6.0  10.1  ...
# 4    5             Bam Adebayo    C   21  MIA  82  28  23.3   3.4   5.9  ...
# 5    6               Deng Adel   SF   21  CLE  19   3  10.2   0.6   1.9  ...
# 6    7  DeVaughn Akoon-Purcell   SG   25  DEN   7   0   3.1   0.4   1.4  ...
# 7    8       LaMarcus Aldridge    C   33  SAS  81  81  33.2   8.4  16.3  ...
# 8    9            Rawle Alkins   SG   21  CHI  10   1  12.0   1.3   3.9  ...
# 9   10           Grayson Allen   SG   23  UTA  38   2  10.9   1.8   4.7  ...
# 10  11           Jarrett Allen    C   20  BRK  80  80  26.2   4.2   7.1  ...
# 11  12            Kadeem Allen   PG   26  NYK  19   1  21.9   3.4   7.4  ...
# 12  13         Al-Farouq Aminu   PF   28  POR  81  81  28.3   3.2   7.3  ...
# 13  14         Justin Anderson   SF   25  ATL  48   4   9.6   1.3   3.3  ...
# 14  15           Kyle Anderson   SF   25  MEM  43  40  29.8   3.5   6.4  ...
# 15  16           Ryan Anderson   PF   30  TOT  25   8  12.9   0.8   2.8  ...
# 16  16           Ryan Anderson   PF   30  PHO  15   8  18.5   1.3   4.0  ...
# 17  16           Ryan Anderson   PF   30  MIA  10   0   4.4   0.2   0.9  ...
# 18  17            Ike Anigbogu    C   20  IND   3   0   2.0   0.0   1.0  ...
# 19  18   Giannis Antetokounmpo   PF   24  MIL  72  72  32.8  10.0  17.3  ...
# 20  19    Kostas Antetokounmpo   PF   21  DAL   2   0   5.5   0.0   1.5  ...
# 21  20         Carmelo Anthony   PF   34  HOU  10   2  29.4   4.9  12.1  ...
# 22  Rk                  Player  Pos  Age   Tm   G  GS    MP    FG   FGA  ...
# 23  21              OG Anunoby   SF   21  TOR  67   6  20.2   2.7   6.0  ...
# 24  22        Ryan Arcidiacono   PG   24  CHI  81  32  24.2   2.3   5.2  ...
# 25  23            Trevor Ariza   SF   33  TOT  69  69  34.0   4.3  10.7  ...
# 26  23            Trevor Ariza   SF   33  PHO  26  26  34.0   3.3   8.7  ...
# 27  23            Trevor Ariza   SF   33  WAS  43  43  34.1   4.8  11.8  ...
# 28  24           D.J. Augustin   PG   31  ORL  81  81  28.0   3.9   8.4  ...
# 29  25           Deandre Ayton    C   20  PHO  71  70  30.7   7.2  12.3  ...
#
#       FT%  ORB   DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0    .923  0.2   1.4   1.5  0.6  0.5  0.2  0.5  1.7   5.3
# 1    .700  0.3   2.2   2.5  0.8  0.1  0.4  0.4  2.4   1.7
# 2    .778  0.3   1.4   1.8  1.9  0.4  0.1  0.8  1.3   3.2
# 3    .500  4.9   4.6   9.5  1.6  1.5  1.0  1.7  2.6  13.9
# 4    .735  2.0   5.3   7.3  2.2  0.9  0.8  1.5  2.5   8.9
# 5   1.000  0.2   0.8   1.0  0.3  0.1  0.2  0.3  0.7   1.7
# 6    .500  0.1   0.4   0.6  0.9  0.3  0.0  0.3  0.6   1.0
# 7    .847  3.1   6.1   9.2  2.4  0.5  1.3  1.8  2.2  21.3
# 8    .667  1.1   1.5   2.6  1.3  0.1  0.0  0.8  0.7   3.7
# 9    .750  0.1   0.5   0.6  0.7  0.2  0.2  0.9  1.2   5.6
# 10   .709  2.4   6.0   8.4  1.4  0.5  1.5  1.3  2.3  10.9
# 11   .778  0.4   2.3   2.7  4.0  0.8  0.2  1.4  2.4   9.9
# 12   .867  1.4   6.1   7.5  1.3  0.8  0.4  0.9  1.8   9.4
# 13   .743  0.5   1.3   1.8  0.5  0.5  0.3  0.5  1.0   3.7
# 14   .578  1.1   4.7   5.8  3.0  1.3  0.9  1.3  2.6   8.0
# 15   .750  0.7   1.4   2.2  0.8  0.2  0.0  0.6  1.0   2.5
# 16   .786  0.9   2.1   3.0  1.1  0.2  0.1  0.8  1.5   3.7
# 17   .500  0.4   0.5   0.9  0.2  0.1  0.0  0.2  0.2   0.7
# 18    NaN  0.3   0.7   1.0  0.3  0.0  0.3  0.3  0.0   0.0
# 19   .729  2.2  10.3  12.5  5.9  1.3  1.5  3.7  3.2  27.7
# 20   .500  0.0   0.5   0.5  0.0  1.0  0.0  0.5  0.0   1.0
# 21   .682  0.9   4.5   5.4  0.5  0.4  0.7  0.8  3.2  13.4
# 22    FT%  ORB   DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 23   .581  0.9   2.1   2.9  0.7  0.7  0.3  0.8  2.1   7.0
# 24   .873  0.3   2.4   2.7  3.3  0.8  0.0  0.8  2.1   6.7
# 25   .793  0.7   4.7   5.4  3.7  1.3  0.3  1.5  1.9  12.5
# 26   .837  0.6   5.0   5.6  3.3  1.5  0.3  1.5  1.7   9.9
# 27   .777  0.8   4.5   5.3  3.8  1.2  0.3  1.6  2.0  14.1
# 28   .866  0.5   2.0   2.5  5.3  0.6  0.0  1.6  1.4  11.7
# 29   .746  3.1   7.1  10.3  1.8  0.9  0.9  1.8  2.9  16.3
#
# [30 rows x 30 columns]

# %%
nba.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %% [markdown]
# ###### Importing Advanced Stats ######

# %%
html_url = "https://www.basketball-reference.com/leagues/NBA_"+year+"_advanced.html"
advanced_tables = pd.read_html(html_url)
len(advanced_tables)
advanced = advanced_tables[0]
advanced.head(30)
# Out:
#     Rk                  Player  Pos  Age   Tm   G    MP   PER   TS%  3PAr  \
# 0    1            Álex Abrines   SG   25  OKC  31   588   6.3  .507  .809
# 1    2              Quincy Acy   PF   28  PHO  10   123   2.9  .379  .833
# 2    3            Jaylen Adams   PG   22  ATL  34   428   7.6  .474  .673
# 3    4            Steven Adams    C   25  OKC  80  2669  18.5  .591  .002
# 4    5             Bam Adebayo    C   21  MIA  82  1913  17.9  .623  .031
# 5    6               Deng Adel   SF   21  CLE  19   194   2.7  .424  .639
# 6    7  DeVaughn Akoon-Purcell   SG   25  DEN   7    22   8.2  .322  .400
# 7    8       LaMarcus Aldridge    C   33  SAS  81  2687  22.9  .576  .032
# 8    9            Rawle Alkins   SG   21  CHI  10   120   8.1  .418  .308
# 9   10           Grayson Allen   SG   23  UTA  38   416   7.5  .516  .556
# 10  11           Jarrett Allen    C   20  BRK  80  2096  18.5  .632  .079
# 11  12            Kadeem Allen   PG   26  NYK  19   416  16.2  .574  .255
# 12  13         Al-Farouq Aminu   PF   28  POR  81  2292  13.2  .568  .472
# 13  14         Justin Anderson   SF   25  ATL  48   463  11.2  .516  .490
# 14  15           Kyle Anderson   SF   25  MEM  43  1281  12.8  .569  .123
# 15  16           Ryan Anderson   PF   30  TOT  25   322   4.6  .414  .580
# 16  16           Ryan Anderson   PF   30  PHO  15   278   4.6  .423  .567
# 17  16           Ryan Anderson   PF   30  MIA  10    44   4.5  .354  .667
# 18  17            Ike Anigbogu    C   20  IND   3     6  -6.0  .000  .000
# 19  18   Giannis Antetokounmpo   PF   24  MIL  72  2358  30.9  .644  .163
# 20  19    Kostas Antetokounmpo   PF   21  DAL   2    11  -0.9  .210  .000
# 21  20         Carmelo Anthony   PF   34  HOU  10   294  10.9  .513  .529
# 22  Rk                  Player  Pos  Age   Tm   G    MP   PER   TS%  3PAr
# 23  21              OG Anunoby   SF   21  TOR  67  1352   9.8  .544  .500
# 24  22        Ryan Arcidiacono   PG   24  CHI  81  1961  11.6  .588  .519
# 25  23            Trevor Ariza   SF   33  TOT  69  2349  12.1  .534  .590
# 26  23            Trevor Ariza   SF   33  PHO  26   884  10.5  .525  .612
# 27  23            Trevor Ariza   SF   33  WAS  43  1465  13.0  .538  .580
# 28  24           D.J. Augustin   PG   31  ORL  81  2269  15.7  .616  .459
# 29  25           Deandre Ayton    C   20  PHO  71  2183  20.5  .608  .005
#
#     ... Unnamed: 19   OWS  DWS    WS   WS/48 Unnamed: 24   OBPM  DBPM    BPM  \
# 0   ...         NaN   0.1  0.6   0.6    .053         NaN   -3.7   0.4   -3.3
# 1   ...         NaN  -0.1  0.0  -0.1  -0.022         NaN   -7.6  -0.5   -8.1
# 2   ...         NaN  -0.1  0.2   0.1    .011         NaN   -3.8  -0.5   -4.3
# 3   ...         NaN   5.1  4.0   9.1    .163         NaN    0.7   0.4    1.1
# 4   ...         NaN   3.4  3.4   6.8    .171         NaN   -0.4   2.2    1.8
# 5   ...         NaN  -0.2  0.0  -0.2  -0.054         NaN   -5.9  -1.6   -7.5
# 6   ...         NaN  -0.1  0.0   0.0  -0.051         NaN   -7.9   2.1   -5.8
# 7   ...         NaN   6.4  2.9   9.3    .167         NaN    2.4  -0.6    1.8
# 8   ...         NaN  -0.1  0.0  -0.1  -0.042         NaN   -3.8  -3.5   -7.3
# 9   ...         NaN  -0.4  0.4   0.0    .002         NaN   -4.2  -2.1   -6.3
# 10  ...         NaN   4.4  3.3   7.6    .175         NaN    0.2   1.4    1.6
# 11  ...         NaN   0.7  0.2   1.0    .111         NaN    0.2   0.3    0.5
# 12  ...         NaN   3.0  2.8   5.8    .121         NaN    0.1   0.6    0.7
# 13  ...         NaN   0.1  0.4   0.4    .043         NaN   -2.4  -0.3   -2.7
# 14  ...         NaN   0.8  1.8   2.7    .100         NaN   -1.6   2.4    0.8
# 15  ...         NaN  -0.3  0.0  -0.2  -0.035         NaN   -4.5  -1.9   -6.4
# 16  ...         NaN  -0.2  0.0  -0.2  -0.039         NaN   -4.5  -1.9   -6.3
# 17  ...         NaN   0.0  0.0   0.0  -0.009         NaN   -4.6  -1.9   -6.5
# 18  ...         NaN  -0.1  0.0  -0.1  -0.480         NaN  -14.0  -2.3  -16.2
# 19  ...         NaN   8.9  5.5  14.4    .292         NaN    6.3   4.1   10.4
# 20  ...         NaN  -0.1  0.0  -0.1  -0.247         NaN  -12.6  -0.1  -12.7
# 21  ...         NaN   0.1  0.2   0.3    .048         NaN   -1.3  -1.4   -2.7
# 22  ...         NaN   OWS  DWS    WS   WS/48         NaN   OBPM  DBPM    BPM
# 23  ...         NaN   0.3  1.7   2.0    .070         NaN   -2.4   0.1   -2.4
# 24  ...         NaN   2.8  0.9   3.7    .090         NaN   -2.0   0.1   -1.9
# 25  ...         NaN   1.3  1.2   2.5    .052         NaN   -0.7  -0.6   -1.3
# 26  ...         NaN   0.2  0.5   0.6    .035         NaN   -1.1   0.0   -1.1
# 27  ...         NaN   1.1  0.8   1.9    .062         NaN   -0.5  -0.9   -1.4
# 28  ...         NaN   5.0  1.9   6.9    .146         NaN    1.1  -0.7    0.5
# 29  ...         NaN   4.1  1.7   5.8    .128         NaN    1.3  -1.1    0.2
#
#     VORP
# 0   -0.2
# 1   -0.2
# 2   -0.2
# 3    2.1
# 4    1.8
# 5   -0.3
# 6    0.0
# 7    2.6
# 8   -0.2
# 9   -0.5
# 10   1.9
# 11   0.3
# 12   1.5
# 13  -0.1
# 14   0.9
# 15  -0.4
# 16  -0.3
# 17   0.0
# 18   0.0
# 19   7.4
# 20   0.0
# 21  -0.1
# 22  VORP
# 23  -0.1
# 24   0.1
# 25   0.4
# 26   0.2
# 27   0.2
# 28   1.4
# 29   1.2
#
# [30 rows x 29 columns]

# %%
advanced.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr',
#        'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
#        'Unnamed: 19', 'OWS', 'DWS', 'WS', 'WS/48', 'Unnamed: 24', 'OBPM',
#        'DBPM', 'BPM', 'VORP'],
#       dtype='object')

# %% [markdown]
# #### Cleaning DataFrame ####

# %% [markdown]
# ###### Cleaning Normal Stats ######

# %%
#renames columns to strings only#
nba.rename(
    columns={
        'FG%': 'FGP',
        '3P': 'TP',
        '3PA': 'TPA',
        '3P%': 'TPP',
        '2P': 'TWOP',
        '2PA': 'TWOPA',
        '2P%': 'TWOPP',
        'eFG%': 'eFGP',
        'FT%': 'FTP'
    }, inplace=True)

#removing duplicate players (stats of players that played on different teams)#
nba.drop_duplicates(subset=['Player'], keep=False, inplace=True)
#Dropping "Rk" Column#
nba.drop('Rk', axis=1, inplace=True)

#replacing NaN with 0#
nba.fillna(0, inplace=True)

nba[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]] = nba[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]].apply(pd.to_numeric)

# %% [markdown]
# ###### Cleaning Advanced Stats ######

# %%
advanced.rename(
    columns={
        'WS': 'Win Shares',
        'BPM': 'Avg. Box +/-'
    }, inplace=True)

#removing duplicate players (stats of players that played on different teams)#
advanced.drop_duplicates(subset=['Player'], keep=False, inplace=True)
#Dropping "Rk" Column#
advanced.drop('Rk', axis=1, inplace=True)

#replacing NaN with 0#
advanced.fillna(0, inplace=True)

advanced[['Age', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr','ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%','Unnamed: 19', 'OWS', 'DWS', 'Win Shares', 'WS/48', 'Unnamed: 24', 'OBPM','DBPM', 'Avg. Box +/-', 'VORP']] = advanced[['Age', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr','ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%','Unnamed: 19', 'OWS', 'DWS', 'Win Shares', 'WS/48', 'Unnamed: 24', 'OBPM','DBPM', 'Avg. Box +/-', 'VORP']].apply(pd.to_numeric)
advanced.drop(['Player','Pos','Age','Tm','G','MP','3PAr','FTr','ORB%','DRB%','TRB%','AST%','STL%','BLK%','TOV%','USG%','OWS','DWS','WS/48','OBPM','DBPM','TS%','VORP','Unnamed: 19','Unnamed: 24'], axis=1, inplace=True)
shorter_advanced = advanced
shorter_advanced
# Out:
#       PER  Win Shares  Avg. Box +/-
# 0     6.3         0.6          -3.3
# 1     2.9        -0.1          -8.1
# 2     7.6         0.1          -4.3
# 3    18.5         9.1           1.1
# 4    17.9         6.8           1.8
# ..    ...         ...           ...
# 723   2.3         0.0          -6.9
# 724  16.2         6.9           1.5
# 725  17.0         3.3          -0.6
# 726  17.2         3.9           0.1
# 730  16.2         2.0          -3.2
#
# [444 rows x 3 columns]

# %%
nba = nba.loc[~nba.index.duplicated(keep='first')]
shorter_advanced = shorter_advanced.loc[~shorter_advanced.index.duplicated(keep='first')]
full = pd.concat([nba, shorter_advanced], axis=1)
full
# Out:
#              Player Pos Age   Tm   G  GS    MP   FG   FGA    FGP  ...  TRB  \
# 0      Álex Abrines  SG  25  OKC  31   2  19.0  1.8   5.1  0.357  ...  1.5
# 1        Quincy Acy  PF  28  PHO  10   0  12.3  0.4   1.8  0.222  ...  2.5
# 2      Jaylen Adams  PG  22  ATL  34   1  12.6  1.1   3.2  0.345  ...  1.8
# 3      Steven Adams   C  25  OKC  80  80  33.4  6.0  10.1  0.595  ...  9.5
# 4       Bam Adebayo   C  21  MIA  82  28  23.3  3.4   5.9  0.576  ...  7.3
# ..              ...  ..  ..  ...  ..  ..   ...  ...   ...    ...  ...  ...
# 723      Nick Young  SG  33  DEN   4   0   9.3  0.8   2.3  0.333  ...  0.3
# 724  Thaddeus Young  PF  30  IND  81  81  30.7  5.5  10.4  0.527  ...  6.5
# 725      Trae Young  PG  20  ATL  81  81  30.9  6.5  15.5  0.418  ...  3.7
# 726     Cody Zeller   C  26  CHO  49  47  25.4  3.9   7.0  0.551  ...  6.8
# 730      Ante Žižić   C  22  CLE  59  25  18.3  3.1   5.6  0.553  ...  5.4
#
#      AST  STL  BLK  TOV   PF   PTS   PER  Win Shares  Avg. Box +/-
# 0    0.6  0.5  0.2  0.5  1.7   5.3   6.3         0.6          -3.3
# 1    0.8  0.1  0.4  0.4  2.4   1.7   2.9        -0.1          -8.1
# 2    1.9  0.4  0.1  0.8  1.3   3.2   7.6         0.1          -4.3
# 3    1.6  1.5  1.0  1.7  2.6  13.9  18.5         9.1           1.1
# 4    2.2  0.9  0.8  1.5  2.5   8.9  17.9         6.8           1.8
# ..   ...  ...  ...  ...  ...   ...   ...         ...           ...
# 723  0.5  0.0  0.3  0.5  1.0   2.3   2.3         0.0          -6.9
# 724  2.5  1.5  0.4  1.5  2.4  12.6  16.2         6.9           1.5
# 725  8.1  0.9  0.2  3.8  1.7  19.1  17.0         3.3          -0.6
# 726  2.1  0.8  0.8  1.3  3.3  10.1  17.2         3.9           0.1
# 730  0.9  0.2  0.4  1.0  1.9   7.8  16.2         2.0          -3.2
#
# [444 rows x 32 columns]

# %% [markdown]
# #### Filtering DataFrame ####

# %% [markdown]
# ###### Filtering Normal Stats ######

# %%
full.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FGP', 'TP',
#        'TPA', 'TPP', 'TWOP', 'TWOPA', 'TWOPP', 'eFGP', 'FT', 'FTA', 'FTP',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'PER',
#        'Win Shares', 'Avg. Box +/-'],
#       dtype='object')

# %%
full[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]] = nba[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]].apply(pd.to_numeric)

# %%
full.drop(full[full['G'] <= 10].index, inplace = True)
full.drop(full[full['TP'] <= 0.1].index, inplace = True)
full.drop(full[full['TPA'] <= 0.1].index, inplace = True)
full.drop(full[full['TPP'] <= 0.1].index, inplace = True)
full.drop(full[full['PTS'] <= 21.1].index, inplace = True)

# %% [markdown]
# #### Processing the Data ####

# %%
for index, row in full.iterrows():
    full.loc[index, "Score"] = (((row['FGP']*row['TPP']*row['FTP'])*(row['PTS']+row['TRB']+row['STL']+row['AST']+row['BLK']-row['TOV']-(row['FGA']-row['FG']))*(1-row['eFGP']))*(row['PTS']+row['TRB']+row['STL']+(0.5*row['AST'])+(0.5*row['BLK'])-row['FGA']-row['TOV']-(0.5*row['FTA'])-(0.5*row['PF'])))
    
#NBA Efficiency Metric = (Points)+(Rebounds)+(Steals)+(Assists)+(Blocked Shots)-(Turnovers)-(Missed Shots)#
#Win Score = (Points)+(Rebounds)+(Steals)+(½Assists)+(½Blocked Shots)-(Field Goal Attempts)-(Turnovers)-½(Free Throw Attempts)-½Personal Fouls#
#My equation = (((FG%*3P%*FT%)NBA Efficiency)(1-eFG%))(Win Score)#

# %%
full.sort_values(by=['Score'], ascending=False, inplace=True)
full.drop(['GS','MP','FG','FGA','TP','TPA','TWOP','TWOPA','TWOPP','eFGP','FT','FTA','FTP','ORB','DRB','STL','BLK','TOV','PF','Avg. Box +/-'], axis=1, inplace=True)
mvp = full.head(15)
mvp = mvp.copy()
mvp['Advanced Score'] = (mvp['PER']*mvp['Win Shares'])/100
mvp['MVP Score'] = round(mvp['Score']*mvp['Advanced Score'],2)
mvp.drop(['Score', 'Advanced Score'], axis=1, inplace=True)
mvp.sort_values(by=['MVP Score'], ascending=False, inplace=True)
mvp = mvp.rename({'FGP': 'FG%', 'TPP': '3P%', 'TRB': 'REB'}, axis='columns')

# %%
mvp
# Out:
#                     Player Pos Age   Tm   G    FG%    3P%   REB   AST   PTS  \
# 19   Giannis Antetokounmpo  PF  24  MIL  72  0.578  0.256  12.5   5.9  27.7
# 280           James Harden  PG  29  HOU  78  0.442  0.368   6.6   7.5  36.1
# 167          Anthony Davis   C  25  NOP  56  0.517  0.331  12.0   3.9  25.9
# 672     Karl-Anthony Towns   C  23  MIN  77  0.518  0.400  12.4   3.4  24.4
# 207            Joel Embiid   C  24  PHI  64  0.484  0.300  13.6   3.7  27.5
# 198           Kevin Durant  SF  30  GSW  78  0.521  0.353   6.4   5.9  26.0
# 252            Paul George  SF  28  OKC  77  0.438  0.386   8.2   4.1  28.0
# 412          Kawhi Leonard  SF  27  TOR  60  0.496  0.371   7.3   3.3  26.6
# 165          Stephen Curry  PG  30  GSW  69  0.472  0.437   5.3   5.2  27.3
# 416         Damian Lillard  PG  28  POR  80  0.444  0.369   4.6   6.9  25.8
# 336           Kyrie Irving  PG  26  BOS  67  0.487  0.401   5.0   6.9  23.8
# 347           LeBron James  SF  34  LAL  55  0.510  0.339   8.5   8.3  27.4
# 274          Blake Griffin  PF  29  DET  75  0.462  0.362   7.5   5.4  24.5
# 700      Russell Westbrook  PG  30  OKC  73  0.428  0.290  11.1  10.7  22.9
# 575          Julius Randle  PF  24  NOP  73  0.524  0.344   8.7   3.1  21.4
#
#       PER  Win Shares  MVP Score
# 19   30.9        14.4     130.21
# 280  30.6        15.2     127.88
# 167  30.3         9.5     108.94
# 672  26.3        10.4      96.48
# 207  26.1         8.7      68.95
# 198  24.2        11.5      65.53
# 252  23.3        11.9      63.39
# 412  25.8         9.5      60.74
# 165  24.4         9.7      52.56
# 416  23.7        12.1      47.34
# 336  24.3         9.1      41.90
# 347  25.6         7.2      41.16
# 274  21.0         8.0      23.48
# 700  21.1         6.8      23.12
# 575  20.9         6.1      18.21

# %% [markdown]
# #### Visualization ####

# %% [markdown]
# ###### PER vs MVP Score Plot ######

# %%
x = mvp['PER']
y = mvp['MVP Score']

plt.scatter(x, y)
plt.title('PER vs. MVP Score', fontdict={'fontsize':16, 'fontweight':'bold'})
plt.xlabel('PER of Player', fontdict={'fontweight':'bold'})
plt.ylabel('MVP Score', fontdict={'fontweight':'bold'})
plt.show()

# %%
#plt.savefig('PER vs. MVP Score.png')

# %%
x = mvp['Win Shares']
y = mvp['MVP Score']

plt.scatter(x, y)
plt.title('Win Shares vs. MVP Score', fontdict={'fontsize':16, 'fontweight':'bold'})
plt.xlabel('Win Shares of Player', fontdict={'fontweight':'bold'})
plt.ylabel('MVP Score', fontdict={'fontweight':'bold'})
plt.show()

# %%
#plt.savefig('Win Shares vs. MVP Score.png')

# %%
mvp.set_index(['Player', 'Pos', 'Age', 'Tm', 'G', 'REB', 'AST', 'PTS', 'FG%', '3P%', 'PER', 'Win Shares', 'MVP Score'], inplace=True)
mvp
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Giannis Antetokounmpo, PF, 24, MIL, 72, 12.5, 5.9, 27.7, 0.578, 0.256, 30.9, 14.4, 130.21), (James Harden, PG, 29, HOU, 78, 6.6, 7.5, 36.1, 0.442, 0.368, 30.6, 15.2, 127.88), (Anthony Davis, C, 25, NOP, 56, 12.0, 3.9, 25.9, 0.517, 0.331, 30.3, 9.5, 108.94), (Karl-Anthony Towns, C, 23, MIN, 77, 12.4, 3.4, 24.4, 0.518, 0.4, 26.3, 10.4, 96.48), (Joel Embiid, C, 24, PHI, 64, 13.6, 3.7, 27.5, 0.484, 0.3, 26.1, 8.7, 68.95), (Kevin Durant, SF, 30, GSW, 78, 6.4, 5.9, 26.0, 0.521, 0.353, 24.2, 11.5, 65.53), (Paul George, SF, 28, OKC, 77, 8.2, 4.1, 28.0, 0.438, 0.386, 23.3, 11.9, 63.39), (Kawhi Leonard, SF, 27, TOR, 60, 7.3, 3.3, 26.6, 0.496, 0.371, 25.8, 9.5, 60.74), (Stephen Curry, PG, 30, GSW, 69, 5.3, 5.2, 27.3, 0.472, 0.437, 24.4, 9.7, 52.56), (Damian Lillard, PG, 28, POR, 80, 4.6, 6.9, 25.8, 0.444, 0.369, 23.7, 12.1, 47.34), (Kyrie Irving, PG, 26, BOS, 67, 5.0, 6.9, 23.8, 0.487, 0.401, 24.3, 9.1, 41.9), (LeBron James, SF, 34, LAL, 55, 8.5, 8.3, 27.4, 0.51, 0.339, 25.6, 7.2, 41.16), (Blake Griffin, PF, 29, DET, 75, 7.5, 5.4, 24.5, 0.462, 0.362, 21.0, 8.0, 23.48), (Russell Westbrook, PG, 30, OKC, 73, 11.1, 10.7, 22.9, 0.428, 0.29, 21.1, 6.8, 23.12), (Julius Randle, PF, 24, NOP, 73, 8.7, 3.1, 21.4, 0.524, 0.344, 20.9, 6.1, 18.21)]

# %% [markdown]
# #### Exporting ####

# %% [markdown]
# ###### MVP Table to CSV ######

# %%
'''
import datetime

current_date = datetime.datetime.now()
filename = str(current_date.month)+"-"+str(current_date.day)+"-"+str(current_date.year)
output = mvp.to_csv(str("MVP " + filename))
'''
# Out:
# '\nimport datetime\n\ncurrent_date = datetime.datetime.now()\nfilename = str(current_date.month)+"-"+str(current_date.day)+"-"+str(current_date.year)\noutput = mvp.to_csv(str("MVP " + filename))\n'
