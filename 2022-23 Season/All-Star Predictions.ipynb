# %% [markdown]
# # All-Star Predictions #

# %%
# -*- coding: utf-8 -*-#
"""
Created by MinhKhang Nguyen
July 27 2021 7:37 PM - August 6 2021 2:08 AM
"""
# Out:
# '\nCreated by MinhKhang Nguyen\nJuly 27 2021 7:37 PM - August 6 2021 2:08 AM\n'

# %%
import pandas as pd 
import random as rnd
import numpy as np
import matplotlib.pyplot as plt

# %%
import ssl
ssl._create_default_https_econtext = ssl._create_unverified_context

# %% [markdown]
# #### Importing Data ####

# %% [markdown]
# ###### Importing Normal Stats ######

# %%
html_url = "https://www.basketball-reference.com/leagues/NBA_2023_per_game.html"
nba_tables = pd.read_html(html_url)
len(nba_tables)
nba = nba_tables[0]
nba.head(30)
# Out:
#     Rk                    Player  Pos  Age   Tm   G  GS    MP    FG   FGA  \
# 0    1          Precious Achiuwa    C   23  TOR  36  11  23.5   3.9   8.1
# 1    2              Steven Adams    C   29  MEM  42  42  27.0   3.7   6.3
# 2    3               Bam Adebayo    C   25  MIA  54  54  35.4   8.5  15.7
# 3    4              Ochai Agbaji   SG   22  UTA  38   2  15.2   1.8   3.7
# 4    5              Santi Aldama   PF   22  MEM  55  18  22.0   3.3   7.0
# 5    6  Nickeil Alexander-Walker   SG   24  TOT  38   3  14.1   2.2   4.5
# 6    6  Nickeil Alexander-Walker   SG   24  UTA  36   3  14.7   2.3   4.7
# 7    6  Nickeil Alexander-Walker   SG   24  MIN   2   0   3.0   0.5   1.0
# 8    7             Grayson Allen   SG   27  MIL  54  52  27.6   3.4   7.6
# 9    8             Jarrett Allen    C   24  CLE  55  55  33.2   6.1   9.4
# 10   9             Jose Alvarado   PG   24  NOP  59  10  21.7   3.3   8.1
# 11  10             Kyle Anderson   PF   29  MIN  48  32  26.1   3.1   6.3
# 12  11     Giannis Antetokounmpo   PF   28  MIL  47  47  33.1  11.3  21.0
# 13  12    Thanasis Antetokounmpo   SF   30  MIL  25   0   4.0   0.2   0.8
# 14  13              Cole Anthony   PG   22  ORL  40   3  24.9   4.2   9.6
# 15  14                OG Anunoby   SF   25  TOR  46  46  35.7   6.2  13.7
# 16  15          Ryan Arcidiacono   PG   28  TOT  14   1   4.9   0.3   1.0
# 17  15          Ryan Arcidiacono   PG   28  NYK  11   0   2.4   0.1   0.5
# 18  15          Ryan Arcidiacono   PG   28  POR   3   1  14.3   1.0   3.0
# 19  16               Deni Avdija   SF   22  WAS  56  32  26.3   3.3   7.5
# 20  17             Deandre Ayton    C   24  PHO  51  51  30.2   8.2  13.7
# 21  18            Udoka Azubuike    C   23  UTA  24   0   5.7   0.9   1.0
# 22  19         Marvin Bagley III    C   23  DET  25  13  21.3   4.3   8.0
# 23  20       Patrick Baldwin Jr.   SF   20  GSW  17   0   8.2   1.8   4.0
# 24  Rk                    Player  Pos  Age   Tm   G  GS    MP    FG   FGA
# 25  21               LaMelo Ball   PG   21  CHO  33  33  35.4   8.3  20.3
# 26  22                  Mo Bamba    C   24  TOT  42   6  17.1   2.6   5.4
# 27  22                  Mo Bamba    C   24  ORL  40   6  17.0   2.7   5.4
# 28  22                  Mo Bamba    C   24  LAL   2   0  19.0   2.0   6.0
# 29  23            Paolo Banchero   PF   20  ORL  53  53  33.7   6.5  15.5
#
#     ...   FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0   ...  .697  2.1  4.6   6.7  1.0  0.7  0.7  1.2  2.1  10.3
# 1   ...  .364  5.1  6.5  11.5  2.3  0.9  1.1  1.9  2.3   8.6
# 2   ...  .805  2.7  7.3  10.0  3.3  1.2  0.8  2.5  2.8  21.6
# 3   ...  .611  0.7  1.0   1.7  0.6  0.2  0.1  0.3  1.5   4.8
# 4   ...  .729  1.0  3.6   4.6  1.2  0.7  0.7  0.7  1.9   9.5
# 5   ...  .692  0.2  1.4   1.6  2.0  0.6  0.4  1.2  1.5   6.1
# 6   ...  .692  0.2  1.4   1.6  2.1  0.7  0.4  1.3  1.6   6.3
# 7   ...   NaN  0.0  0.5   0.5  0.0  0.0  0.0  0.5  0.0   1.0
# 8   ...  .904  0.9  2.6   3.4  2.4  0.8  0.2  1.1  1.6  10.5
# 9   ...  .720  3.2  6.7   9.9  1.7  0.8  1.2  1.5  2.3  14.7
# 10  ...  .813  0.4  1.9   2.3  3.1  1.1  0.2  1.4  2.1   9.1
# 11  ...  .779  0.8  3.9   4.7  4.1  1.2  0.8  1.4  2.1   8.6
# 12  ...  .646  2.3  9.9  12.2  5.4  0.8  0.8  4.0  3.4  31.8
# 13  ...  .500  0.3  0.7   1.0  0.2  0.1  0.1  0.3  0.5   0.5
# 14  ...  .886  0.6  4.0   4.6  4.1  0.6  0.6  1.5  2.5  12.1
# 15  ...  .822  1.5  4.0   5.5  2.0  2.1  0.8  2.2  3.0  16.8
# 16  ...   NaN  0.0  0.7   0.7  0.6  0.1  0.0  0.2  0.4   0.9
# 17  ...   NaN  0.0  0.4   0.4  0.2  0.2  0.0  0.1  0.3   0.3
# 18  ...   NaN  0.0  2.0   2.0  2.0  0.0  0.0  0.7  1.0   3.0
# 19  ...  .752  1.1  5.2   6.3  2.5  0.9  0.5  1.4  2.9   9.1
# 20  ...  .736  2.8  7.3  10.1  2.0  0.6  0.7  1.9  2.8  18.7
# 21  ...  .333  0.5  1.5   2.1  0.3  0.1  0.3  0.4  0.5   1.8
# 22  ...  .769  2.1  3.8   5.9  0.6  0.5  0.7  0.9  2.0  10.6
# 23  ...  .667  0.0  1.4   1.4  0.2  0.4  0.1  0.4  0.4   5.4
# 24  ...   FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 25  ...  .856  1.2  5.1   6.3  8.4  1.3  0.3  3.5  3.4  23.3
# 26  ...  .661  1.1  3.7   4.8  1.0  0.3  1.0  0.6  2.3   7.2
# 27  ...  .686  1.2  3.4   4.6  1.1  0.3  1.0  0.6  2.2   7.3
# 28  ...  .500  0.5  9.0   9.5  1.0  0.0  1.5  1.5  5.0   7.0
# 29  ...  .751  1.2  5.5   6.6  3.6  0.9  0.5  2.7  2.2  19.7
#
# [30 rows x 30 columns]

# %%
nba.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %% [markdown]
# ###### Importing Advanced Stats ######

# %%
html_url = "https://www.basketball-reference.com/leagues/NBA_2023_advanced.html"
advanced_tables = pd.read_html(html_url)
len(advanced_tables)
advanced = advanced_tables[0]
advanced.head(30)
# Out:
#     Rk                    Player  Pos  Age   Tm   G    MP   PER   TS%  3PAr  \
# 0    1          Precious Achiuwa    C   23  TOR  36   847  15.3  .553  .259
# 1    2              Steven Adams    C   29  MEM  42  1133  17.6  .564  .004
# 2    3               Bam Adebayo    C   25  MIA  54  1909  21.2  .594  .013
# 3    4              Ochai Agbaji   SG   22  UTA  38   579   8.8  .608  .610
# 4    5              Santi Aldama   PF   22  MEM  55  1209  14.7  .602  .528
# 5    6  Nickeil Alexander-Walker   SG   24  TOT  38   534  13.1  .608  .506
# 6    6  Nickeil Alexander-Walker   SG   24  UTA  36   528  13.2  .609  .512
# 7    6  Nickeil Alexander-Walker   SG   24  MIN   2     6  -0.4  .500  .000
# 8    7             Grayson Allen   SG   27  MIL  54  1491  12.6  .618  .636
# 9    8             Jarrett Allen    C   24  CLE  55  1827  20.1  .677  .015
# 10   9             Jose Alvarado   PG   24  NOP  59  1279  11.9  .526  .507
# 11  10             Kyle Anderson   PF   29  MIN  48  1253  14.7  .596  .227
# 12  11     Giannis Antetokounmpo   PF   28  MIL  47  1554  28.4  .595  .143
# 13  12    Thanasis Antetokounmpo   SF   30  MIL  25   101   1.2  .266  .211
# 14  13              Cole Anthony   PG   22  ORL  40   995  15.9  .560  .340
# 15  14                OG Anunoby   SF   25  TOR  46  1644  14.2  .560  .386
# 16  15          Ryan Arcidiacono   PG   28  TOT  14    69   4.6  .429  .643
# 17  15          Ryan Arcidiacono   PG   28  NYK  11    26   3.2  .300  .600
# 18  15          Ryan Arcidiacono   PG   28  POR   3    43   5.5  .500  .667
# 19  16               Deni Avdija   SF   22  WAS  56  1472  11.5  .536  .406
# 20  17             Deandre Ayton    C   24  PHO  51  1540  21.2  .620  .033
# 21  18            Udoka Azubuike    C   23  UTA  24   137  16.3  .826  .000
# 22  19         Marvin Bagley III    C   23  DET  25   532  17.4  .592  .164
# 23  20       Patrick Baldwin Jr.   SF   20  GSW  17   139  16.1  .644  .794
# 24  Rk                    Player  Pos  Age   Tm   G    MP   PER   TS%  3PAr
# 25  21               LaMelo Ball   PG   21  CHO  33  1167  18.0  .536  .525
# 26  22                  Mo Bamba    C   24  TOT  42   719  16.1  .603  .518
# 27  22                  Mo Bamba    C   24  ORL  40   681  16.5  .613  .505
# 28  22                  Mo Bamba    C   24  LAL   2    38   7.6  .451  .750
# 29  23            Paolo Banchero   PF   20  ORL  53  1786  14.9  .525  .266
#
#     ... Unnamed: 19   OWS  DWS    WS   WS/48 Unnamed: 24   OBPM  DBPM    BPM  \
# 0   ...         NaN   0.7  1.0   1.6    .093         NaN   -1.5  -0.9   -2.4
# 1   ...         NaN   1.3  2.1   3.4    .145         NaN   -0.3   0.9    0.6
# 2   ...         NaN   3.0  3.2   6.2    .156         NaN    1.3   1.1    2.3
# 3   ...         NaN   0.7  0.1   0.8    .069         NaN   -1.4  -1.4   -2.8
# 4   ...         NaN   1.8  1.9   3.7    .146         NaN    0.1   1.2    1.4
# 5   ...         NaN   0.3  0.5   0.8    .072         NaN   -0.6   1.0    0.4
# 6   ...         NaN   0.4  0.5   0.8    .076         NaN   -0.5   1.0    0.5
# 7   ...         NaN   0.0  0.0   0.0  -0.213         NaN  -10.0  -3.0  -13.0
# 8   ...         NaN   2.3  1.8   4.1    .130         NaN   -0.5   0.7    0.2
# 9   ...         NaN   4.5  3.3   7.8    .205         NaN    1.4   1.0    2.4
# 10  ...         NaN   0.2  1.5   1.7    .065         NaN   -1.9   0.6   -1.3
# 11  ...         NaN   1.6  1.7   3.3    .127         NaN    0.0   2.4    2.4
# 12  ...         NaN   3.5  2.9   6.4    .197         NaN    5.4   2.5    7.9
# 13  ...         NaN  -0.3  0.1  -0.1  -0.066         NaN   -9.6  -1.0  -10.5
# 14  ...         NaN   1.3  1.1   2.3    .113         NaN    0.8   0.7    1.5
# 15  ...         NaN   0.5  2.0   2.5    .074         NaN   -0.9   0.6   -0.3
# 16  ...         NaN   0.0  0.1   0.0    .003         NaN   -6.7  -0.8   -7.5
# 17  ...         NaN   0.0  0.0   0.0  -0.010         NaN   -9.0   3.8   -5.3
# 18  ...         NaN   0.0  0.0   0.0    .012         NaN   -5.3  -3.6   -8.9
# 19  ...         NaN   0.3  1.8   2.1    .069         NaN   -2.6   0.7   -2.0
# 20  ...         NaN   2.8  2.2   5.0    .156         NaN    1.7  -0.1    1.7
# 21  ...         NaN   0.2  0.2   0.4    .125         NaN   -0.8   0.7   -0.1
# 22  ...         NaN   0.8  0.4   1.1    .104         NaN    0.1  -1.0   -0.9
# 23  ...         NaN   0.1  0.2   0.2    .074         NaN    3.2  -0.9    2.3
# 24  ...         NaN   OWS  DWS    WS   WS/48         NaN   OBPM  DBPM    BPM
# 25  ...         NaN   0.7  1.0   1.6    .067         NaN    3.1  -1.1    1.9
# 26  ...         NaN   1.1  1.0   2.1    .143         NaN    0.0   0.8    0.9
# 27  ...         NaN   1.2  0.9   2.1    .151         NaN    0.5   0.8    1.4
# 28  ...         NaN  -0.1  0.1   0.0  -0.008         NaN   -8.9   1.2   -7.7
# 29  ...         NaN  -0.2  1.9   1.7    .046         NaN   -0.8  -0.8   -1.6
#
#     VORP
# 0   -0.1
# 1    0.7
# 2    2.1
# 3   -0.1
# 4    1.0
# 5    0.3
# 6    0.3
# 7    0.0
# 8    0.8
# 9    2.0
# 10   0.2
# 11   1.4
# 12   3.9
# 13  -0.2
# 14   0.9
# 15   0.7
# 16  -0.1
# 17   0.0
# 18  -0.1
# 19   0.0
# 20   1.4
# 21   0.1
# 22   0.1
# 23   0.2
# 24  VORP
# 25   1.2
# 26   0.5
# 27   0.6
# 28  -0.1
# 29   0.2
#
# [30 rows x 29 columns]

# %%
advanced.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr',
#        'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
#        'Unnamed: 19', 'OWS', 'DWS', 'WS', 'WS/48', 'Unnamed: 24', 'OBPM',
#        'DBPM', 'BPM', 'VORP'],
#       dtype='object')

# %% [markdown]
# #### Cleaning DataFrame ####

# %% [markdown]
# ###### Cleaning Normal Stats ######

# %%
#renames columns to strings only#
nba.rename(
    columns={
        'FG%': 'FGP',
        '3P': 'TP',
        '3PA': 'TPA',
        '3P%': 'TPP',
        '2P': 'TWOP',
        '2PA': 'TWOPA',
        '2P%': 'TWOPP',
        'eFG%': 'eFGP',
        'FT%': 'FTP'
    }, inplace=True)

#removing duplicate players (stats of players that played on different teams)#
nba.drop_duplicates(subset=['Player'], keep=False, inplace=True)
#Dropping "Rk" Column#
nba.drop('Rk', axis=1, inplace=True)

#replacing NaN with 0#
nba.fillna(0, inplace=True)

nba[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]] = nba[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]].apply(pd.to_numeric)
nba
# Out:
#                  Player Pos Age   Tm   G  GS    MP   FG   FGA    FGP  ...  \
# 0      Precious Achiuwa   C  23  TOR  36  11  23.5  3.9   8.1  0.485  ...
# 1          Steven Adams   C  29  MEM  42  42  27.0  3.7   6.3  0.597  ...
# 2           Bam Adebayo   C  25  MIA  54  54  35.4  8.5  15.7  0.544  ...
# 3          Ochai Agbaji  SG  22  UTA  38   2  15.2  1.8   3.7  0.482  ...
# 4          Santi Aldama  PF  22  MEM  55  18  22.0  3.3   7.0  0.477  ...
# ..                  ...  ..  ..  ...  ..  ..   ...  ...   ...    ...  ...
# 627        Delon Wright  PG  30  WAS  29   2  22.5  2.3   5.2  0.440  ...
# 628  McKinley Wright IV  PG  24  DAL  20   1  10.3  1.2   2.5  0.469  ...
# 629      Thaddeus Young  PF  34  TOR  47   9  16.0  2.2   3.9  0.562  ...
# 630          Trae Young  PG  24  ATL  52  52  35.4  8.4  19.7  0.428  ...
# 631         Ivica Zubac   C  25  LAC  59  59  29.4  4.0   6.5  0.617  ...
#
#        FTP  ORB  DRB   TRB   AST  STL  BLK  TOV   PF   PTS
# 0    0.697  2.1  4.6   6.7   1.0  0.7  0.7  1.2  2.1  10.3
# 1    0.364  5.1  6.5  11.5   2.3  0.9  1.1  1.9  2.3   8.6
# 2    0.805  2.7  7.3  10.0   3.3  1.2  0.8  2.5  2.8  21.6
# 3    0.611  0.7  1.0   1.7   0.6  0.2  0.1  0.3  1.5   4.8
# 4    0.729  1.0  3.6   4.6   1.2  0.7  0.7  0.7  1.9   9.5
# ..     ...  ...  ...   ...   ...  ...  ...  ...  ...   ...
# 627  0.903  1.0  2.2   3.2   3.7  2.0  0.3  1.0  1.4   6.2
# 628  0.636  0.3  1.0   1.3   1.9  0.4  0.2  0.6  0.9   2.9
# 629  0.692  1.4  1.9   3.3   1.5  1.1  0.1  0.8  1.8   4.9
# 630  0.885  0.7  2.2   2.9  10.3  1.0  0.2  4.1  1.5  26.7
# 631  0.699  3.3  6.8  10.1   1.1  0.4  1.3  1.7  2.9  10.2
#
# [457 rows x 29 columns]

# %% [markdown]
# ###### Cleaning Advanced Stats ######

# %%
advanced.rename(
    columns={
        'WS': 'Win Shares',
        'BPM': 'Avg. Box +/-'
    }, inplace=True)

#removing duplicate players (stats of players that played on different teams)#
advanced.drop_duplicates(subset=['Player'], keep=False, inplace=True)
#Dropping "Rk" Column#
advanced.drop('Rk', axis=1, inplace=True)

#replacing NaN with 0#
advanced.fillna(0, inplace=True)

advanced[['Age', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr','ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%','Unnamed: 19', 'OWS', 'DWS', 'Win Shares', 'WS/48', 'Unnamed: 24', 'OBPM','DBPM', 'Avg. Box +/-', 'VORP']] = advanced[['Age', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr','ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%','Unnamed: 19', 'OWS', 'DWS', 'Win Shares', 'WS/48', 'Unnamed: 24', 'OBPM','DBPM', 'Avg. Box +/-', 'VORP']].apply(pd.to_numeric)
advanced.drop(['Player','Pos','Age','Tm','G','MP','3PAr','FTr','ORB%','DRB%','TRB%','AST%','STL%','BLK%','TOV%','USG%','OWS','DWS','WS/48','OBPM','DBPM','TS%','VORP','Unnamed: 19','Unnamed: 24'], axis=1, inplace=True)
shorter_advanced = advanced
shorter_advanced
# Out:
#       PER  Win Shares  Avg. Box +/-
# 0    15.3         1.6          -2.4
# 1    17.6         3.4           0.6
# 2    21.2         6.2           2.3
# 3     8.8         0.8          -2.8
# 4    14.7         3.7           1.4
# ..    ...         ...           ...
# 627  15.4         1.8           3.1
# 628  11.5         0.3          -2.9
# 629  14.7         1.8           0.4
# 630  21.9         4.6           3.3
# 631  15.8         5.0          -1.5
#
# [457 rows x 3 columns]

# %%
nba = nba.loc[~nba.index.duplicated(keep='first')]
shorter_advanced = shorter_advanced.loc[~shorter_advanced.index.duplicated(keep='first')]
full = pd.concat([nba, shorter_advanced], axis=1)
full
# Out:
#                  Player Pos Age   Tm   G  GS    MP   FG   FGA    FGP  ...  \
# 0      Precious Achiuwa   C  23  TOR  36  11  23.5  3.9   8.1  0.485  ...
# 1          Steven Adams   C  29  MEM  42  42  27.0  3.7   6.3  0.597  ...
# 2           Bam Adebayo   C  25  MIA  54  54  35.4  8.5  15.7  0.544  ...
# 3          Ochai Agbaji  SG  22  UTA  38   2  15.2  1.8   3.7  0.482  ...
# 4          Santi Aldama  PF  22  MEM  55  18  22.0  3.3   7.0  0.477  ...
# ..                  ...  ..  ..  ...  ..  ..   ...  ...   ...    ...  ...
# 627        Delon Wright  PG  30  WAS  29   2  22.5  2.3   5.2  0.440  ...
# 628  McKinley Wright IV  PG  24  DAL  20   1  10.3  1.2   2.5  0.469  ...
# 629      Thaddeus Young  PF  34  TOR  47   9  16.0  2.2   3.9  0.562  ...
# 630          Trae Young  PG  24  ATL  52  52  35.4  8.4  19.7  0.428  ...
# 631         Ivica Zubac   C  25  LAC  59  59  29.4  4.0   6.5  0.617  ...
#
#       TRB   AST  STL  BLK  TOV   PF   PTS   PER  Win Shares  Avg. Box +/-
# 0     6.7   1.0  0.7  0.7  1.2  2.1  10.3  15.3         1.6          -2.4
# 1    11.5   2.3  0.9  1.1  1.9  2.3   8.6  17.6         3.4           0.6
# 2    10.0   3.3  1.2  0.8  2.5  2.8  21.6  21.2         6.2           2.3
# 3     1.7   0.6  0.2  0.1  0.3  1.5   4.8   8.8         0.8          -2.8
# 4     4.6   1.2  0.7  0.7  0.7  1.9   9.5  14.7         3.7           1.4
# ..    ...   ...  ...  ...  ...  ...   ...   ...         ...           ...
# 627   3.2   3.7  2.0  0.3  1.0  1.4   6.2  15.4         1.8           3.1
# 628   1.3   1.9  0.4  0.2  0.6  0.9   2.9  11.5         0.3          -2.9
# 629   3.3   1.5  1.1  0.1  0.8  1.8   4.9  14.7         1.8           0.4
# 630   2.9  10.3  1.0  0.2  4.1  1.5  26.7  21.9         4.6           3.3
# 631  10.1   1.1  0.4  1.3  1.7  2.9  10.2  15.8         5.0          -1.5
#
# [457 rows x 32 columns]

# %%
full['Conf'] = full['Tm'].apply(lambda x: 'West' if x in ['DAL','DEN','GSW','HOU','LAC','LAL','MEM','MIN','NOP','OKC','PHO','POR','SAC','SAS','UTA'] else 'East')
full
# Out:
#                  Player Pos Age   Tm   G  GS    MP   FG   FGA    FGP  ...  \
# 0      Precious Achiuwa   C  23  TOR  36  11  23.5  3.9   8.1  0.485  ...
# 1          Steven Adams   C  29  MEM  42  42  27.0  3.7   6.3  0.597  ...
# 2           Bam Adebayo   C  25  MIA  54  54  35.4  8.5  15.7  0.544  ...
# 3          Ochai Agbaji  SG  22  UTA  38   2  15.2  1.8   3.7  0.482  ...
# 4          Santi Aldama  PF  22  MEM  55  18  22.0  3.3   7.0  0.477  ...
# ..                  ...  ..  ..  ...  ..  ..   ...  ...   ...    ...  ...
# 627        Delon Wright  PG  30  WAS  29   2  22.5  2.3   5.2  0.440  ...
# 628  McKinley Wright IV  PG  24  DAL  20   1  10.3  1.2   2.5  0.469  ...
# 629      Thaddeus Young  PF  34  TOR  47   9  16.0  2.2   3.9  0.562  ...
# 630          Trae Young  PG  24  ATL  52  52  35.4  8.4  19.7  0.428  ...
# 631         Ivica Zubac   C  25  LAC  59  59  29.4  4.0   6.5  0.617  ...
#
#       AST  STL  BLK  TOV   PF   PTS   PER  Win Shares  Avg. Box +/-  Conf
# 0     1.0  0.7  0.7  1.2  2.1  10.3  15.3         1.6          -2.4  East
# 1     2.3  0.9  1.1  1.9  2.3   8.6  17.6         3.4           0.6  West
# 2     3.3  1.2  0.8  2.5  2.8  21.6  21.2         6.2           2.3  East
# 3     0.6  0.2  0.1  0.3  1.5   4.8   8.8         0.8          -2.8  West
# 4     1.2  0.7  0.7  0.7  1.9   9.5  14.7         3.7           1.4  West
# ..    ...  ...  ...  ...  ...   ...   ...         ...           ...   ...
# 627   3.7  2.0  0.3  1.0  1.4   6.2  15.4         1.8           3.1  East
# 628   1.9  0.4  0.2  0.6  0.9   2.9  11.5         0.3          -2.9  West
# 629   1.5  1.1  0.1  0.8  1.8   4.9  14.7         1.8           0.4  East
# 630  10.3  1.0  0.2  4.1  1.5  26.7  21.9         4.6           3.3  East
# 631   1.1  0.4  1.3  1.7  2.9  10.2  15.8         5.0          -1.5  West
#
# [457 rows x 33 columns]

# %% [markdown]
# #### Filtering DataFrame ####

# %% [markdown]
# ###### Filtering Normal Stats ######

# %%
full.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FGP', 'TP',
#        'TPA', 'TPP', 'TWOP', 'TWOPA', 'TWOPP', 'eFGP', 'FT', 'FTA', 'FTP',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'PER',
#        'Win Shares', 'Avg. Box +/-', 'Conf'],
#       dtype='object')

# %%
full[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]] = nba[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]].apply(pd.to_numeric)

# %%
full.drop(full[full['G'] <= 10].index, inplace = True)
full.drop(full[full['TP'] <= 0.1].index, inplace = True)
full.drop(full[full['TPA'] <= 0.1].index, inplace = True)
full.drop(full[full['TPP'] <= 0.1].index, inplace = True)
full.drop(full[full['PTS'] <= 14].index, inplace = True)

# %%
west = full[full["Conf"].str.contains("West")]
east = full[full["Conf"].str.contains("East")]

# %%
west[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]] = west[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]].apply(pd.to_numeric)
# Out:
# C:\Users\MK Nguyen\AppData\Local\Temp\ipykernel_24468\2250643581.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   west[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]] = west[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]].apply(pd.to_numeric)

# %%
east[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]] = east[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]].apply(pd.to_numeric)
# Out:
# C:\Users\MK Nguyen\AppData\Local\Temp\ipykernel_24468\3641391594.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   east[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]] = east[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]].apply(pd.to_numeric)

# %% [markdown]
# #### Processing the Data ####

# %%
for index, row in full.iterrows():
    west.loc[index, "Score"] = (((row['FGP']*row['TPP']*row['FTP'])*(row['PTS']+row['TRB']+row['STL']+row['AST']+row['BLK']-row['TOV']-(row['FGA']-row['FG']))*(1-row['eFGP']))*(row['PTS']+row['TRB']+row['STL']+(0.5*row['AST'])+(0.5*row['BLK'])-row['FGA']-row['TOV']-(0.5*row['FTA'])-(0.5*row['PF'])))
# Out:
# C:\Users\MK Nguyen\AppData\Local\Temp\ipykernel_24468\2752619839.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   west.loc[index, "Score"] = (((row['FGP']*row['TPP']*row['FTP'])*(row['PTS']+row['TRB']+row['STL']+row['AST']+row['BLK']-row['TOV']-(row['FGA']-row['FG']))*(1-row['eFGP']))*(row['PTS']+row['TRB']+row['STL']+(0.5*row['AST'])+(0.5*row['BLK'])-row['FGA']-row['TOV']-(0.5*row['FTA'])-(0.5*row['PF'])))

# %%
west.sort_values(by=['Score'], ascending=False, inplace=True)
west.drop(['GS','MP','FG','FGA','TP','TPA','TWOP','TWOPA','TWOPP','eFGP','FT','FTA','FTP','ORB','DRB','STL','BLK','TOV','PF','Avg. Box +/-'], axis=1, inplace=True)
west['Advanced Score'] = (west['PER']*west['Win Shares'])/100
west['ASG Score'] = round(west['Score']*west['Advanced Score'],2)
west.drop(['Score', 'Advanced Score'], axis=1, inplace=True)
west.sort_values(by=['ASG Score'], ascending=False, inplace=True)
west = west.rename({'FGP': 'FG%', 'TPP': '3P%', 'TRB': 'REB'}, axis='columns')
west = west.dropna()

# %%
for index, row in full.iterrows():
    east.loc[index, "Score"] = (((row['FGP']*row['TPP']*row['FTP'])*(row['PTS']+row['TRB']+row['STL']+row['AST']+row['BLK']-row['TOV']-(row['FGA']-row['FG']))*(1-row['eFGP']))*(row['PTS']+row['TRB']+row['STL']+(0.5*row['AST'])+(0.5*row['BLK'])-row['FGA']-row['TOV']-(0.5*row['FTA'])-(0.5*row['PF'])))
# Out:
# C:\Users\MK Nguyen\AppData\Local\Temp\ipykernel_24468\2937448875.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   east.loc[index, "Score"] = (((row['FGP']*row['TPP']*row['FTP'])*(row['PTS']+row['TRB']+row['STL']+row['AST']+row['BLK']-row['TOV']-(row['FGA']-row['FG']))*(1-row['eFGP']))*(row['PTS']+row['TRB']+row['STL']+(0.5*row['AST'])+(0.5*row['BLK'])-row['FGA']-row['TOV']-(0.5*row['FTA'])-(0.5*row['PF'])))
# C:\Users\MK Nguyen\AppData\Local\Temp\ipykernel_24468\2937448875.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   east.loc[index, "Score"] = (((row['FGP']*row['TPP']*row['FTP'])*(row['PTS']+row['TRB']+row['STL']+row['AST']+row['BLK']-row['TOV']-(row['FGA']-row['FG']))*(1-row['eFGP']))*(row['PTS']+row['TRB']+row['STL']+(0.5*row['AST'])+(0.5*row['BLK'])-row['FGA']-row['TOV']-(0.5*row['FTA'])-(0.5*row['PF'])))

# %%
east.sort_values(by=['Score'], ascending=False, inplace=True)
east.drop(['GS','MP','FG','FGA','TP','TPA','TWOP','TWOPA','TWOPP','eFGP','FT','FTA','FTP','ORB','DRB','STL','BLK','TOV','PF','Avg. Box +/-'], axis=1, inplace=True)
east['Advanced Score'] = (east['PER']*east['Win Shares'])/100
east['ASG Score'] = round(east['Score']*east['Advanced Score'],2)
east.drop(['Score', 'Advanced Score'], axis=1, inplace=True)
east.sort_values(by=['ASG Score'], ascending=False, inplace=True)
east = east.rename({'FGP': 'FG%', 'TPP': '3P%', 'TRB': 'REB'}, axis='columns')
east = east.dropna()

# %%
westpg = west[west['Pos'].str.contains('PG')]
westsg = west[west['Pos'].str.contains('SG')]
westsf = west[west['Pos'].str.contains('SF')]
westpf = west[west['Pos'].str.contains('PF')]
westc = west[west['Pos'].str.contains('C')]

# %%
eastpg = east[east['Pos'].str.contains('PG')]
eastsg = east[east['Pos'].str.contains('SG')]
eastsf = east[east['Pos'].str.contains('SF')]
eastpf = east[east['Pos'].str.contains('PF')]
eastc = east[east['Pos'].str.contains('C')]

# %%
westbc = pd.concat([westpg, westsg], axis=0)
westbc.sort_values(by=['ASG Score'], ascending=False, inplace=True)
westbc.head(15)
# Out:
#                       Player Pos Age   Tm     G    FG%    3P%  REB  AST   PTS  \
# 141              Luka Dončić  PG  23  DAL  51.0  0.505  0.347  8.8  8.2  33.2
# 188  Shai Gilgeous-Alexander  PG  24  OKC  54.0  0.507  0.338  4.7  5.7  31.0
# 348           Damian Lillard  PG  32  POR  46.0  0.467  0.372  4.3  7.3  31.4
# 122            Stephen Curry  PG  34  GSW  38.0  0.495  0.427  6.3  6.4  29.4
# 404                Ja Morant  PG  23  MEM  49.0  0.462  0.318  5.9  8.2  27.1
# 177             De'Aaron Fox  PG  25  SAC  53.0  0.511  0.328  4.3  6.1  24.9
# 185              Paul George  SG  32  LAC  44.0  0.461  0.382  6.1  5.3  23.3
# 30              Desmond Bane  SG  24  MEM  36.0  0.467  0.423  5.0  4.1  21.6
# 60              Devin Booker  SG  26  PHO  33.0  0.476  0.358  4.5  5.5  26.6
# 410             Jamal Murray  PG  25  DEN  46.0  0.457  0.391  4.1  5.9  20.1
# 157          Anthony Edwards  SG  21  MIN  61.0  0.464  0.364  5.9  4.5  24.9
# 378              CJ McCollum  SG  31  NOP  53.0  0.436  0.388  4.3  5.9  21.2
# 187              Josh Giddey  SG  20  OKC  53.0  0.484  0.306  7.8  5.8  16.3
# 468            Norman Powell  SG  29  LAC  50.0  0.486  0.417  3.1  1.8  17.0
# 531          Anfernee Simons  SG  23  POR  56.0  0.450  0.381  2.7  4.2  21.4
#
#       PER  Win Shares  Conf  ASG Score
# 141  30.4         8.9  West      87.12
# 188  27.3         9.2  West      63.02
# 348  26.6         7.7  West      48.25
# 122  24.8         5.4  West      40.07
# 404  23.4         5.2  West      16.69
# 177  21.2         5.3  West      14.29
# 185  19.7         3.7  West      11.01
# 30   19.2         3.7  West       9.79
# 60   21.3         3.4  West       9.51
# 410  18.4         3.8  West       7.59
# 157  17.8         3.5  West       7.38
# 378  16.2         3.0  West       4.15
# 187  16.5         2.4  West       3.95
# 468  18.1         3.4  West       3.57
# 531  15.2         3.1  West       3.06

# %%
westfc = pd.concat([westsf, westpf, westc], axis=0)
westfc.sort_values(by=['ASG Score'], ascending=False, inplace=True)
westfc.head(15)
# Out:
#                  Player Pos Age   Tm     G    FG%    3P%   REB   AST   PTS  \
# 294        Nikola Jokić   C  27  DEN  52.0  0.632  0.402  11.6  10.2  24.7
# 513    Domantas Sabonis   C  26  SAC  56.0  0.610  0.343  12.4   6.9  18.8
# 124       Anthony Davis   C  29  LAL  36.0  0.562  0.250  12.3   2.5  25.6
# 364     Lauri Markkanen  SF  25  UTA  55.0  0.513  0.407   8.6   1.8  25.2
# 282        LeBron James  PF  38  LAL  46.0  0.503  0.310   8.4   7.0  29.6
# 345       Kawhi Leonard  SF  31  LAC  34.0  0.497  0.380   6.2   4.0  22.1
# 620     Zion Williamson  PF  22  NOP  29.0  0.608  0.368   7.0   4.6  26.0
# 193        Aaron Gordon  PF  27  DEN  49.0  0.587  0.397   6.9   2.9  17.3
# 276   Jaren Jackson Jr.   C  23  MEM  41.0  0.496  0.348   6.7   0.9  17.0
# 521      Alperen Şengün   C  20  HOU  53.0  0.562  0.316   8.8   3.7  15.1
# 573   Jonas Valančiūnas   C  30  NOP  59.0  0.544  0.341   9.8   1.7  14.4
# 626      Christian Wood   C  27  DAL  49.0  0.526  0.375   8.0   1.7  17.7
# 568  Karl-Anthony Towns  PF  27  MIN  21.0  0.505  0.325   8.2   5.3  20.8
# 200        Jerami Grant  PF  28  POR  54.0  0.484  0.406   4.3   2.3  20.8
# 33      Harrison Barnes  PF  30  SAC  58.0  0.472  0.375   4.6   1.6  14.9
#
#       PER  Win Shares  Conf  ASG Score
# 294  31.8        11.6  West     209.65
# 513  23.1         8.9  West      65.65
# 124  28.2         5.6  West      44.74
# 364  22.7         7.4  West      43.12
# 282  24.5         5.0  West      27.12
# 345  23.7         4.4  West      21.01
# 620  25.3         3.6  West      19.33
# 193  20.9         5.4  West      14.34
# 276  21.7         4.3  West      11.26
# 521  20.5         4.1  West      11.05
# 573  19.3         4.3  West      11.03
# 626  21.0         3.9  West      10.74
# 568  19.3         2.1  West       7.06
# 200  16.5         4.2  West       6.82
# 33   14.0         4.5  West       4.70

# %%
eastbc = pd.concat([eastpg, eastsg], axis=0)
eastbc.sort_values(by=['ASG Score'], ascending=False, inplace=True)
eastbc.head(15)
# Out:
#                 Player Pos Age   Tm     G    FG%    3P%  REB   AST   PTS  \
# 222       James Harden  PG  33  PHI  42.0  0.456  0.397  6.2  10.7  21.6
# 217  Tyrese Haliburton  PG  22  IND  49.0  0.481  0.398  3.7  10.1  19.9
# 396   Donovan Mitchell  SG  26  CLE  51.0  0.478  0.386  4.0   4.8  27.2
# 82       Jalen Brunson  PG  26  NYK  56.0  0.485  0.411  3.6   6.2  23.9
# 181     Darius Garland  PG  23  CLE  52.0  0.465  0.415  2.7   7.9  21.8
# 630         Trae Young  PG  24  ATL  52.0  0.428  0.324  2.9  10.3  26.7
# 250       Jrue Holiday  PG  32  MIL  47.0  0.462  0.377  5.2   7.1  19.4
# 72     Malcolm Brogdon  PG  30  BOS  51.0  0.488  0.465  4.2   3.8  14.9
# 409    Dejounte Murray  SG  26  ATL  54.0  0.462  0.363  5.5   6.1  20.7
# 336        Zach LaVine  SG  27  CHI  55.0  0.465  0.369  4.9   4.1  24.0
# 41        Bradley Beal  SG  29  WAS  36.0  0.520  0.375  3.5   5.2  23.1
# 577      Fred VanVleet  PG  28  TOR  50.0  0.394  0.344  4.3   6.6  19.7
# 241        Tyler Herro  SG  23  MIA  45.0  0.437  0.369  5.7   4.4  20.6
# 25         LaMelo Ball  PG  21  CHO  33.0  0.408  0.365  6.3   8.4  23.3
# 569     Gary Trent Jr.  SG  24  TOR  51.0  0.441  0.369  2.5   1.6  18.6
#
#       PER  Win Shares  Conf  ASG Score
# 222  22.7         6.6  East      37.73
# 217  22.8         6.3  East      28.43
# 396  22.8         6.8  East      24.15
# 82   21.4         7.3  East      22.48
# 181  19.6         6.2  East      14.95
# 630  21.9         4.6  East      11.42
# 250  18.7         4.4  East      10.44
# 72   18.8         4.4  East       8.51
# 409  17.4         3.6  East       8.16
# 336  17.6         4.1  East       7.98
# 41   20.8         3.1  East       7.77
# 577  16.9         4.6  East       7.52
# 241  15.7         2.6  East       4.40
# 25   18.0         1.6  East       3.53
# 569  15.4         3.8  East       3.16

# %%
eastbc = pd.concat([eastsf, eastpf, eastc], axis=0)
eastbc.sort_values(by=['ASG Score'], ascending=False, inplace=True)
eastbc.head(15)
# Out:
#                     Player Pos Age   Tm     G    FG%    3P%   REB  AST   PTS  \
# 162            Joel Embiid   C  28  PHI  46.0  0.530  0.342  10.3  4.1  33.0
# 550           Jayson Tatum  PF  24  BOS  56.0  0.462  0.355   8.7  4.6  30.6
# 154           Kevin Durant  PF  34  BRK  39.0  0.559  0.376   6.7  5.3  29.7
# 12   Giannis Antetokounmpo  PF  28  MIL  47.0  0.538  0.270  12.2  5.4  31.8
# 89            Jimmy Butler  SF  33  MIA  44.0  0.507  0.303   6.0  5.1  21.7
# 465     Kristaps Porziņģis   C  27  WAS  50.0  0.487  0.370   8.6  2.5  22.8
# 582         Nikola Vučević   C  32  CHI  59.0  0.516  0.356  11.5  3.4  17.9
# 477          Julius Randle  PF  28  NYK  60.0  0.460  0.338  10.8  4.1  24.8
# 526          Pascal Siakam   C  28  TOR  50.0  0.480  0.340   7.7  6.1  25.3
# 131          DeMar DeRozan  SF  33  CHI  53.0  0.507  0.318   4.7  5.1  25.4
# 571           Myles Turner   C  26  IND  51.0  0.543  0.400   8.0  1.3  18.0
# 464           Bobby Portis  PF  27  MIL  47.0  0.499  0.341  10.1  1.8  14.4
# 398            Evan Mobley  PF  21  CLE  60.0  0.554  0.211   8.9  2.7  16.0
# 77            Jaylen Brown  SF  26  BOS  49.0  0.486  0.334   7.1  3.2  26.6
# 354            Brook Lopez   C  34  MIL  57.0  0.507  0.374   6.5  1.2  14.5
#
#       PER  Win Shares  Conf  ASG Score
# 162  30.4         8.1  East      99.05
# 550  24.0         8.0  East      52.27
# 154  26.5         5.9  East      52.24
# 12   28.4         6.4  East      41.34
# 89   25.4         7.5  East      37.23
# 465  22.7         6.0  East      28.53
# 582  19.3         6.0  East      27.15
# 477  20.8         6.8  East      27.13
# 526  20.9         5.6  East      20.38
# 131  20.7         5.9  East      18.29
# 571  20.3         4.9  East      16.86
# 464  18.6         3.9  East      10.05
# 398  17.4         6.2  East       9.26
# 77   19.2         3.6  East       9.04
# 354  17.1         5.4  East       8.78
