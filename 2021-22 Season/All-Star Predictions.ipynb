# %% [markdown]
# # All-Star Predictions #

# %%
# -*- coding: utf-8 -*-#
"""
Created by MinhKhang Nguyen
July 27 2021 7:37 PM - August 6 2021 2:08 AM
"""

# %%
import pandas as pd 
import random as rnd
import numpy as np
import matplotlib.pyplot as plt

# %%
import ssl
ssl._create_default_https_econtext = ssl._create_unverified_context

# %% [markdown]
# #### Importing Data ####

# %% [markdown]
# ###### Importing Normal Stats ######

# %%
html_url = "https://www.basketball-reference.com/leagues/NBA_2022_per_game.html"
nba_tables = pd.read_html(html_url)
len(nba_tables)
nba = nba_tables[0]
nba.head(30)
# Out:
#     Rk                    Player  Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0    1          Precious Achiuwa    C   22  TOR  22  17  26.3  3.6   8.9  ...
# 1    2              Steven Adams    C   28  MEM  35  35  25.5  2.6   5.0  ...
# 2    3               Bam Adebayo    C   24  MIA  18  18  32.9  7.0  13.5  ...
# 3    4              Santi Aldama   PF   21  MEM  16   0   9.8  1.5   4.1  ...
# 4    5         LaMarcus Aldridge    C   36  BRK  25   8  23.6  6.0  10.4  ...
# 5    6  Nickeil Alexander-Walker   SG   23  NOP  32  18  28.2  5.2  13.9  ...
# 6    7             Grayson Allen   SG   26  MIL  33  32  28.5  4.2   9.8  ...
# 7    8             Jarrett Allen    C   23  CLE  28  28  32.6  6.8   9.7  ...
# 8    9             Jose Alvarado   PG   23  NOP   8   0   5.1  0.6   1.6  ...
# 9   10           Justin Anderson    G   28  CLE   3   0  15.7  1.3   2.7  ...
# 10  11             Kyle Anderson   PF   28  MEM  31   3  22.1  3.2   7.4  ...
# 11  12     Giannis Antetokounmpo   PF   27  MIL  28  28  32.4  9.7  18.3  ...
# 12  13    Thanasis Antetokounmpo   SF   29  MIL  25   5  12.6  1.4   3.0  ...
# 13  14           Carmelo Anthony   PF   37  LAL  35   3  27.4  4.6  10.7  ...
# 14  15              Cole Anthony   PG   21  ORL  24  24  34.2  6.9  16.5  ...
# 15  16                OG Anunoby   SF   24  TOR  16  16  36.8  7.3  17.1  ...
# 16  17              Trevor Ariza   SF   36  LAL   2   0  18.0  2.5   2.5  ...
# 17  18             D.J. Augustin   PG   34  HOU  29   2  14.9  1.7   3.9  ...
# 18  19               Deni Avdija   SF   21  WAS  34   3  22.4  2.6   5.8  ...
# 19  20                Joel Ayayi   SG   21  WAS   6   0   2.8  0.2   0.8  ...
# 20  Rk                    Player  Pos  Age   Tm   G  GS    MP   FG   FGA  ...
# 21  21             Deandre Ayton    C   23  PHO  24  24  30.7  7.5  12.0  ...
# 22  22            Udoka Azubuike    C   22  UTA   4   0   2.0  0.3   0.3  ...
# 23  23         Marvin Bagley III   PF   22  SAC  15   2  19.5  3.0   6.6  ...
# 24  24               LaMelo Ball   PG   20  CHO  29  29  32.2  7.1  16.8  ...
# 25  25                Lonzo Ball   PG   24  CHI  29  29  35.6  4.8  11.4  ...
# 26  26                  Mo Bamba    C   23  ORL  27  27  28.7  4.2   9.1  ...
# 27  27              Desmond Bane   SF   23  MEM  35  35  29.5  6.5  13.9  ...
# 28  28             Dalano Banton   SF   22  TOR  28   1  13.0  1.7   3.9  ...
# 29  29                Cat Barber    G   27  ATL   2   0   3.0  0.0   1.0  ...
#
#      FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0   .528  2.2  5.9   8.1  1.5  0.5  0.5  1.1  2.5   8.4
# 1   .627  4.1  5.0   9.1  2.9  0.9  0.5  1.7  1.7   7.1
# 2   .759  2.7  7.4  10.2  3.2  1.1  0.3  2.9  3.3  18.7
# 3   .583  1.0  1.6   2.6  0.8  0.1  0.2  0.3  1.1   3.6
# 4   .833  1.4  4.3   5.7  0.9  0.4  1.2  0.8  1.7  14.0
# 5   .737  1.0  2.8   3.8  2.7  1.0  0.3  1.6  1.8  13.8
# 6   .872  0.4  3.0   3.4  1.3  0.8  0.4  0.7  1.5  12.2
# 7   .719  3.3  7.5  10.8  2.0  0.9  1.4  2.0  1.9  16.8
# 8   .667  0.3  0.4   0.6  1.1  0.5  0.0  0.1  0.4   1.8
# 9   .750  0.0  2.0   2.0  2.0  0.3  0.0  0.7  1.3   4.3
# 10  .647  0.9  4.5   5.4  2.5  1.1  0.6  1.0  1.5   8.2
# 11  .681  2.0  9.4  11.4  5.8  1.0  1.6  3.2  3.1  27.4
# 12  .591  1.1  1.9   3.0  0.8  0.5  0.2  0.7  1.9   3.4
# 13  .795  0.9  3.5   4.3  1.0  0.8  0.8  0.9  2.3  13.5
# 14  .876  0.5  5.5   6.0  5.8  0.8  0.2  2.9  2.5  20.0
# 15  .810  1.5  3.8   5.3  2.7  1.5  0.6  1.6  2.8  19.3
# 16  .500  0.0  3.0   3.0  1.0  0.5  0.0  0.0  1.0   7.5
# 17  .906  0.2  0.9   1.1  2.3  0.3  0.0  1.3  0.6   5.4
# 18  .667  0.8  4.2   5.0  1.4  0.7  0.8  0.9  2.2   7.1
# 19   NaN  0.2  0.3   0.5  0.7  0.0  0.0  0.0  0.0   0.3
# 20   FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 21  .662  2.9  8.2  11.1  1.6  0.8  0.8  1.8  2.2  17.0
# 22   NaN  0.3  0.8   1.0  0.0  0.0  0.0  0.3  0.0   0.5
# 23  .667  2.1  4.6   6.7  0.7  0.1  0.3  0.5  1.3   7.8
# 24  .916  1.6  5.8   7.4  8.0  1.9  0.4  3.1  3.2  19.7
# 25  .773  1.0  4.4   5.4  5.0  1.8  1.0  2.4  2.4  13.2
# 26  .720  2.3  6.3   8.6  1.7  0.8  2.2  1.4  2.6  10.3
# 27  .935  0.5  3.9   4.3  2.2  1.0  0.4  1.4  2.5  17.2
# 28  .750  0.7  1.7   2.4  1.9  0.4  0.2  1.1  1.4   4.3
# 29   NaN  0.0  0.5   0.5  1.0  0.0  0.0  0.5  0.0   0.0
#
# [30 rows x 30 columns]

# %%
nba.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %% [markdown]
# ###### Importing Advanced Stats ######

# %%
html_url = "https://www.basketball-reference.com/leagues/NBA_2022_advanced.html"
advanced_tables = pd.read_html(html_url)
len(advanced_tables)
advanced = advanced_tables[0]
advanced.head(30)
# Out:
#     Rk                    Player  Pos  Age   Tm   G    MP   PER    TS%  3PAr  \
# 0    1          Precious Achiuwa    C   22  TOR  22   579  10.7   .437  .143
# 1    2              Steven Adams    C   28  MEM  35   891  17.4   .567  .000
# 2    3               Bam Adebayo    C   24  MIA  18   592  19.5   .577  .004
# 3    4              Santi Aldama   PF   21  MEM  16   156  10.2   .407  .409
# 4    5         LaMarcus Aldridge    C   36  BRK  25   590  21.4   .621  .115
# 5    6  Nickeil Alexander-Walker   SG   23  NOP  32   902  11.5   .470  .484
# 6    7             Grayson Allen   SG   26  MIL  33   942  13.1   .587  .702
# 7    8             Jarrett Allen    C   23  CLE  28   913  24.1   .723  .022
# 8    9             Jose Alvarado   PG   23  NOP   8    41  18.5   .489  .385
# 9   10           Justin Anderson    G   28  CLE   3    47  10.9   .666  .750
# 10  11             Kyle Anderson   PF   28  MEM  31   684  14.9   .509  .285
# 11  12     Giannis Antetokounmpo   PF   27  MIL  28   908  30.8   .601  .207
# 12  13    Thanasis Antetokounmpo   SF   29  MIL  25   316  10.0   .502  .118
# 13  14           Carmelo Anthony   PF   37  LAL  35   960  14.6   .573  .565
# 14  15              Cole Anthony   PG   21  ORL  24   821  16.7   .547  .458
# 15  16                OG Anunoby   SF   24  TOR  16   588  15.9   .530  .421
# 16  17              Trevor Ariza   SF   36  LAL   2    36  20.8  1.276  .800
# 17  18             D.J. Augustin   PG   34  HOU  29   433  11.1   .617  .702
# 18  19               Deni Avdija   SF   21  WAS  34   761  12.5   .550  .462
# 19  20                Joel Ayayi   SG   21  WAS   6    17   6.7   .200  .000
# 20  Rk                    Player  Pos  Age   Tm   G    MP   PER    TS%  3PAr
# 21  21             Deandre Ayton    C   23  PHO  24   737  22.2   .640  .024
# 22  22            Udoka Azubuike    C   22  UTA   4     8  12.9  1.000  .000
# 23  23         Marvin Bagley III   PF   22  SAC  15   293  15.0   .528  .333
# 24  24               LaMelo Ball   PG   20  CHO  29   935  21.5   .543  .428
# 25  25                Lonzo Ball   PG   24  CHI  29  1031  14.3   .564  .652
# 26  26                  Mo Bamba    C   23  ORL  27   774  16.0   .541  .437
# 27  27              Desmond Bane   SF   23  MEM  35  1031  17.1   .595  .485
# 28  28             Dalano Banton   SF   22  TOR  28   365  11.3   .502  .231
# 29  29                Cat Barber    G   27  ATL   2     6  -9.3   .000  .000
#
#     ... Unnamed: 19   OWS  DWS    WS   WS/48 Unnamed: 24   OBPM  DBPM    BPM  \
# 0   ...         NaN  -0.2  0.6   0.4    .030         NaN   -3.1  -1.0   -4.1
# 1   ...         NaN   1.7  1.0   2.7    .145         NaN    0.7   0.2    0.9
# 2   ...         NaN   0.9  0.9   1.9    .151         NaN    0.9   1.0    1.9
# 3   ...         NaN   0.0  0.1   0.1    .021         NaN   -4.3  -2.9   -7.2
# 4   ...         NaN   1.4  0.9   2.3    .186         NaN    2.1   0.0    2.1
# 5   ...         NaN  -0.4  0.5   0.1    .006         NaN   -1.1  -1.7   -2.8
# 6   ...         NaN   1.4  0.9   2.3    .117         NaN    0.8  -0.4    0.4
# 7   ...         NaN   3.1  1.9   4.9    .260         NaN    3.1   2.0    5.1
# 8   ...         NaN   0.1  0.1   0.1    .166         NaN    1.3   3.1    4.4
# 9   ...         NaN   0.1  0.1   0.1    .147         NaN   -4.5   0.1   -4.4
# 10  ...         NaN   0.5  0.9   1.5    .103         NaN   -0.4   1.2    0.7
# 11  ...         NaN   3.4  1.7   5.1    .269         NaN    6.7   3.4   10.0
# 12  ...         NaN   0.1  0.4   0.5    .075         NaN   -4.6   0.5   -4.0
# 13  ...         NaN   1.3  0.9   2.2    .110         NaN    0.5  -0.7   -0.1
# 14  ...         NaN   0.8  0.4   1.2    .071         NaN    1.7  -0.9    0.8
# 15  ...         NaN   0.7  0.4   1.1    .092         NaN    1.4  -0.8    0.7
# 16  ...         NaN   0.2  0.0   0.2    .250         NaN    6.5   2.5    8.9
# 17  ...         NaN   0.4  0.0   0.4    .039         NaN   -0.6  -3.0   -3.6
# 18  ...         NaN   0.5  0.9   1.3    .084         NaN   -1.6   1.3   -0.3
# 19  ...         NaN   0.0  0.0   0.0  -0.043         NaN   -2.3  -1.3   -3.6
# 20  ...         NaN   OWS  DWS    WS   WS/48         NaN   OBPM  DBPM    BPM
# 21  ...         NaN   1.8  1.5   3.2    .211         NaN    2.4   1.0    3.4
# 22  ...         NaN   0.0  0.0   0.0    .078         NaN   -0.6  -1.1   -1.7
# 23  ...         NaN   0.4  0.2   0.6    .101         NaN    0.4  -2.5   -2.1
# 24  ...         NaN   1.8  0.8   2.5    .130         NaN    4.1   0.5    4.6
# 25  ...         NaN   0.7  1.4   2.1    .099         NaN    0.8   1.4    2.2
# 26  ...         NaN   0.5  1.0   1.5    .092         NaN   -0.7   1.2    0.5
# 27  ...         NaN   1.9  0.8   2.8    .130         NaN    2.3  -0.6    1.7
# 28  ...         NaN   0.0  0.3   0.3    .038         NaN   -2.3  -0.5   -2.8
# 29  ...         NaN  -0.1  0.0  -0.1  -0.429         NaN  -16.1  -8.2  -24.3
#
#     VORP
# 0   -0.3
# 1    0.7
# 2    0.6
# 3   -0.2
# 4    0.6
# 5   -0.2
# 6    0.6
# 7    1.6
# 8    0.1
# 9    0.0
# 10   0.5
# 11   2.8
# 12  -0.2
# 13   0.5
# 14   0.6
# 15   0.4
# 16   0.1
# 17  -0.2
# 18   0.3
# 19   0.0
# 20  VORP
# 21   1.0
# 22   0.0
# 23   0.0
# 24   1.5
# 25   1.1
# 26   0.5
# 27   1.0
# 28  -0.1
# 29   0.0
#
# [30 rows x 29 columns]

# %%
advanced.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr',
#        'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
#        'Unnamed: 19', 'OWS', 'DWS', 'WS', 'WS/48', 'Unnamed: 24', 'OBPM',
#        'DBPM', 'BPM', 'VORP'],
#       dtype='object')

# %% [markdown]
# #### Cleaning DataFrame ####

# %% [markdown]
# ###### Cleaning Normal Stats ######

# %%
#renames columns to strings only#
nba.rename(
    columns={
        'FG%': 'FGP',
        '3P': 'TP',
        '3PA': 'TPA',
        '3P%': 'TPP',
        '2P': 'TWOP',
        '2PA': 'TWOPA',
        '2P%': 'TWOPP',
        'eFG%': 'eFGP',
        'FT%': 'FTP'
    }, inplace=True)

#removing duplicate players (stats of players that played on different teams)#
nba.drop_duplicates(subset=['Player'], keep=False, inplace=True)
#Dropping "Rk" Column#
nba.drop('Rk', axis=1, inplace=True)

#replacing NaN with 0#
nba.fillna(0, inplace=True)

nba[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]] = nba[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]].apply(pd.to_numeric)
nba
# Out:
#                 Player Pos Age   Tm   G  GS    MP   FG   FGA    FGP  ...  \
# 0     Precious Achiuwa   C  22  TOR  22  17  26.3  3.6   8.9  0.403  ...
# 1         Steven Adams   C  28  MEM  35  35  25.5  2.6   5.0  0.529  ...
# 2          Bam Adebayo   C  24  MIA  18  18  32.9  7.0  13.5  0.519  ...
# 3         Santi Aldama  PF  21  MEM  16   0   9.8  1.5   4.1  0.364  ...
# 4    LaMarcus Aldridge   C  36  BRK  25   8  23.6  6.0  10.4  0.573  ...
# ..                 ...  ..  ..  ...  ..  ..   ...  ...   ...    ...  ...
# 579     Thaddeus Young  PF  33  SAS  22   0  14.1  2.9   5.1  0.566  ...
# 580         Trae Young  PG  23  ATL  30  30  34.3  9.4  20.7  0.456  ...
# 581     Omer Yurtseven   C  23  MIA  26   2  11.3  1.8   4.0  0.466  ...
# 582        Cody Zeller   C  29  POR  24   0  13.3  1.8   3.2  0.566  ...
# 583        Ivica Zubac   C  24  LAC  34  34  24.9  3.7   5.6  0.667  ...
#
#        FTP  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0    0.528  2.2  5.9   8.1  1.5  0.5  0.5  1.1  2.5   8.4
# 1    0.627  4.1  5.0   9.1  2.9  0.9  0.5  1.7  1.7   7.1
# 2    0.759  2.7  7.4  10.2  3.2  1.1  0.3  2.9  3.3  18.7
# 3    0.583  1.0  1.6   2.6  0.8  0.1  0.2  0.3  1.1   3.6
# 4    0.833  1.4  4.3   5.7  0.9  0.4  1.2  0.8  1.7  14.0
# ..     ...  ...  ...   ...  ...  ...  ...  ...  ...   ...
# 579  0.444  1.5  1.9   3.4  2.5  0.9  0.3  1.0  1.4   6.2
# 580  0.897  0.8  3.1   3.9  9.3  1.0  0.1  4.0  1.7  27.3
# 581  0.633  1.5  3.1   4.6  0.5  0.3  0.5  0.8  1.4   4.4
# 582  0.766  1.8  2.8   4.6  0.8  0.3  0.3  0.7  2.1   5.1
# 583  0.741  2.6  5.4   8.1  1.1  0.6  1.2  1.4  2.4   9.9
#
# [545 rows x 29 columns]

# %% [markdown]
# ###### Cleaning Advanced Stats ######

# %%
advanced.rename(
    columns={
        'WS': 'Win Shares',
        'BPM': 'Avg. Box +/-'
    }, inplace=True)

#removing duplicate players (stats of players that played on different teams)#
advanced.drop_duplicates(subset=['Player'], keep=False, inplace=True)
#Dropping "Rk" Column#
advanced.drop('Rk', axis=1, inplace=True)

#replacing NaN with 0#
advanced.fillna(0, inplace=True)

advanced[['Age', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr','ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%','Unnamed: 19', 'OWS', 'DWS', 'Win Shares', 'WS/48', 'Unnamed: 24', 'OBPM','DBPM', 'Avg. Box +/-', 'VORP']] = advanced[['Age', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr','ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%','Unnamed: 19', 'OWS', 'DWS', 'Win Shares', 'WS/48', 'Unnamed: 24', 'OBPM','DBPM', 'Avg. Box +/-', 'VORP']].apply(pd.to_numeric)
advanced.drop(['Player','Pos','Age','Tm','G','MP','3PAr','FTr','ORB%','DRB%','TRB%','AST%','STL%','BLK%','TOV%','USG%','OWS','DWS','WS/48','OBPM','DBPM','TS%','VORP','Unnamed: 19','Unnamed: 24'], axis=1, inplace=True)
shorter_advanced = advanced
shorter_advanced
# Out:
#       PER  Win Shares  Avg. Box +/-
# 0    10.7         0.4          -4.1
# 1    17.4         2.7           0.9
# 2    19.5         1.9           1.9
# 3    10.2         0.1          -7.2
# 4    21.4         2.3           2.1
# ..    ...         ...           ...
# 579  20.1         1.0           3.1
# 580  25.4         3.7           4.7
# 581  15.2         0.6          -4.0
# 582  17.5         1.1          -1.9
# 583  19.3         3.7           1.3
#
# [545 rows x 3 columns]

# %%
nba = nba.loc[~nba.index.duplicated(keep='first')]
shorter_advanced = shorter_advanced.loc[~shorter_advanced.index.duplicated(keep='first')]
full = pd.concat([nba, shorter_advanced], axis=1)
full
# Out:
#                 Player Pos Age   Tm   G  GS    MP   FG   FGA    FGP  ...  \
# 0     Precious Achiuwa   C  22  TOR  22  17  26.3  3.6   8.9  0.403  ...
# 1         Steven Adams   C  28  MEM  35  35  25.5  2.6   5.0  0.529  ...
# 2          Bam Adebayo   C  24  MIA  18  18  32.9  7.0  13.5  0.519  ...
# 3         Santi Aldama  PF  21  MEM  16   0   9.8  1.5   4.1  0.364  ...
# 4    LaMarcus Aldridge   C  36  BRK  25   8  23.6  6.0  10.4  0.573  ...
# ..                 ...  ..  ..  ...  ..  ..   ...  ...   ...    ...  ...
# 579     Thaddeus Young  PF  33  SAS  22   0  14.1  2.9   5.1  0.566  ...
# 580         Trae Young  PG  23  ATL  30  30  34.3  9.4  20.7  0.456  ...
# 581     Omer Yurtseven   C  23  MIA  26   2  11.3  1.8   4.0  0.466  ...
# 582        Cody Zeller   C  29  POR  24   0  13.3  1.8   3.2  0.566  ...
# 583        Ivica Zubac   C  24  LAC  34  34  24.9  3.7   5.6  0.667  ...
#
#       TRB  AST  STL  BLK  TOV   PF   PTS   PER  Win Shares  Avg. Box +/-
# 0     8.1  1.5  0.5  0.5  1.1  2.5   8.4  10.7         0.4          -4.1
# 1     9.1  2.9  0.9  0.5  1.7  1.7   7.1  17.4         2.7           0.9
# 2    10.2  3.2  1.1  0.3  2.9  3.3  18.7  19.5         1.9           1.9
# 3     2.6  0.8  0.1  0.2  0.3  1.1   3.6  10.2         0.1          -7.2
# 4     5.7  0.9  0.4  1.2  0.8  1.7  14.0  21.4         2.3           2.1
# ..    ...  ...  ...  ...  ...  ...   ...   ...         ...           ...
# 579   3.4  2.5  0.9  0.3  1.0  1.4   6.2  20.1         1.0           3.1
# 580   3.9  9.3  1.0  0.1  4.0  1.7  27.3  25.4         3.7           4.7
# 581   4.6  0.5  0.3  0.5  0.8  1.4   4.4  15.2         0.6          -4.0
# 582   4.6  0.8  0.3  0.3  0.7  2.1   5.1  17.5         1.1          -1.9
# 583   8.1  1.1  0.6  1.2  1.4  2.4   9.9  19.3         3.7           1.3
#
# [545 rows x 32 columns]

# %%
full['Conf'] = full['Tm'].apply(lambda x: 'West' if x in ['DAL','DEN','GSW','HOU','LAC','LAL','MEM','MIN','NOP','OKC','PHO','POR','SAC','SAS','UTA'] else 'East')
full
# Out:
#                 Player Pos Age   Tm   G  GS    MP   FG   FGA    FGP  ...  AST  \
# 0     Precious Achiuwa   C  22  TOR  22  17  26.3  3.6   8.9  0.403  ...  1.5
# 1         Steven Adams   C  28  MEM  35  35  25.5  2.6   5.0  0.529  ...  2.9
# 2          Bam Adebayo   C  24  MIA  18  18  32.9  7.0  13.5  0.519  ...  3.2
# 3         Santi Aldama  PF  21  MEM  16   0   9.8  1.5   4.1  0.364  ...  0.8
# 4    LaMarcus Aldridge   C  36  BRK  25   8  23.6  6.0  10.4  0.573  ...  0.9
# ..                 ...  ..  ..  ...  ..  ..   ...  ...   ...    ...  ...  ...
# 579     Thaddeus Young  PF  33  SAS  22   0  14.1  2.9   5.1  0.566  ...  2.5
# 580         Trae Young  PG  23  ATL  30  30  34.3  9.4  20.7  0.456  ...  9.3
# 581     Omer Yurtseven   C  23  MIA  26   2  11.3  1.8   4.0  0.466  ...  0.5
# 582        Cody Zeller   C  29  POR  24   0  13.3  1.8   3.2  0.566  ...  0.8
# 583        Ivica Zubac   C  24  LAC  34  34  24.9  3.7   5.6  0.667  ...  1.1
#
#      STL  BLK  TOV   PF   PTS   PER  Win Shares  Avg. Box +/-  Conf
# 0    0.5  0.5  1.1  2.5   8.4  10.7         0.4          -4.1  East
# 1    0.9  0.5  1.7  1.7   7.1  17.4         2.7           0.9  West
# 2    1.1  0.3  2.9  3.3  18.7  19.5         1.9           1.9  East
# 3    0.1  0.2  0.3  1.1   3.6  10.2         0.1          -7.2  West
# 4    0.4  1.2  0.8  1.7  14.0  21.4         2.3           2.1  East
# ..   ...  ...  ...  ...   ...   ...         ...           ...   ...
# 579  0.9  0.3  1.0  1.4   6.2  20.1         1.0           3.1  West
# 580  1.0  0.1  4.0  1.7  27.3  25.4         3.7           4.7  East
# 581  0.3  0.5  0.8  1.4   4.4  15.2         0.6          -4.0  East
# 582  0.3  0.3  0.7  2.1   5.1  17.5         1.1          -1.9  West
# 583  0.6  1.2  1.4  2.4   9.9  19.3         3.7           1.3  West
#
# [545 rows x 33 columns]

# %% [markdown]
# #### Filtering DataFrame ####

# %% [markdown]
# ###### Filtering Normal Stats ######

# %%
full.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FGP', 'TP',
#        'TPA', 'TPP', 'TWOP', 'TWOPA', 'TWOPP', 'eFGP', 'FT', 'FTA', 'FTP',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'PER',
#        'Win Shares', 'Avg. Box +/-', 'Conf'],
#       dtype='object')

# %%
full[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]] = nba[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]].apply(pd.to_numeric)

# %%
full.drop(full[full['G'] <= 10].index, inplace = True)
full.drop(full[full['TP'] <= 0.1].index, inplace = True)
full.drop(full[full['TPA'] <= 0.1].index, inplace = True)
full.drop(full[full['TPP'] <= 0.1].index, inplace = True)
full.drop(full[full['PTS'] <= 14].index, inplace = True)

# %%
west = full[full["Conf"].str.contains("West")]
east = full[full["Conf"].str.contains("East")]

# %%
west[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]] = west[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]].apply(pd.to_numeric)
# Out:
# C:\Users\Home\anaconda3\lib\site-packages\pandas\core\frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
east[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]] = east[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]].apply(pd.to_numeric)

# %% [markdown]
# #### Processing the Data ####

# %%
for index, row in full.iterrows():
    west.loc[index, "Score"] = (((row['FGP']*row['TPP']*row['FTP'])*(row['PTS']+row['TRB']+row['STL']+row['AST']+row['BLK']-row['TOV']-(row['FGA']-row['FG']))*(1-row['eFGP']))*(row['PTS']+row['TRB']+row['STL']+(0.5*row['AST'])+(0.5*row['BLK'])-row['FGA']-row['TOV']-(0.5*row['FTA'])-(0.5*row['PF'])))
# Out:
# C:\Users\Home\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
west.sort_values(by=['Score'], ascending=False, inplace=True)
west.drop(['GS','MP','FG','FGA','TP','TPA','TWOP','TWOPA','TWOPP','eFGP','FT','FTA','FTP','ORB','DRB','STL','BLK','TOV','PF','Avg. Box +/-'], axis=1, inplace=True)
west['Advanced Score'] = (west['PER']*west['Win Shares'])/100
west['ASG Score'] = round(west['Score']*west['Advanced Score'],2)
west.drop(['Score', 'Advanced Score'], axis=1, inplace=True)
west.sort_values(by=['ASG Score'], ascending=False, inplace=True)
west = west.rename({'FGP': 'FG%', 'TPP': '3P%', 'TRB': 'REB'}, axis='columns')
west = west.dropna()

# %%
for index, row in full.iterrows():
    east.loc[index, "Score"] = (((row['FGP']*row['TPP']*row['FTP'])*(row['PTS']+row['TRB']+row['STL']+row['AST']+row['BLK']-row['TOV']-(row['FGA']-row['FG']))*(1-row['eFGP']))*(row['PTS']+row['TRB']+row['STL']+(0.5*row['AST'])+(0.5*row['BLK'])-row['FGA']-row['TOV']-(0.5*row['FTA'])-(0.5*row['PF'])))
# Out:
# C:\Users\Home\anaconda3\lib\site-packages\pandas\core\indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\Home\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\Home\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
east.sort_values(by=['Score'], ascending=False, inplace=True)
east.drop(['GS','MP','FG','FGA','TP','TPA','TWOP','TWOPA','TWOPP','eFGP','FT','FTA','FTP','ORB','DRB','STL','BLK','TOV','PF','Avg. Box +/-'], axis=1, inplace=True)
east['Advanced Score'] = (east['PER']*east['Win Shares'])/100
east['ASG Score'] = round(east['Score']*east['Advanced Score'],2)
east.drop(['Score', 'Advanced Score'], axis=1, inplace=True)
east.sort_values(by=['ASG Score'], ascending=False, inplace=True)
east = east.rename({'FGP': 'FG%', 'TPP': '3P%', 'TRB': 'REB'}, axis='columns')
east = east.dropna()

# %%
westpg = west[west['Pos'].str.contains('PG')]
westsg = west[west['Pos'].str.contains('SG')]
westsf = west[west['Pos'].str.contains('SF')]
westpf = west[west['Pos'].str.contains('PF')]
westc = west[west['Pos'].str.contains('C')]

# %%
eastpg = east[east['Pos'].str.contains('PG')]
eastsg = east[east['Pos'].str.contains('SG')]
eastsf = east[east['Pos'].str.contains('SF')]
eastpf = east[east['Pos'].str.contains('PF')]
eastc = east[east['Pos'].str.contains('C')]

# %%
westbc = pd.concat([westpg, westsg], axis=0)
westbc.sort_values(by=['ASG Score'], ascending=False, inplace=True)
westbc.head(15)
# Out:
#                       Player Pos Age   Tm     G    FG%    3P%  REB   AST  \
# 123            Stephen Curry  PG  33  GSW  32.0  0.433  0.397  5.3   5.9
# 424               Chris Paul  PG  36  PHO  33.0  0.484  0.316  4.1  10.0
# 390          Dejounte Murray  PG  25  SAS  31.0  0.438  0.341  8.4   8.8
# 380                Ja Morant  PG  22  MEM  23.0  0.478  0.350  5.5   6.8
# 373         Donovan Mitchell  SG  25  UTA  31.0  0.457  0.337  3.8   5.0
# 56              Devin Booker  SG  25  PHO  26.0  0.455  0.422  5.0   4.6
# 110              Mike Conley  PG  34  UTA  30.0  0.478  0.434  2.7   5.3
# 323           Damian Lillard  PG  31  POR  27.0  0.403  0.328  4.1   7.4
# 137              Luka Dončić  PG  22  DAL  21.0  0.447  0.326  8.0   8.5
# 80             Jalen Brunson  PG  25  DAL  32.0  0.491  0.327  3.8   5.5
# 184  Shai Gilgeous-Alexander  PG  23  OKC  30.0  0.420  0.283  4.8   5.2
# 557            Derrick White  SG  27  SAS  33.0  0.423  0.291  3.6   5.3
# 151          Anthony Edwards  SG  20  MIN  28.0  0.434  0.360  5.8   3.6
# 555        Russell Westbrook  PG  33  LAL  35.0  0.455  0.315  8.0   8.2
# 435             Jordan Poole  SG  22  GSW  28.0  0.442  0.338  3.4   3.4
#
#       PTS   PER  Win Shares  Conf  ASG Score
# 123  27.7  23.7         5.1  West      22.52
# 424  14.5  21.0         4.8  West      13.07
# 390  17.8  20.1         2.8  West       8.90
# 380  23.7  23.9         2.5  West       8.25
# 373  25.4  22.4         3.7  West       7.61
# 56   23.1  19.6         2.4  West       5.40
# 110  14.1  19.0         3.6  West       5.22
# 323  23.9  19.5         2.3  West       4.21
# 137  25.6  21.7         1.4  West       3.78
# 80   15.8  18.4         3.0  West       3.75
# 184  22.7  18.9         2.2  West       2.84
# 557  14.3  16.4         2.5  West       2.28
# 151  22.1  16.4         1.5  West       1.96
# 555  19.8  16.1         1.4  West       1.96
# 435  17.9  14.8         2.2  West       1.47

# %%
westfc = pd.concat([westsf, westpf, westc], axis=0)
westfc.sort_values(by=['ASG Score'], ascending=False, inplace=True)
westfc.head(15)
# Out:
#                  Player Pos Age   Tm     G    FG%    3P%   REB  AST   PTS  \
# 281        Nikola Jokić   C  26  DEN  28.0  0.559  0.350  14.0  7.1  25.8
# 527  Karl-Anthony Towns   C  26  MIN  30.0  0.510  0.426   9.1  3.6  24.5
# 531   Jonas Valančiūnas   C  29  NOP  33.0  0.522  0.453  12.0  2.4  18.5
# 263        LeBron James  SF  37  LAL  23.0  0.520  0.353   7.0  6.7  27.6
# 124       Anthony Davis   C  28  LAL  27.0  0.521  0.179   9.9  2.9  23.3
# 440  Kristaps Porziņģis  PF  26  DAL  24.0  0.445  0.280   8.0  2.2  20.3
# 30      Harrison Barnes  PF  29  SAC  30.0  0.450  0.408   6.3  2.4  17.3
# 573      Christian Wood   C  26  HOU  33.0  0.470  0.350  10.7  2.2  17.3
# 27         Desmond Bane  SF  23  MEM  35.0  0.472  0.426   4.3  2.2  17.2
# 561      Andrew Wiggins  SF  26  GSW  30.0  0.487  0.425   4.6  1.8  18.8
# 52     Bojan Bogdanović  PF  32  UTA  33.0  0.482  0.427   3.6  1.6  17.5
# 254      Brandon Ingram  SF  24  NOP  27.0  0.453  0.349   6.1  4.9  22.9
# 276      Keldon Johnson  SF  22  SAS  32.0  0.478  0.472   6.6  1.7  15.3
# 181         Paul George  SF  31  LAC  26.0  0.421  0.323   7.1  5.5  24.7
# 259   Jaren Jackson Jr.  PF  22  MEM  34.0  0.417  0.327   5.2  1.1  16.4
#
#       PER  Win Shares  Conf  ASG Score
# 281  32.3         5.2  West      73.16
# 527  23.5         4.0  West      22.99
# 531  22.1         3.4  West      21.67
# 263  25.3         3.4  West      20.22
# 124  23.4         3.2  West       8.55
# 440  23.4         2.7  West       7.86
# 30   16.7         2.5  West       4.77
# 573  17.9         2.0  West       4.30
# 27   17.1         2.8  West       4.12
# 561  17.4         2.9  West       3.81
# 52   16.9         3.2  West       3.57
# 254  18.1         1.6  West       2.91
# 276  14.9         2.0  West       2.81
# 181  18.2         1.2  West       2.38
# 259  16.9         2.1  West       1.72

# %%
eastbc = pd.concat([eastpg, eastsg], axis=0)
eastbc.sort_values(by=['ASG Score'], ascending=False, inplace=True)
eastbc.head(15)
# Out:
#               Player Pos Age   Tm     G    FG%    3P%  REB  AST   PTS   PER  \
# 208     James Harden  PG  32  BRK  28.0  0.415  0.343  8.0  9.8  22.0  21.1
# 580       Trae Young  PG  23  ATL  30.0  0.456  0.371  3.9  9.3  27.3  25.4
# 24       LaMelo Ball  PG  20  CHO  29.0  0.422  0.392  7.4  8.0  19.7  21.5
# 535    Fred VanVleet  PG  27  TOR  28.0  0.434  0.397  5.1  6.7  20.1  18.3
# 176   Darius Garland  PG  22  CLE  31.0  0.479  0.384  3.0  7.3  19.5  17.8
# 67   Malcolm Brogdon  PG  29  IND  26.0  0.446  0.311  5.3  6.1  19.0  19.0
# 234     Jrue Holiday  PG  31  MIL  29.0  0.493  0.360  4.5  6.6  17.8  19.3
# 348     Tyrese Maxey  PG  21  PHI  31.0  0.470  0.360  3.4  4.5  16.5  16.2
# 122       Seth Curry  SG  31  PHI  31.0  0.512  0.411  3.0  3.4  16.0  15.2
# 14      Cole Anthony  PG  21  ORL  24.0  0.418  0.354  6.0  5.8  20.0  16.7
# 528   Gary Trent Jr.  SG  23  TOR  28.0  0.424  0.379  3.0  2.2  16.9  15.2
# 227      Tyler Herro  SG  22  MIA  29.0  0.444  0.408  5.0  3.9  20.6  16.2
# 543     Kemba Walker  PG  31  NYK  23.0  0.418  0.408  3.6  3.7  14.1  17.0
# 369      Patty Mills  PG  33  BRK  32.0  0.452  0.441  2.1  2.6  14.4  13.9
# 39      Bradley Beal  SG  28  WAS  28.0  0.456  0.283  4.6  5.9  23.3  17.6
#
#      Win Shares  Conf  ASG Score
# 208         3.5  East      14.68
# 580         3.7  East      14.61
# 24          2.5  East      10.15
# 535         2.8  East       6.58
# 176         3.0  East       4.90
# 67          2.6  East       4.89
# 234         2.9  East       4.88
# 348         2.4  East       2.82
# 122         2.4  East       2.54
# 14          1.2  East       1.89
# 528         2.2  East       1.82
# 227         1.4  East       1.72
# 543         1.6  East       1.56
# 369         2.3  East       1.42
# 39          1.0  East       1.00

# %%
eastbc = pd.concat([eastsf, eastpf, eastc], axis=0)
eastbc.sort_values(by=['ASG Score'], ascending=False, inplace=True)
eastbc.head(15)
# Out:
#                     Player Pos Age   Tm     G    FG%    3P%   REB  AST   PTS  \
# 150           Kevin Durant  PF  33  BRK  27.0  0.523  0.382   7.9  5.9  29.7
# 11   Giannis Antetokounmpo  PF  27  MIL  28.0  0.530  0.274  11.4  5.8  27.4
# 155            Joel Embiid   C  27  PHI  23.0  0.467  0.388  10.9  4.1  26.0
# 475       Domantas Sabonis   C  25  IND  33.0  0.571  0.282  11.7  4.2  18.0
# 131          DeMar DeRozan  PF  32  CHI  28.0  0.506  0.365   5.1  4.4  27.0
# 108           John Collins  PF  24  ATL  32.0  0.549  0.427   7.9  2.1  17.6
# 87            Jimmy Butler  SF  32  MIA  20.0  0.502  0.188   6.2  5.7  22.7
# 314            Zach LaVine  SF  26  CHI  29.0  0.496  0.406   5.2  4.4  26.4
# 439           Bobby Portis   C  26  MIL  27.0  0.481  0.429   9.0  1.5  15.8
# 510           Jayson Tatum  SF  23  BOS  33.0  0.417  0.329   8.6  3.8  25.6
# 31          Scottie Barnes  PF  20  TOR  27.0  0.494  0.356   8.3  3.4  15.6
# 374            Evan Mobley  PF  20  CLE  26.0  0.485  0.341   8.3  2.4  14.1
# 65           Miles Bridges  PF  23  CHO  34.0  0.472  0.314   7.2  3.7  19.7
# 215          Tobias Harris  PF  29  PHI  25.0  0.458  0.299   7.8  3.7  18.8
# 452          Julius Randle  PF  27  NYK  34.0  0.421  0.333  10.0  5.0  19.7
#
#       PER  Win Shares  Conf  ASG Score
# 150  25.8         4.5  East      37.93
# 11   30.8         5.1  East      37.10
# 155  28.3         3.6  East      33.93
# 475  22.3         4.4  East      18.59
# 131  24.2         4.1  East      18.26
# 108  21.2         4.2  East      16.58
# 87   27.2         3.9  East      13.63
# 314  22.3         3.3  East      11.85
# 439  20.3         2.7  East       8.26
# 510  19.2         2.5  East       6.13
# 31   17.4         2.5  East       5.34
# 374  16.1         2.6  East       5.15
# 65   17.5         2.5  East       5.03
# 215  18.0         1.9  East       3.95
# 452  16.5         1.8  East       3.45
