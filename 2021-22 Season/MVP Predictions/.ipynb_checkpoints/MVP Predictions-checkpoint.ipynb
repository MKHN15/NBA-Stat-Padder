# %% [markdown]
# # MVP Predictions #

# %%
# -*- coding: utf-8 -*-#
"""
Created by MinhKhang Nguyen
July 27 2021 7:37 PM - August 6 2021 2:08 AM
"""
# Out:
# '\nCreated by MinhKhang Nguyen\nJuly 27 2021 7:37 PM - August 6 2021 2:08 AM\n'

# %%
import pandas as pd 
import random as rnd
import numpy as np
import matplotlib.pyplot as plt

# %%
import ssl
ssl._create_default_https_econtext = ssl._create_unverified_context

# %% [markdown]
# #### Importing Data ####

# %% [markdown]
# ###### Importing Normal Stats ######

# %%
html_url = "https://www.basketball-reference.com/leagues/NBA_2022_per_game.html"
nba_tables = pd.read_html(html_url)
len(nba_tables)
nba = nba_tables[0]
nba.head(30)
# Out:
#     Rk                    Player  Pos  Age   Tm   G  GS    MP    FG   FGA  \
# 0    1          Precious Achiuwa    C   22  TOR  73  28  23.6   3.6   8.3
# 1    2              Steven Adams    C   28  MEM  76  75  26.3   2.8   5.1
# 2    3               Bam Adebayo    C   24  MIA  56  56  32.6   7.3  13.0
# 3    4              Santi Aldama   PF   21  MEM  32   0  11.3   1.7   4.1
# 4    5         LaMarcus Aldridge    C   36  BRK  47  12  22.3   5.4   9.7
# 5    6  Nickeil Alexander-Walker   SG   23  TOT  65  21  22.6   3.9  10.5
# 6    6  Nickeil Alexander-Walker   SG   23  NOP  50  19  26.3   4.7  12.6
# 7    6  Nickeil Alexander-Walker   SG   23  UTA  15   2   9.9   1.1   3.2
# 8    7             Grayson Allen   SG   26  MIL  66  61  27.3   3.9   8.6
# 9    8             Jarrett Allen    C   23  CLE  56  56  32.3   6.6   9.7
# 10   9             Jose Alvarado   PG   23  NOP  54   1  15.4   2.4   5.4
# 11  10           Justin Anderson   SF   28  TOT  16   6  19.8   2.3   5.9
# 12  10           Justin Anderson   SF   28  CLE   3   0  15.7   1.3   2.7
# 13  10           Justin Anderson   SF   28  IND  13   6  20.7   2.5   6.7
# 14  11             Kyle Anderson   PF   28  MEM  69  11  21.5   3.0   6.8
# 15  12     Giannis Antetokounmpo   PF   27  MIL  67  67  32.9  10.3  18.6
# 16  13    Thanasis Antetokounmpo   SF   29  MIL  48   6   9.9   1.5   2.7
# 17  14           Carmelo Anthony   PF   37  LAL  69   3  26.0   4.6  10.5
# 18  15              Cole Anthony   PG   21  ORL  65  65  31.7   5.5  14.0
# 19  16                OG Anunoby   SF   24  TOR  48  48  36.0   6.4  14.5
# 20  17          Ryan Arcidiacono   PG   27  NYK  10   0   7.6   0.6   1.2
# 21  18              Trevor Ariza   SF   36  LAL  24  11  19.3   1.4   4.1
# 22  19             D.J. Augustin   PG   34  TOT  55   2  16.1   1.7   4.0
# 23  19             D.J. Augustin   PG   34  HOU  34   2  15.0   1.6   4.0
# 24  19             D.J. Augustin   PG   34  LAL  21   0  17.8   1.9   4.1
# 25  20               Deni Avdija   SF   21  WAS  82   8  24.2   3.0   7.1
# 26  Rk                    Player  Pos  Age   Tm   G  GS    MP    FG   FGA
# 27  21                Joel Ayayi   SG   21  WAS   7   0   2.9   0.1   0.9
# 28  22             Deandre Ayton    C   23  PHO  58  58  29.5   7.6  12.0
# 29  23            Udoka Azubuike    C   22  UTA  17   6  11.5   2.2   2.9
#
#     ...    FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0   ...   .595  2.0  4.5   6.5  1.1  0.5  0.6  1.2  2.1   9.1
# 1   ...   .543  4.6  5.4  10.0  3.4  0.9  0.8  1.5  2.0   6.9
# 2   ...   .753  2.4  7.6  10.1  3.4  1.4  0.8  2.6  3.1  19.1
# 3   ...   .625  1.0  1.7   2.7  0.7  0.2  0.3  0.5  1.1   4.1
# 4   ...   .873  1.6  3.9   5.5  0.9  0.3  1.0  0.9  1.7  12.9
# 5   ...   .743  0.6  2.3   2.9  2.4  0.7  0.4  1.4  1.6  10.6
# 6   ...   .722  0.7  2.6   3.3  2.8  0.8  0.4  1.7  1.8  12.8
# 7   ...   .917  0.1  1.5   1.5  1.1  0.3  0.3  0.5  1.0   3.5
# 8   ...   .865  0.5  2.9   3.4  1.5  0.7  0.3  0.7  1.5  11.1
# 9   ...   .708  3.4  7.3  10.8  1.6  0.8  1.3  1.7  1.7  16.1
# 10  ...   .679  0.5  1.4   1.9  2.8  1.3  0.1  0.7  1.4   6.1
# 11  ...   .789  0.3  2.6   2.9  2.1  0.5  0.4  0.5  1.4   6.4
# 12  ...   .750  0.0  2.0   2.0  2.0  0.3  0.0  0.7  1.3   4.3
# 13  ...   .800  0.3  2.8   3.1  2.1  0.5  0.5  0.5  1.4   6.8
# 14  ...   .638  1.0  4.3   5.3  2.7  1.1  0.7  1.0  1.6   7.6
# 15  ...   .722  2.0  9.6  11.6  5.8  1.1  1.4  3.3  3.2  29.9
# 16  ...   .630  0.8  1.3   2.1  0.5  0.3  0.3  0.5  1.4   3.6
# 17  ...   .830  0.9  3.3   4.2  1.0  0.7  0.8  0.9  2.4  13.3
# 18  ...   .854  0.5  4.9   5.4  5.7  0.7  0.3  2.6  2.6  16.3
# 19  ...   .754  1.5  4.0   5.5  2.6  1.5  0.5  1.7  2.7  17.1
# 20  ...    NaN  0.0  0.8   0.8  0.4  0.1  0.0  0.3  0.5   1.6
# 21  ...   .556  0.4  3.0   3.4  1.1  0.5  0.3  0.5  0.8   4.0
# 22  ...   .884  0.2  1.0   1.2  1.9  0.3  0.0  1.0  0.7   5.3
# 23  ...   .868  0.2  1.0   1.2  2.2  0.3  0.0  1.3  0.5   5.4
# 24  ...  1.000  0.2  1.1   1.3  1.6  0.3  0.0  0.5  1.0   5.3
# 25  ...   .757  0.6  4.5   5.2  2.0  0.7  0.5  1.1  2.3   8.4
# 26  ...    FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 27  ...    NaN  0.1  0.3   0.4  0.6  0.0  0.0  0.0  0.0   0.3
# 28  ...   .746  2.6  7.7  10.2  1.4  0.7  0.7  1.6  2.4  17.2
# 29  ...   .545  1.1  3.1   4.2  0.0  0.1  0.6  0.7  1.5   4.7
#
# [30 rows x 30 columns]

# %%
nba.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %% [markdown]
# ###### Importing Advanced Stats ######

# %%
html_url = "https://www.basketball-reference.com/leagues/NBA_2022_advanced.html"
advanced_tables = pd.read_html(html_url)
len(advanced_tables)
advanced = advanced_tables[0]
advanced.head(30)
# Out:
#     Rk                    Player  Pos  Age   Tm   G    MP   PER   TS%  3PAr  \
# 0    1          Precious Achiuwa    C   22  TOR  73  1725  12.7  .503  .259
# 1    2              Steven Adams    C   28  MEM  76  1999  17.6  .560  .003
# 2    3               Bam Adebayo    C   24  MIA  56  1825  21.8  .608  .008
# 3    4              Santi Aldama   PF   21  MEM  32   360  10.2  .452  .364
# 4    5         LaMarcus Aldridge    C   36  BRK  47  1050  19.6  .604  .100
# 5    6  Nickeil Alexander-Walker   SG   23  TOT  65  1466  10.5  .475  .497
# 6    6  Nickeil Alexander-Walker   SG   23  NOP  50  1317  10.5  .474  .483
# 7    6  Nickeil Alexander-Walker   SG   23  UTA  15   149  10.2  .497  .688
# 8    7             Grayson Allen   SG   26  MIL  66  1805  12.7  .609  .684
# 9    8             Jarrett Allen    C   23  CLE  56  1809  23.0  .698  .018
# 10   9             Jose Alvarado   PG   23  NOP  54   834  16.4  .520  .374
# 11  10           Justin Anderson   SF   28  TOT  16   316  10.4  .493  .621
# 12  10           Justin Anderson   SF   28  CLE   3    47  10.7  .666  .750
# 13  10           Justin Anderson   SF   28  IND  13   269  10.3  .475  .609
# 14  11             Kyle Anderson   PF   28  MEM  69  1484  14.4  .506  .232
# 15  12     Giannis Antetokounmpo   PF   27  MIL  67  2204  32.1  .633  .194
# 16  13    Thanasis Antetokounmpo   SF   29  MIL  48   473  12.5  .577  .109
# 17  14           Carmelo Anthony   PF   37  LAL  69  1793  14.8  .579  .549
# 18  15              Cole Anthony   PG   21  ORL  65  2059  13.5  .519  .429
# 19  16                OG Anunoby   SF   24  TOR  48  1728  14.8  .549  .455
# 20  17          Ryan Arcidiacono   PG   27  NYK  10    76   6.1  .667  .750
# 21  18              Trevor Ariza   SF   36  LAL  24   462   7.0  .449  .747
# 22  19             D.J. Augustin   PG   34  TOT  55   883   9.7  .610  .739
# 23  19             D.J. Augustin   PG   34  HOU  34   510   9.7  .596  .706
# 24  19             D.J. Augustin   PG   34  LAL  21   373   9.7  .635  .791
# 25  20               Deni Avdija   SF   21  WAS  82  1984  11.6  .536  .447
# 26  Rk                    Player  Pos  Age   Tm   G    MP   PER   TS%  3PAr
# 27  21                Joel Ayayi   SG   21  WAS   7    20   3.4  .167  .167
# 28  22             Deandre Ayton    C   23  PHO  58  1713  21.9  .656  .027
# 29  23            Udoka Azubuike    C   22  UTA  17   195  17.6  .743  .000
#
#     ... Unnamed: 19   OWS  DWS    WS   WS/48 Unnamed: 24  OBPM  DBPM   BPM  \
# 0   ...         NaN   0.4  2.1   2.5    .070         NaN  -2.0  -0.6  -2.6
# 1   ...         NaN   3.8  3.0   6.8    .163         NaN   1.0   1.0   2.0
# 2   ...         NaN   3.6  3.5   7.2    .188         NaN   1.7   2.1   3.8
# 3   ...         NaN  -0.1  0.4   0.3    .044         NaN  -4.2  -1.5  -5.7
# 4   ...         NaN   2.1  1.0   3.1    .141         NaN   1.3  -0.6   0.7
# 5   ...         NaN  -1.1  1.1   0.1    .003         NaN  -1.8  -1.1  -2.9
# 6   ...         NaN  -1.1  0.9  -0.1  -0.005         NaN  -1.7  -1.3  -3.0
# 7   ...         NaN   0.0  0.2   0.2    .070         NaN  -2.9   1.2  -1.7
# 8   ...         NaN   2.8  1.4   4.2    .110         NaN   0.6  -0.2   0.5
# 9   ...         NaN   5.4  3.0   8.5    .225         NaN   2.7   1.2   3.9
# 10  ...         NaN   1.0  1.1   2.1    .121         NaN  -0.5   2.4   1.9
# 11  ...         NaN   0.2  0.2   0.4    .054         NaN  -1.9  -1.3  -3.2
# 12  ...         NaN   0.1  0.0   0.1    .124         NaN  -3.0   0.4  -2.6
# 13  ...         NaN   0.1  0.1   0.2    .041         NaN  -1.7  -1.6  -3.3
# 14  ...         NaN   1.0  2.5   3.5    .113         NaN  -0.9   2.1   1.2
# 15  ...         NaN   9.2  3.7  12.9    .281         NaN   7.6   3.5  11.2
# 16  ...         NaN   0.4  0.5   0.9    .095         NaN  -3.5  -0.1  -3.5
# 17  ...         NaN   2.2  1.4   3.6    .097         NaN   0.4  -0.8  -0.5
# 18  ...         NaN  -0.1  1.7   1.6    .038         NaN  -0.6  -0.6  -1.2
# 19  ...         NaN   1.8  1.9   3.7    .104         NaN   0.4   0.1   0.5
# 20  ...         NaN   0.0  0.1   0.1    .052         NaN  -4.6   0.0  -4.6
# 21  ...         NaN  -0.2  0.4   0.2    .020         NaN  -3.3  -0.2  -3.4
# 22  ...         NaN   0.7  0.1   0.8    .043         NaN  -1.2  -2.4  -3.6
# 23  ...         NaN   0.2  0.0   0.2    .017         NaN  -1.4  -2.9  -4.3
# 24  ...         NaN   0.5  0.1   0.6    .079         NaN  -1.0  -1.6  -2.6
# 25  ...         NaN   0.6  1.8   2.4    .058         NaN  -2.1   0.4  -1.7
# 26  ...         NaN   OWS  DWS    WS   WS/48         NaN  OBPM  DBPM   BPM
# 27  ...         NaN   0.0  0.0   0.0  -0.098         NaN  -4.3  -1.7  -6.0
# 28  ...         NaN   4.1  3.1   7.3    .203         NaN   2.2   0.6   2.8
# 29  ...         NaN   0.3  0.3   0.6    .157         NaN  -1.8   0.4  -1.4
#
#     VORP
# 0   -0.2
# 1    2.0
# 2    2.7
# 3   -0.3
# 4    0.7
# 5   -0.3
# 6   -0.3
# 7    0.0
# 8    1.1
# 9    2.7
# 10   0.8
# 11  -0.1
# 12   0.0
# 13  -0.1
# 14   1.2
# 15   7.4
# 16  -0.2
# 17   0.7
# 18   0.4
# 19   1.1
# 20  -0.1
# 21  -0.2
# 22  -0.4
# 23  -0.3
# 24  -0.1
# 25   0.1
# 26  VORP
# 27   0.0
# 28   2.1
# 29   0.0
#
# [30 rows x 29 columns]

# %%
advanced.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr',
#        'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
#        'Unnamed: 19', 'OWS', 'DWS', 'WS', 'WS/48', 'Unnamed: 24', 'OBPM',
#        'DBPM', 'BPM', 'VORP'],
#       dtype='object')

# %% [markdown]
# #### Cleaning DataFrame ####

# %% [markdown]
# ###### Cleaning Normal Stats ######

# %%
#renames columns to strings only#
nba.rename(
    columns={
        'FG%': 'FGP',
        '3P': 'TP',
        '3PA': 'TPA',
        '3P%': 'TPP',
        '2P': 'TWOP',
        '2PA': 'TWOPA',
        '2P%': 'TWOPP',
        'eFG%': 'eFGP',
        'FT%': 'FTP'
    }, inplace=True)

#removing duplicate players (stats of players that played on different teams)#
nba.drop_duplicates(subset=['Player'], keep=False, inplace=True)
#Dropping "Rk" Column#
nba.drop('Rk', axis=1, inplace=True)

#replacing NaN with 0#
nba.fillna(0, inplace=True)

nba[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]] = nba[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]].apply(pd.to_numeric)

# %% [markdown]
# ###### Cleaning Advanced Stats ######

# %%
advanced.rename(
    columns={
        'WS': 'Win Shares',
        'BPM': 'Avg. Box +/-'
    }, inplace=True)

#removing duplicate players (stats of players that played on different teams)#
advanced.drop_duplicates(subset=['Player'], keep=False, inplace=True)
#Dropping "Rk" Column#
advanced.drop('Rk', axis=1, inplace=True)

#replacing NaN with 0#
advanced.fillna(0, inplace=True)

advanced[['Age', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr','ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%','Unnamed: 19', 'OWS', 'DWS', 'Win Shares', 'WS/48', 'Unnamed: 24', 'OBPM','DBPM', 'Avg. Box +/-', 'VORP']] = advanced[['Age', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr','ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%','Unnamed: 19', 'OWS', 'DWS', 'Win Shares', 'WS/48', 'Unnamed: 24', 'OBPM','DBPM', 'Avg. Box +/-', 'VORP']].apply(pd.to_numeric)
advanced.drop(['Player','Pos','Age','Tm','G','MP','3PAr','FTr','ORB%','DRB%','TRB%','AST%','STL%','BLK%','TOV%','USG%','OWS','DWS','WS/48','OBPM','DBPM','TS%','VORP','Unnamed: 19','Unnamed: 24'], axis=1, inplace=True)
shorter_advanced = advanced
shorter_advanced
# Out:
#       PER  Win Shares  Avg. Box +/-
# 0    12.7         2.5          -2.6
# 1    17.6         6.8           2.0
# 2    21.8         7.2           3.8
# 3    10.2         0.3          -5.7
# 4    19.6         3.1           0.7
# ..    ...         ...           ...
# 833  12.7         0.0          -1.5
# 838  25.4        10.0           5.2
# 839  17.4         2.1          -1.0
# 840  17.2         1.1          -2.2
# 841  19.2         7.2           0.7
#
# [508 rows x 3 columns]

# %%
nba = nba.loc[~nba.index.duplicated(keep='first')]
shorter_advanced = shorter_advanced.loc[~shorter_advanced.index.duplicated(keep='first')]
full = pd.concat([nba, shorter_advanced], axis=1)
full
# Out:
#                 Player Pos Age   Tm   G  GS    MP   FG   FGA    FGP  ...  \
# 0     Precious Achiuwa   C  22  TOR  73  28  23.6  3.6   8.3  0.439  ...
# 1         Steven Adams   C  28  MEM  76  75  26.3  2.8   5.1  0.547  ...
# 2          Bam Adebayo   C  24  MIA  56  56  32.6  7.3  13.0  0.557  ...
# 3         Santi Aldama  PF  21  MEM  32   0  11.3  1.7   4.1  0.402  ...
# 4    LaMarcus Aldridge   C  36  BRK  47  12  22.3  5.4   9.7  0.550  ...
# ..                 ...  ..  ..  ...  ..  ..   ...  ...   ...    ...  ...
# 833          Gabe York  SG  28  IND   2   0  10.5  1.0   3.5  0.286  ...
# 838         Trae Young  PG  23  ATL  76  76  34.9  9.4  20.3  0.460  ...
# 839     Omer Yurtseven   C  23  MIA  56  12  12.6  2.3   4.4  0.526  ...
# 840        Cody Zeller   C  29  POR  27   0  13.1  1.9   3.3  0.567  ...
# 841        Ivica Zubac   C  24  LAC  76  76  24.4  4.1   6.5  0.626  ...
#
#       TRB  AST  STL  BLK  TOV   PF   PTS   PER  Win Shares  Avg. Box +/-
# 0     6.5  1.1  0.5  0.6  1.2  2.1   9.1  12.7         2.5          -2.6
# 1    10.0  3.4  0.9  0.8  1.5  2.0   6.9  17.6         6.8           2.0
# 2    10.1  3.4  1.4  0.8  2.6  3.1  19.1  21.8         7.2           3.8
# 3     2.7  0.7  0.2  0.3  0.5  1.1   4.1  10.2         0.3          -5.7
# 4     5.5  0.9  0.3  1.0  0.9  1.7  12.9  19.6         3.1           0.7
# ..    ...  ...  ...  ...  ...  ...   ...   ...         ...           ...
# 833   1.0  2.0  1.0  0.5  0.5  2.0   4.0  12.7         0.0          -1.5
# 838   3.7  9.7  0.9  0.1  4.0  1.7  28.4  25.4        10.0           5.2
# 839   5.3  0.9  0.3  0.4  0.7  1.5   5.3  17.4         2.1          -1.0
# 840   4.6  0.8  0.3  0.2  0.7  2.1   5.2  17.2         1.1          -2.2
# 841   8.5  1.6  0.5  1.0  1.5  2.7  10.3  19.2         7.2           0.7
#
# [508 rows x 32 columns]

# %% [markdown]
# #### Filtering DataFrame ####

# %% [markdown]
# ###### Filtering Normal Stats ######

# %%
full.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FGP', 'TP',
#        'TPA', 'TPP', 'TWOP', 'TWOPA', 'TWOPP', 'eFGP', 'FT', 'FTA', 'FTP',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'PER',
#        'Win Shares', 'Avg. Box +/-'],
#       dtype='object')

# %%
full[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]] = nba[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]].apply(pd.to_numeric)

# %%
full.drop(full[full['G'] <= 10].index, inplace = True)
full.drop(full[full['TP'] <= 0.1].index, inplace = True)
full.drop(full[full['TPA'] <= 0.1].index, inplace = True)
full.drop(full[full['TPP'] <= 0.1].index, inplace = True)
full.drop(full[full['PTS'] <= 21.1].index, inplace = True)

# %% [markdown]
# #### Processing the Data ####

# %%
for index, row in full.iterrows():
    full.loc[index, "Score"] = (((row['FGP']*row['TPP']*row['FTP'])*(row['PTS']+row['TRB']+row['STL']+row['AST']+row['BLK']-row['TOV']-(row['FGA']-row['FG']))*(1-row['eFGP']))*(row['PTS']+row['TRB']+row['STL']+(0.5*row['AST'])+(0.5*row['BLK'])-row['FGA']-row['TOV']-(0.5*row['FTA'])-(0.5*row['PF'])))
    
#NBA Efficiency Metric = (Points)+(Rebounds)+(Steals)+(Assists)+(Blocked Shots)-(Turnovers)-(Missed Shots)#
#Win Score = (Points)+(Rebounds)+(Steals)+(½Assists)+(½Blocked Shots)-(Field Goal Attempts)-(Turnovers)-½(Free Throw Attempts)-½Personal Fouls#
#My equation = (((FG%*3P%*FT%)NBA Efficiency)(1-eFG%))(Win Score)#

# %%
full.sort_values(by=['Score'], ascending=False, inplace=True)
full.drop(['GS','MP','FG','FGA','TP','TPA','TWOP','TWOPA','TWOPP','eFGP','FT','FTA','FTP','ORB','DRB','STL','BLK','TOV','PF','Avg. Box +/-'], axis=1, inplace=True)
mvp = full.head(15)
mvp = mvp.copy()
mvp['Advanced Score'] = (mvp['PER']*mvp['Win Shares'])/100
mvp['MVP Score'] = round(mvp['Score']*mvp['Advanced Score'],2)
mvp.drop(['Score', 'Advanced Score'], axis=1, inplace=True)
mvp.sort_values(by=['MVP Score'], ascending=False, inplace=True)
mvp = mvp.rename({'FGP': 'FG%', 'TPP': '3P%', 'TRB': 'REB'}, axis='columns')

# %%
mvp
# Out:
#                     Player Pos Age   Tm   G    FG%    3P%   REB  AST   PTS  \
# 405           Nikola Jokić   C  26  DEN  74  0.583  0.337  13.8  7.9  27.1
# 214            Joel Embiid   C  27  PHI  68  0.499  0.371  11.7  4.2  30.6
# 15   Giannis Antetokounmpo  PF  27  MIL  67  0.553  0.293  11.6  5.8  29.9
# 205           Kevin Durant  PF  33  BRK  55  0.518  0.383   7.4  6.4  29.9
# 763     Karl-Anthony Towns   C  26  MIN  74  0.529  0.410   9.8  3.6  24.6
# 381           LeBron James  SF  37  LAL  56  0.524  0.359   8.2  6.2  30.3
# 838             Trae Young  PG  23  ATL  76  0.460  0.382   3.7  9.7  28.4
# 185            Luka Dončić  PG  22  DAL  65  0.457  0.353   9.1  8.7  28.4
# 734           Jayson Tatum  SF  23  BOS  76  0.453  0.353   8.0  4.4  26.9
# 173          DeMar DeRozan  PF  32  CHI  76  0.504  0.352   5.2  4.9  27.9
# 692          Pascal Siakam  PF  27  TOR  68  0.494  0.344   8.5  5.3  22.8
# 165          Stephen Curry  PG  33  GSW  64  0.437  0.380   5.2  6.3  25.5
# 545              Ja Morant  PG  22  MEM  57  0.493  0.344   5.7  6.7  27.4
# 72            Devin Booker  SG  25  PHO  68  0.466  0.383   5.0  4.8  26.8
# 369           Kyrie Irving  PG  29  BRK  29  0.469  0.418   4.4  5.8  27.4
#
#       PER  Win Shares  MVP Score
# 405  32.8        15.2     251.45
# 214  31.2        12.0     155.14
# 15   32.1        12.9     131.50
# 205  25.6         8.4      71.49
# 763  24.1        10.3      70.54
# 381  26.2         7.5      53.45
# 838  25.4        10.0      47.53
# 185  25.1         7.6      42.52
# 734  21.8         9.6      38.48
# 173  23.1         8.8      36.34
# 692  20.3         8.1      28.24
# 165  21.4         8.0      28.15
# 545  24.4         6.7      25.86
# 72   21.3         7.6      23.82
# 369  21.4         3.3      13.44

# %% [markdown]
# #### Visualization ####

# %% [markdown]
# ###### PER vs MVP Score Plot ######

# %%
x = mvp['PER']
y = mvp['MVP Score']

plt.scatter(x, y)
plt.title('PER vs. MVP Score', fontdict={'fontsize':16, 'fontweight':'bold'})
plt.xlabel('PER of Player', fontdict={'fontweight':'bold'})
plt.ylabel('MVP Score', fontdict={'fontweight':'bold'})
plt.show()

# %%
#plt.savefig('PER vs. MVP Score.png')

# %%
x = mvp['Win Shares']
y = mvp['MVP Score']

plt.scatter(x, y)
plt.title('Win Shares vs. MVP Score', fontdict={'fontsize':16, 'fontweight':'bold'})
plt.xlabel('Win Shares of Player', fontdict={'fontweight':'bold'})
plt.ylabel('MVP Score', fontdict={'fontweight':'bold'})
plt.show()

# %%
#plt.savefig('Win Shares vs. MVP Score.png')

# %%
mvp.set_index(['Player', 'Pos', 'Age', 'Tm', 'G', 'REB', 'AST', 'PTS', 'FG%', '3P%', 'PER', 'Win Shares', 'MVP Score'], inplace=True)
mvp
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Nikola Jokić, C, 26, DEN, 74, 13.8, 7.9, 27.1, 0.583, 0.337, 32.8, 15.2, 251.45), (Joel Embiid, C, 27, PHI, 68, 11.7, 4.2, 30.6, 0.499, 0.371, 31.2, 12.0, 155.14), (Giannis Antetokounmpo, PF, 27, MIL, 67, 11.6, 5.8, 29.9, 0.553, 0.293, 32.1, 12.9, 131.5), (Kevin Durant, PF, 33, BRK, 55, 7.4, 6.4, 29.9, 0.518, 0.383, 25.6, 8.4, 71.49), (Karl-Anthony Towns, C, 26, MIN, 74, 9.8, 3.6, 24.6, 0.529, 0.41, 24.1, 10.3, 70.54), (LeBron James, SF, 37, LAL, 56, 8.2, 6.2, 30.3, 0.524, 0.359, 26.2, 7.5, 53.45), (Trae Young, PG, 23, ATL, 76, 3.7, 9.7, 28.4, 0.46, 0.382, 25.4, 10.0, 47.53), (Luka Dončić, PG, 22, DAL, 65, 9.1, 8.7, 28.4, 0.457, 0.353, 25.1, 7.6, 42.52), (Jayson Tatum, SF, 23, BOS, 76, 8.0, 4.4, 26.9, 0.453, 0.353, 21.8, 9.6, 38.48), (DeMar DeRozan, PF, 32, CHI, 76, 5.2, 4.9, 27.9, 0.504, 0.352, 23.1, 8.8, 36.34), (Pascal Siakam, PF, 27, TOR, 68, 8.5, 5.3, 22.8, 0.494, 0.344, 20.3, 8.1, 28.24), (Stephen Curry, PG, 33, GSW, 64, 5.2, 6.3, 25.5, 0.437, 0.38, 21.4, 8.0, 28.15), (Ja Morant, PG, 22, MEM, 57, 5.7, 6.7, 27.4, 0.493, 0.344, 24.4, 6.7, 25.86), (Devin Booker, SG, 25, PHO, 68, 5.0, 4.8, 26.8, 0.466, 0.383, 21.3, 7.6, 23.82), (Kyrie Irving, PG, 29, BRK, 29, 4.4, 5.8, 27.4, 0.469, 0.418, 21.4, 3.3, 13.44)]

# %% [markdown]
# #### Exporting ####

# %% [markdown]
# ###### MVP Table to CSV ######

# %%
import datetime

current_date = datetime.datetime.now()
filename = str(current_date.month)+"-"+str(current_date.day)+"-"+str(current_date.year)
output = mvp.to_csv(str("MVP " + filename))
