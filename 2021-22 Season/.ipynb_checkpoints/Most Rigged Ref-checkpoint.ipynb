# %%
import pandas as pd 
import random as rnd
import numpy as np
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup

# %%
ref_tables = pd.read_excel(r'C:\Users\Home\Downloads\NBA Stat Padder\2021-22 Season\Rigged Ref Data\data.xlsx', index_col=0)  
len(ref_tables)
ref = ref_tables[0]
ref.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-fc9e330789e0> in <module>
#       1 ref_tables = pd.read_excel(r'C:\Users\Home\Downloads\NBA Stat Padder\2021-22 Season\Rigged Ref Data\data.xlsx', index_col=0)
#       2 len(ref_tables)
# ----> 3 ref = ref_tables[0]
#       4 ref.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 0

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
ref.columns
# Out:
# Index(['RANK', 'REFEREE', 'ROLE', 'EXPERIENCE (YEARS)', 'GAMES OFFICIATED',
#        'HOME TEAM WIN%', 'HOME TEAM POINTS DIFFERENTIAL',
#        'TOTAL POINTS PER GAME', 'CALLED FOULS PER GAME',
#        'FOUL% AGAINST ROAD TEAMS', 'FOUL% AGAINST HOME TEAMS',
#        'FOUL DIFFERENTIALFoul Differential Per GameSeason average of {Called Fouls Against Road Team} - {Called Fouls Against Home Team}. When foul differential is in positive figure, that referee (a.k.a. homey) favors home teams and is more prone to call against road teams.'],
#       dtype='object')

# %%
ref.drop('RANK', axis=1, inplace=True)
ref.drop('ROLE', axis=1, inplace=True)

# %%
ref[['EXPERIENCE (YEARS)', 'GAMES OFFICIATED', 'HOME TEAM WIN%', 'HOME TEAM POINTS DIFFERENTIAL', 'TOTAL POINTS PER GAME', 'CALLED FOULS PER GAME', 'FOUL% AGAINST ROAD TEAMS', 'FOUL% AGAINST HOME TEAMS', 'FOUL DIFFERENTIALFoul Differential Per GameSeason average of {Called Fouls Against Road Team} - {Called Fouls Against Home Team}. When foul differential is in positive figure, that referee (a.k.a. homey) favors home teams and is more prone to call against road teams.']] = ref[['EXPERIENCE (YEARS)', 'GAMES OFFICIATED', 'HOME TEAM WIN%', 'HOME TEAM POINTS DIFFERENTIAL', 'TOTAL POINTS PER GAME', 'CALLED FOULS PER GAME', 'FOUL% AGAINST ROAD TEAMS', 'FOUL% AGAINST HOME TEAMS', 'FOUL DIFFERENTIALFoul Differential Per GameSeason average of {Called Fouls Against Road Team} - {Called Fouls Against Home Team}. When foul differential is in positive figure, that referee (a.k.a. homey) favors home teams and is more prone to call against road teams.']].apply(pd.to_numeric)

# %%
ref.rename(
    columns={
        'FOUL DIFFERENTIALFoul Differential Per GameSeason average of {Called Fouls Against Road Team} - {Called Fouls Against Home Team}. When foul differential is in positive figure, that referee (a.k.a. homey) favors home teams and is more prone to call against road teams.': 'FOUL DIFFERENTIAL'
    }, inplace=True)

# %%
ref
# Out:
#               REFEREE  EXPERIENCE (YEARS)  GAMES OFFICIATED  HOME TEAM WIN%  \
# 0        James Capers                  26                13           0.462
# 1          Josh Tiven                  12                12           0.667
# 2     Kane Fitzgerald                  12                 9           0.667
# 3        Curtis Blair                  13                 8           0.500
# 4         Sean Wright                  16                12           0.500
# 5       Tony Brothers                  27                10           0.700
# 6          Ben Taylor                  10                 7           0.571
# 7          Zach Zarba                  18                 8           0.625
# 8           Ken Mauer                  33                 6           0.667
# 9          Tyler Ford                   7                 6           0.667
# 10       Scott Foster                  27                 8           0.750
# 11        Kevin Scott                  11                 6           0.500
# 12         Tre Maddox                  11                 5           0.400
# 13         Eric Lewis                  17                10           0.500
# 14       Mark Lindsay                  14                 5           0.800
# 15         John Goble                  14                 8           0.500
# 16      David Guthrie                  16                 9           0.556
# 17         Marc Davis                  23                 5           0.400
# 18        Rodney Mott                  26                 4           0.500
# 19        Sean Corbin                  28                 4           0.750
# 20        Brian Forte                  16                 4           0.250
# 21     James Williams                  12                 8           0.625
# 22  Courtney Kirkland                  22                 4           0.250
# 23       Bill Kennedy                  26                 5           0.600
# 24          Karl Lane                  11                 3           0.000
# 25         Marc Davis                  23                 9           0.556
# 26      Michael Smith                  28                 3           1.000
# 27         Eric Lewis                  17                 3           1.000
# 28         Zach Zarba                  18                 5           0.000
# 29       Bill Kennedy                  26                 3           0.667
# 30     Tom Washington                  30                 3           0.333
# 31  Courtney Kirkland                  22                 6           0.833
# 32          Ed Malloy                  19                 3           0.667
# 33         Pat Fraher                  26                 4           0.500
# 34         Pat Fraher                  26                 5           0.600
# 35       Scott Foster                  27                 4           1.000
# 36      Brent Barnaky                  12                 2           0.500
# 37       Kevin Cutler                  12                 2           0.500
# 38         John Goble                  14                 2           0.500
# 39          Leon Wood                  26                 2           1.000
# 40      David Guthrie                  16                 2           0.500
# 41    Derrick Collins                  22                 2           0.000
# 42      Michael Smith                  28                 2           0.500
# 43     Tom Washington                  30                 3           0.667
# 44          JB DeRosa                   4                 2           0.000
# 45          JB DeRosa                   4                 1           1.000
# 46          Ken Mauer                  33                 2           0.000
# 47    Derrick Collins                  22                 1           0.000
# 48          Ed Malloy                  19                 1           1.000
# 49         Scott Wall                  26                 1           1.000
# 50         Scott Wall                  26                 1           1.000
# 51        Sean Corbin                  28                 1           1.000
# 52        Rodney Mott                  26                 1           0.000
#
#     HOME TEAM POINTS DIFFERENTIAL  TOTAL POINTS PER GAME  \
# 0                           0.077                221.769
# 1                           9.500                223.333
# 2                           8.667                217.111
# 3                           0.625                220.625
# 4                          -1.500                226.167
# 5                           6.200                219.600
# 6                          -0.143                232.143
# 7                           6.625                216.375
# 8                           7.000                216.333
# 9                           0.667                206.000
# 10                         10.250                221.000
# 11                          3.333                229.667
# 12                         -0.200                225.800
# 13                          0.300                210.500
# 14                         11.200                234.800
# 15                         -0.500                223.250
# 16                          1.556                222.444
# 17                          2.400                215.200
# 18                         -1.000                223.000
# 19                          7.750                216.750
# 20                         -7.000                210.000
# 21                         10.500                221.250
# 22                         -6.250                212.250
# 23                          2.000                218.800
# 24                         -8.333                226.333
# 25                          3.889                218.111
# 26                         19.667                235.667
# 27                          5.333                250.667
# 28                         -9.600                220.800
# 29                         10.000                219.333
# 30                         -2.333                218.333
# 31                         10.333                217.667
# 32                          0.667                203.333
# 33                          2.750                203.750
# 34                          8.400                225.600
# 35                         12.000                207.500
# 36                         -4.000                231.000
# 37                         -4.500                247.500
# 38                         -2.500                216.500
# 39                         16.000                229.000
# 40                         -2.500                224.500
# 41                         -3.500                208.500
# 42                         -8.500                252.500
# 43                          9.000                214.333
# 44                         -5.000                202.000
# 45                         12.000                270.000
# 46                         -5.500                182.500
# 47                        -10.000                232.000
# 48                         17.000                241.000
# 49                         11.000                197.000
# 50                          9.000                193.000
# 51                         22.000                238.000
# 52                        -11.000                241.000
#
#     CALLED FOULS PER GAME  FOUL% AGAINST ROAD TEAMS  FOUL% AGAINST HOME TEAMS  \
# 0                  42.692                    49.910                    50.090
# 1                  40.167                    48.547                    51.452
# 2                  41.333                    49.732                    50.269
# 3                  40.125                    47.975                    52.025
# 4                  42.417                    51.866                    48.133
# 5                  36.400                    49.725                    50.275
# 6                  42.571                    52.685                    47.316
# 7                  43.250                    52.023                    47.977
# 8                  43.500                    50.575                    49.425
# 9                  37.167                    53.811                    46.188
# 10                 42.750                    50.877                    49.123
# 11                 39.500                    49.367                    50.633
# 12                 45.600                    50.439                    49.561
# 13                 40.100                    57.357                    42.643
# 14                 41.800                    47.847                    52.153
# 15                 42.750                    53.509                    46.491
# 16                 39.444                    50.141                    49.860
# 17                 35.000                    46.286                    53.714
# 18                 43.250                    50.867                    49.133
# 19                 49.750                    54.774                    45.226
# 20                 43.500                    48.276                    51.724
# 21                 38.125                    51.803                    48.197
# 22                 40.250                    50.311                    49.689
# 23                 40.000                    47.000                    53.000
# 24                 41.333                    47.581                    52.420
# 25                 35.111                    52.215                    47.785
# 26                 44.667                    52.238                    47.761
# 27                 50.333                    51.656                    48.345
# 28                 39.200                    52.041                    47.959
# 29                 41.333                    51.613                    48.387
# 30                 36.000                    45.370                    54.630
# 31                 40.833                    51.837                    48.164
# 32                 42.000                    45.238                    54.762
# 33                 38.250                    48.366                    51.634
# 34                 41.400                    52.657                    47.343
# 35                 40.500                    53.086                    46.914
# 36                 41.000                    43.902                    56.098
# 37                 48.500                    54.639                    45.361
# 38                 39.500                    50.633                    49.367
# 39                 42.000                    53.571                    46.429
# 40                 39.000                    50.000                    50.000
# 41                 36.000                    50.000                    50.000
# 42                 46.500                    53.763                    46.237
# 43                 43.000                    50.388                    49.612
# 44                 33.500                    49.254                    50.746
# 45                 50.000                    50.000                    50.000
# 46                 40.500                    50.617                    49.383
# 47                 40.000                    45.000                    55.000
# 48                 55.000                    54.545                    45.455
# 49                 40.000                    45.000                    55.000
# 50                 41.000                    51.220                    48.780
# 51                 43.000                    46.512                    53.488
# 52                 40.000                    45.000                    55.000
#
#     FOUL DIFFERENTIAL
# 0                -0.1
# 1                -1.2
# 2                -0.2
# 3                -1.6
# 4                 1.6
# 5                -0.2
# 6                 2.3
# 7                 1.8
# 8                 0.5
# 9                 2.8
# 10                0.8
# 11               -0.5
# 12                0.4
# 13                5.9
# 14               -1.8
# 15                3.0
# 16                0.1
# 17               -2.6
# 18                0.8
# 19                4.8
# 20               -1.5
# 21                1.4
# 22                0.3
# 23               -2.4
# 24               -2.0
# 25                1.6
# 26                2.0
# 27                1.7
# 28                1.6
# 29                1.3
# 30               -3.3
# 31                1.5
# 32               -4.0
# 33               -1.3
# 34                2.2
# 35                2.5
# 36               -5.0
# 37                4.5
# 38                0.5
# 39                3.0
# 40                0.0
# 41                0.0
# 42                3.5
# 43                0.3
# 44               -0.5
# 45                0.0
# 46                0.5
# 47               -4.0
# 48                5.0
# 49               -4.0
# 50                1.0
# 51               -3.0
# 52               -4.0

# %%
ref.columns
# Out:
# Index(['REFEREE', 'EXPERIENCE (YEARS)', 'GAMES OFFICIATED', 'HOME TEAM WIN%',
#        'HOME TEAM POINTS DIFFERENTIAL', 'TOTAL POINTS PER GAME',
#        'CALLED FOULS PER GAME', 'FOUL% AGAINST ROAD TEAMS',
#        'FOUL% AGAINST HOME TEAMS', 'FOUL DIFFERENTIAL'],
#       dtype='object')

# %%
ref.drop(ref[ref['GAMES OFFICIATED'] <= 3].index, inplace = True)

# %%
ref
# Out:
#               REFEREE  EXPERIENCE (YEARS)  GAMES OFFICIATED  HOME TEAM WIN%  \
# 0        James Capers                  26                13           0.462
# 1          Josh Tiven                  12                12           0.667
# 2     Kane Fitzgerald                  12                 9           0.667
# 3        Curtis Blair                  13                 8           0.500
# 4         Sean Wright                  16                12           0.500
# 5       Tony Brothers                  27                10           0.700
# 6          Ben Taylor                  10                 7           0.571
# 7          Zach Zarba                  18                 8           0.625
# 8           Ken Mauer                  33                 6           0.667
# 9          Tyler Ford                   7                 6           0.667
# 10       Scott Foster                  27                 8           0.750
# 11        Kevin Scott                  11                 6           0.500
# 12         Tre Maddox                  11                 5           0.400
# 13         Eric Lewis                  17                10           0.500
# 14       Mark Lindsay                  14                 5           0.800
# 15         John Goble                  14                 8           0.500
# 16      David Guthrie                  16                 9           0.556
# 17         Marc Davis                  23                 5           0.400
# 18        Rodney Mott                  26                 4           0.500
# 19        Sean Corbin                  28                 4           0.750
# 20        Brian Forte                  16                 4           0.250
# 21     James Williams                  12                 8           0.625
# 22  Courtney Kirkland                  22                 4           0.250
# 23       Bill Kennedy                  26                 5           0.600
# 25         Marc Davis                  23                 9           0.556
# 28         Zach Zarba                  18                 5           0.000
# 31  Courtney Kirkland                  22                 6           0.833
# 33         Pat Fraher                  26                 4           0.500
# 34         Pat Fraher                  26                 5           0.600
# 35       Scott Foster                  27                 4           1.000
#
#     HOME TEAM POINTS DIFFERENTIAL  TOTAL POINTS PER GAME  \
# 0                           0.077                221.769
# 1                           9.500                223.333
# 2                           8.667                217.111
# 3                           0.625                220.625
# 4                          -1.500                226.167
# 5                           6.200                219.600
# 6                          -0.143                232.143
# 7                           6.625                216.375
# 8                           7.000                216.333
# 9                           0.667                206.000
# 10                         10.250                221.000
# 11                          3.333                229.667
# 12                         -0.200                225.800
# 13                          0.300                210.500
# 14                         11.200                234.800
# 15                         -0.500                223.250
# 16                          1.556                222.444
# 17                          2.400                215.200
# 18                         -1.000                223.000
# 19                          7.750                216.750
# 20                         -7.000                210.000
# 21                         10.500                221.250
# 22                         -6.250                212.250
# 23                          2.000                218.800
# 25                          3.889                218.111
# 28                         -9.600                220.800
# 31                         10.333                217.667
# 33                          2.750                203.750
# 34                          8.400                225.600
# 35                         12.000                207.500
#
#     CALLED FOULS PER GAME  FOUL% AGAINST ROAD TEAMS  FOUL% AGAINST HOME TEAMS  \
# 0                  42.692                    49.910                    50.090
# 1                  40.167                    48.547                    51.452
# 2                  41.333                    49.732                    50.269
# 3                  40.125                    47.975                    52.025
# 4                  42.417                    51.866                    48.133
# 5                  36.400                    49.725                    50.275
# 6                  42.571                    52.685                    47.316
# 7                  43.250                    52.023                    47.977
# 8                  43.500                    50.575                    49.425
# 9                  37.167                    53.811                    46.188
# 10                 42.750                    50.877                    49.123
# 11                 39.500                    49.367                    50.633
# 12                 45.600                    50.439                    49.561
# 13                 40.100                    57.357                    42.643
# 14                 41.800                    47.847                    52.153
# 15                 42.750                    53.509                    46.491
# 16                 39.444                    50.141                    49.860
# 17                 35.000                    46.286                    53.714
# 18                 43.250                    50.867                    49.133
# 19                 49.750                    54.774                    45.226
# 20                 43.500                    48.276                    51.724
# 21                 38.125                    51.803                    48.197
# 22                 40.250                    50.311                    49.689
# 23                 40.000                    47.000                    53.000
# 25                 35.111                    52.215                    47.785
# 28                 39.200                    52.041                    47.959
# 31                 40.833                    51.837                    48.164
# 33                 38.250                    48.366                    51.634
# 34                 41.400                    52.657                    47.343
# 35                 40.500                    53.086                    46.914
#
#     FOUL DIFFERENTIAL
# 0                -0.1
# 1                -1.2
# 2                -0.2
# 3                -1.6
# 4                 1.6
# 5                -0.2
# 6                 2.3
# 7                 1.8
# 8                 0.5
# 9                 2.8
# 10                0.8
# 11               -0.5
# 12                0.4
# 13                5.9
# 14               -1.8
# 15                3.0
# 16                0.1
# 17               -2.6
# 18                0.8
# 19                4.8
# 20               -1.5
# 21                1.4
# 22                0.3
# 23               -2.4
# 25                1.6
# 28                1.6
# 31                1.5
# 33               -1.3
# 34                2.2
# 35                2.5

# %%
for index, row in ref.iterrows():
    ref.loc[index, "Home Rig Score"] = ref['HOME TEAM WIN%']*(ref['FOUL% AGAINST ROAD TEAMS']*ref['HOME TEAM POINTS DIFFERENTIAL'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-ed87e2d1271d> in <module>
#       1 for index, row in ref.iterrows():
# ----> 2     ref.loc[index, "Home Rig Score"] = ref['HOME TEAM WIN%']*(ref['FOUL% AGAINST ROAD TEAMS']*ref['HOME TEAM POINTS DIFFERENTIAL'])
#       3
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     690
#     691         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 692         iloc._setitem_with_indexer(indexer, value, self.name)
#     693
#     694     def _validate_key(self, key, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1602                             indexer, self.obj.axes
#    1603                         )
# -> 1604                         self._setitem_with_indexer(new_indexer, value, name)
#    1605
#    1606                         return
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1633         if take_split_path:
#    1634             # We have to operate column-wise
# -> 1635             self._setitem_with_indexer_split_path(indexer, value, name)
#    1636         else:
#    1637             self._setitem_single_block(indexer, value, name)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer_split_path(self, indexer, value, name)
#    1652
#    1653         if isinstance(value, ABCSeries) and name != "iloc":
# -> 1654             value = self._align_series(indexer, value)
#    1655
#    1656         # Ensure we have something we can iterate over
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _align_series(self, indexer, ser, multiindex_indexer)
#    2028             return ser.reindex(ax)._values
#    2029
# -> 2030         raise ValueError("Incompatible indexer with Series")
#    2031
#    2032     def _align_frame(self, indexer, df: "DataFrame"):
#
# ValueError: Incompatible indexer with Series

# %%
ref.sort_values(by=['Home Rig Score'], ascending=False, inplace=True)
ref.drop(['TOTAL POINTS PER GAME'], axis=1, inplace=True)
ref['FOULS CALLED AGAINST ROAD TEAM'] = ref['FOUL% AGAINST ROAD TEAMS']*ref['CALLED FOULS PER GAME']
ref['FOULS CALLED AGAINST HOME TEAM'] = ref['FOUL% AGAINST HOME TEAMS']*ref['CALLED FOULS PER GAME']
ref['HOME GAMES WON'] = ref['HOME TEAM WIN%']*ref['GAMES OFFICIATED']
ref

# %%
x = ref['FOULS CALLED AGAINST ROAD TEAM']
y = ref['HOME GAMES WON']

plt.scatter(x, y)
plt.title('FOULS CALLED AGAINST ROAD TEAMS vs. HOME GAMES WON', fontdict={'fontsize':16, 'fontweight':'bold'})
plt.xlabel('FOULS CALLED VS ROAD TEAM', fontdict={'fontweight':'bold'})
plt.ylabel('HOME TEAM WINS', fontdict={'fontweight':'bold'})
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'FOULS CALLED AGAINST ROAD TEAM'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-6fe0cbad64fb> in <module>()
# ----> 1 x = ref['FOULS CALLED AGAINST ROAD TEAM']
#       2 y = ref['HOME GAMES WON']
#       3
#       4 plt.scatter(x, y)
#       5 plt.title('FOULS CALLED AGAINST ROAD TEAMS vs. HOME GAMES WON', fontdict={'fontsize':16, 'fontweight':'bold'})
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'FOULS CALLED AGAINST ROAD TEAM'

# %%
ref.set_index(['REFEREE	EXPERIENCE (YEARS)', 'GAMES OFFICIATED', 'HOME TEAM WIN%', 'HOME TEAM POINTS DIFFERENTIAL', 'CALLED FOULS PER GAME', 'FOUL% AGAINST ROAD TEAMS', 'FOUL% AGAINST HOME TEAMS', 'FOUL DIFFERENTIAL', 'HOME RIG SCORE'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-8703bd86e756> in <module>()
# ----> 1 ref.set_index(['REFEREE EXPERIENCE (YEARS)', 'GAMES OFFICIATED', 'HOME TEAM WIN%', 'HOME TEAM POINTS DIFFERENTIAL', 'CALLED FOULS PER GAME', 'FOUL% AGAINST ROAD TEAMS', 'FOUL% AGAINST HOME TEAMS', 'FOUL DIFFERENTIAL', 'HOME RIG SCORE'], inplace=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4553
#    4554         if missing:
# -> 4555             raise KeyError(f"None of {missing} are in the columns")
#    4556
#    4557         if inplace:
#
# KeyError: "None of ['REFEREE\\tEXPERIENCE (YEARS)', 'HOME RIG SCORE'] are in the columns"

# %%
ref
