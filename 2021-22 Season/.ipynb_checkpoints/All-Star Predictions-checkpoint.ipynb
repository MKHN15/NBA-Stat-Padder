# %% [markdown]
# # All-Star Predictions #

# %%
# -*- coding: utf-8 -*-#
"""
Created by MinhKhang Nguyen
July 27 2021 7:37 PM - August 6 2021 2:08 AM
"""
# Out:
# '\nCreated by MinhKhang Nguyen\nJuly 27 2021 7:37 PM - August 6 2021 2:08 AM\n'

# %%
import pandas as pd 
import random as rnd
import numpy as np
import matplotlib.pyplot as plt

# %%
import ssl
ssl._create_default_https_econtext = ssl._create_unverified_context

# %% [markdown]
# #### Importing Data ####

# %% [markdown]
# ###### Importing Normal Stats ######

# %%
html_url = "https://www.basketball-reference.com/leagues/NBA_2022_per_game.html"
nba_tables = pd.read_html(html_url)
len(nba_tables)
nba = nba_tables[0]
nba.head(30)
# Out:
#     Rk                    Player  Pos  Age   Tm   G  GS    MP    FG   FGA  \
# 0    1          Precious Achiuwa    C   22  TOR  42  22  24.1   3.3   7.7
# 1    2              Steven Adams    C   28  MEM  50  49  26.2   2.5   4.9
# 2    3               Bam Adebayo    C   24  MIA  28  28  33.3   6.8  13.0
# 3    4              Santi Aldama   PF   21  MEM  27   0  10.3   1.4   3.6
# 4    5         LaMarcus Aldridge    C   36  BRK  36  11  22.9   5.8  10.4
# 5    6  Nickeil Alexander-Walker   SG   23  NOP  49  19  26.5   4.8  12.8
# 6    7             Grayson Allen   SG   26  MIL  44  43  28.3   4.1   9.6
# 7    8             Jarrett Allen    C   23  CLE  45  45  32.6   6.6   9.8
# 8    9             Jose Alvarado   PG   23  NOP  25   1  12.0   1.6   4.2
# 9   10           Justin Anderson   SF   28  TOT   6   0  12.8   1.0   3.2
# 10  10           Justin Anderson   SF   28  CLE   3   0  15.7   1.3   2.7
# 11  10           Justin Anderson   SF   28  IND   3   0  10.0   0.7   3.7
# 12  11             Kyle Anderson   PF   28  MEM  41   8  22.2   3.1   7.2
# 13  12     Giannis Antetokounmpo   PF   27  MIL  43  43  32.7  10.0  18.6
# 14  13    Thanasis Antetokounmpo   SF   29  MIL  31   5  11.0   1.2   2.6
# 15  14           Carmelo Anthony   PF   37  LAL  50   3  26.5   4.6  10.5
# 16  15              Cole Anthony   PG   21  ORL  39  39  33.3   6.0  15.5
# 17  16                OG Anunoby   SF   24  TOR  36  36  37.2   6.9  15.6
# 18  17              Trevor Ariza   SF   36  LAL  15   6  18.4   1.1   3.4
# 19  18             D.J. Augustin   PG   34  HOU  34   2  15.0   1.6   4.0
# 20  19               Deni Avdija   SF   21  WAS  51   6  22.7   2.7   6.2
# 21  20                Joel Ayayi   SG   21  WAS   7   0   2.9   0.1   0.9
# 22  Rk                    Player  Pos  Age   Tm   G  GS    MP    FG   FGA
# 23  21             Deandre Ayton    C   23  PHO  30  30  29.6   7.1  11.1
# 24  22            Udoka Azubuike    C   22  UTA  11   3   9.3   1.4   2.2
# 25  23         Marvin Bagley III   PF   22  SAC  30  17  21.9   3.8   8.2
# 26  24               LaMelo Ball   PG   20  CHO  46  46  32.3   7.1  16.7
# 27  25                Lonzo Ball   PG   24  CHI  35  35  34.6   4.6  10.9
# 28  26                  Mo Bamba    C   23  ORL  42  40  26.5   4.0   8.5
# 29  27              Desmond Bane   SF   23  MEM  50  50  30.2   6.8  14.6
#
#     ...    FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0   ...   .545  2.3  5.0   7.2  1.2  0.5  0.6  1.0  2.1   7.8
# 1   ...   .573  4.4  5.1   9.5  3.0  1.0  0.7  1.6  1.7   6.5
# 2   ...   .764  2.7  7.3  10.0  3.5  1.5  0.6  3.0  3.3  18.1
# 3   ...   .600  0.9  1.5   2.4  0.5  0.1  0.3  0.3  1.0   3.3
# 4   ...   .853  1.5  4.1   5.6  0.9  0.4  1.1  0.9  1.8  13.4
# 5   ...   .726  0.7  2.6   3.3  2.8  0.8  0.4  1.7  1.7  12.9
# 6   ...   .870  0.6  3.0   3.5  1.5  0.8  0.3  0.6  1.4  11.8
# 7   ...   .691  3.5  7.4  11.0  1.9  0.8  1.4  1.8  1.8  16.2
# 8   ...   .632  0.4  0.9   1.3  1.9  1.1  0.1  0.2  1.4   4.3
# 9   ...   .857  0.3  1.3   1.7  1.5  0.3  0.2  0.5  1.5   3.5
# 10  ...   .750  0.0  2.0   2.0  2.0  0.3  0.0  0.7  1.3   4.3
# 11  ...  1.000  0.7  0.7   1.3  1.0  0.3  0.3  0.3  1.7   2.7
# 12  ...   .645  0.9  4.3   5.2  2.7  1.1  0.6  1.0  1.5   7.9
# 13  ...   .722  1.8  9.5  11.3  6.0  1.0  1.4  3.5  3.3  28.9
# 14  ...   .625  1.0  1.5   2.5  0.6  0.4  0.3  0.6  1.8   3.0
# 15  ...   .824  0.8  3.3   4.2  1.0  0.7  0.8  0.9  2.2  13.4
# 16  ...   .844  0.6  5.3   5.9  6.1  0.9  0.3  2.7  2.7  17.8
# 17  ...   .752  1.5  4.0   5.6  2.7  1.6  0.6  1.8  3.0  18.4
# 18  ...   .667  0.3  2.8   3.1  1.1  0.5  0.2  0.5  0.7   3.5
# 19  ...   .868  0.2  1.0   1.2  2.2  0.3  0.0  1.3  0.5   5.4
# 20  ...   .740  0.7  4.2   4.8  1.6  0.7  0.6  0.9  2.2   7.4
# 21  ...    NaN  0.1  0.3   0.4  0.6  0.0  0.0  0.0  0.0   0.3
# 22  ...    FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 23  ...   .720  2.7  7.7  10.4  1.6  0.8  0.8  1.7  2.2  16.2
# 24  ...   .400  0.6  2.4   3.0  0.0  0.1  0.5  0.6  0.9   2.9
# 25  ...   .745  2.2  4.9   7.2  0.6  0.3  0.4  0.7  1.7   9.3
# 26  ...   .875  1.6  5.5   7.2  7.6  1.5  0.4  3.1  3.1  19.8
# 27  ...   .750  1.0  4.4   5.4  5.1  1.8  0.9  2.3  2.4  13.0
# 28  ...   .773  2.1  5.9   8.0  1.3  0.6  2.0  1.3  2.5  10.2
# 29  ...   .895  0.5  3.8   4.4  2.4  1.1  0.5  1.5  2.4  18.0
#
# [30 rows x 30 columns]

# %%
nba.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %% [markdown]
# ###### Importing Advanced Stats ######

# %%
html_url = "https://www.basketball-reference.com/leagues/NBA_2022_advanced.html"
advanced_tables = pd.read_html(html_url)
len(advanced_tables)
advanced = advanced_tables[0]
advanced.head(30)
# Out:
#     Rk                    Player  Pos  Age   Tm   G    MP   PER   TS%  3PAr  \
# 0    1          Precious Achiuwa    C   22  TOR  42  1013  11.9  .464  .161
# 1    2              Steven Adams    C   28  MEM  50  1311  16.6  .541  .000
# 2    3               Bam Adebayo    C   24  MIA  28   933  19.9  .582  .008
# 3    4              Santi Aldama   PF   21  MEM  27   277   8.6  .425  .402
# 4    5         LaMarcus Aldridge    C   36  BRK  36   825  20.2  .601  .102
# 5    6  Nickeil Alexander-Walker   SG   23  NOP  49  1299  10.8  .472  .480
# 6    7             Grayson Allen   SG   26  MIL  44  1246  13.1  .582  .690
# 7    8             Jarrett Allen    C   23  CLE  45  1468  23.2  .693  .020
# 8    9             Jose Alvarado   PG   23  NOP  25   299  15.3  .476  .419
# 9   10           Justin Anderson   SF   28  TOT   6    77   8.4  .476  .789
# 10  10           Justin Anderson   SF   28  CLE   3    47  10.9  .666  .750
# 11  10           Justin Anderson   SF   28  IND   3    30   4.6  .325  .818
# 12  11             Kyle Anderson   PF   28  MEM  41   911  14.3  .498  .253
# 13  12     Giannis Antetokounmpo   PF   27  MIL  43  1408  31.1  .617  .207
# 14  13    Thanasis Antetokounmpo   SF   29  MIL  31   341   9.7  .497  .134
# 15  14           Carmelo Anthony   PF   37  LAL  50  1327  15.1  .583  .565
# 16  15              Cole Anthony   PG   21  ORL  39  1298  14.7  .511  .439
# 17  16                OG Anunoby   SF   24  TOR  36  1338  15.7  .549  .448
# 18  17              Trevor Ariza   SF   36  LAL  15   276   6.8  .485  .843
# 19  18             D.J. Augustin   PG   34  HOU  34   510  10.0  .596  .706
# 20  19               Deni Avdija   SF   21  WAS  51  1159  11.7  .542  .449
# 21  20                Joel Ayayi   SG   21  WAS   7    20   3.6  .167  .167
# 22  Rk                    Player  Pos  Age   Tm   G    MP   PER   TS%  3PAr
# 23  21             Deandre Ayton    C   23  PHO  30   889  22.0  .658  .024
# 24  22            Udoka Azubuike    C   22  UTA  11   102  12.0  .611  .000
# 25  23         Marvin Bagley III   PF   22  SAC  30   656  14.7  .521  .252
# 26  24               LaMelo Ball   PG   20  CHO  46  1486  20.2  .543  .426
# 27  25                Lonzo Ball   PG   24  CHI  35  1212  14.7  .575  .679
# 28  26                  Mo Bamba    C   23  ORL  42  1115  16.2  .568  .436
# 29  27              Desmond Bane   SF   23  MEM  50  1512  17.2  .587  .476
#
#     ... Unnamed: 19   OWS   DWS    WS   WS/48 Unnamed: 24  OBPM  DBPM   BPM  \
# 0   ...         NaN   0.1   1.1   1.2    .057         NaN  -2.5  -0.7  -3.3
# 1   ...         NaN   2.1   1.7   3.8    .140         NaN   0.5   0.5   1.0
# 2   ...         NaN   1.4   1.6   3.1    .158         NaN   0.9   1.9   2.8
# 3   ...         NaN  -0.1   0.2   0.1    .024         NaN  -4.7  -2.1  -6.7
# 4   ...         NaN   1.7   0.8   2.5    .146         NaN   1.5  -0.7   0.8
# 5   ...         NaN  -1.0   0.8  -0.2  -0.009         NaN  -1.4  -1.7  -3.1
# 6   ...         NaN   1.8   1.1   3.0    .114         NaN   0.6  -0.2   0.4
# 7   ...         NaN   4.6   2.7   7.3    .240         NaN   2.8   1.3   4.1
# 8   ...         NaN   0.3   0.4   0.7    .120         NaN  -1.3   3.4   2.0
# 9   ...         NaN   0.0   0.1   0.1    .064         NaN  -3.9  -0.4  -4.2
# 10  ...         NaN   0.1   0.1   0.1    .138         NaN  -2.9   0.3  -2.6
# 11  ...         NaN  -0.1   0.0   0.0  -0.052         NaN  -5.4  -1.5  -6.9
# 12  ...         NaN   0.6   1.4   2.0    .103         NaN  -0.8   1.5   0.7
# 13  ...         NaN   5.4   2.6   8.0    .272         NaN   6.9   3.5  10.5
# 14  ...         NaN   0.1   0.4   0.5    .069         NaN  -5.0   0.7  -4.3
# 15  ...         NaN   1.8   1.3   3.1    .111         NaN   0.7  -0.6   0.1
# 16  ...         NaN   0.2   1.0   1.2    .044         NaN   0.2  -0.8  -0.6
# 17  ...         NaN   1.7   1.3   3.0    .106         NaN   0.9   0.1   1.0
# 18  ...         NaN   0.0   0.2   0.2    .034         NaN  -3.0  -0.2  -3.1
# 19  ...         NaN   0.3  -0.1   0.2    .019         NaN  -1.2  -3.1  -4.3
# 20  ...         NaN   0.6   1.2   1.8    .074         NaN  -2.0   0.9  -1.1
# 21  ...         NaN   0.0   0.0   0.0  -0.092         NaN  -4.1  -1.8  -5.9
# 22  ...         NaN   OWS   DWS    WS   WS/48         NaN  OBPM  DBPM   BPM
# 23  ...         NaN   2.2   1.7   3.9    .208         NaN   2.4   1.1   3.5
# 24  ...         NaN   0.0   0.1   0.1    .069         NaN  -4.4  -0.7  -5.1
# 25  ...         NaN   0.6   0.4   1.0    .074         NaN  -0.8  -2.7  -3.5
# 26  ...         NaN   2.4   1.4   3.8    .121         NaN   3.4   0.1   3.5
# 27  ...         NaN   1.0   1.5   2.5    .097         NaN   1.2   1.5   2.7
# 28  ...         NaN   0.9   1.6   2.5    .106         NaN  -0.6   1.1   0.5
# 29  ...         NaN   2.7   1.6   4.3    .136         NaN   2.3  -0.2   2.1
#
#     VORP
# 0   -0.3
# 1    1.0
# 2    1.1
# 3   -0.3
# 4    0.6
# 5   -0.3
# 6    0.7
# 7    2.3
# 8    0.3
# 9    0.0
# 10   0.0
# 11   0.0
# 12   0.6
# 13   4.5
# 14  -0.2
# 15   0.7
# 16   0.5
# 17   1.0
# 18  -0.1
# 19  -0.3
# 20   0.3
# 21   0.0
# 22  VORP
# 23   1.2
# 24  -0.1
# 25  -0.3
# 26   2.1
# 27   1.4
# 28   0.7
# 29   1.6
#
# [30 rows x 29 columns]

# %%
advanced.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr',
#        'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
#        'Unnamed: 19', 'OWS', 'DWS', 'WS', 'WS/48', 'Unnamed: 24', 'OBPM',
#        'DBPM', 'BPM', 'VORP'],
#       dtype='object')

# %% [markdown]
# #### Cleaning DataFrame ####

# %% [markdown]
# ###### Cleaning Normal Stats ######

# %%
#renames columns to strings only#
nba.rename(
    columns={
        'FG%': 'FGP',
        '3P': 'TP',
        '3PA': 'TPA',
        '3P%': 'TPP',
        '2P': 'TWOP',
        '2PA': 'TWOPA',
        '2P%': 'TWOPP',
        'eFG%': 'eFGP',
        'FT%': 'FTP'
    }, inplace=True)

#removing duplicate players (stats of players that played on different teams)#
nba.drop_duplicates(subset=['Player'], keep=False, inplace=True)
#Dropping "Rk" Column#
nba.drop('Rk', axis=1, inplace=True)

#replacing NaN with 0#
nba.fillna(0, inplace=True)

nba[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]] = nba[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]].apply(pd.to_numeric)
nba
# Out:
#                 Player Pos Age   Tm   G  GS    MP   FG   FGA    FGP  ...  \
# 0     Precious Achiuwa   C  22  TOR  42  22  24.1  3.3   7.7  0.425  ...
# 1         Steven Adams   C  28  MEM  50  49  26.2  2.5   4.9  0.514  ...
# 2          Bam Adebayo   C  24  MIA  28  28  33.3  6.8  13.0  0.525  ...
# 3         Santi Aldama  PF  21  MEM  27   0  10.3  1.4   3.6  0.381  ...
# 4    LaMarcus Aldridge   C  36  BRK  36  11  22.9  5.8  10.4  0.555  ...
# ..                 ...  ..  ..  ...  ..  ..   ...  ...   ...    ...  ...
# 676     Thaddeus Young  PF  33  SAS  26   1  14.2  2.8   4.9  0.578  ...
# 677         Trae Young  PG  23  ATL  47  47  34.6  9.4  20.6  0.457  ...
# 678     Omer Yurtseven   C  23  MIA  37  10  14.8  2.7   5.1  0.524  ...
# 679        Cody Zeller   C  29  POR  27   0  13.1  1.9   3.3  0.567  ...
# 680        Ivica Zubac   C  24  LAC  48  48  24.3  3.7   5.6  0.652  ...
#
#        FTP  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0    0.545  2.3  5.0   7.2  1.2  0.5  0.6  1.0  2.1   7.8
# 1    0.573  4.4  5.1   9.5  3.0  1.0  0.7  1.6  1.7   6.5
# 2    0.764  2.7  7.3  10.0  3.5  1.5  0.6  3.0  3.3  18.1
# 3    0.600  0.9  1.5   2.4  0.5  0.1  0.3  0.3  1.0   3.3
# 4    0.853  1.5  4.1   5.6  0.9  0.4  1.1  0.9  1.8  13.4
# ..     ...  ...  ...   ...  ...  ...  ...  ...  ...   ...
# 676  0.455  1.5  2.0   3.6  2.3  0.9  0.3  1.2  1.5   6.1
# 677  0.892  0.6  3.4   4.0  9.3  1.0  0.1  4.1  1.6  27.9
# 678  0.640  1.8  4.5   6.2  1.1  0.4  0.5  0.9  1.8   6.2
# 679  0.776  1.9  2.8   4.6  0.8  0.3  0.2  0.7  2.1   5.2
# 680  0.735  2.6  5.4   8.0  1.3  0.5  1.0  1.4  2.5   9.6
#
# [562 rows x 29 columns]

# %% [markdown]
# ###### Cleaning Advanced Stats ######

# %%
advanced.rename(
    columns={
        'WS': 'Win Shares',
        'BPM': 'Avg. Box +/-'
    }, inplace=True)

#removing duplicate players (stats of players that played on different teams)#
advanced.drop_duplicates(subset=['Player'], keep=False, inplace=True)
#Dropping "Rk" Column#
advanced.drop('Rk', axis=1, inplace=True)

#replacing NaN with 0#
advanced.fillna(0, inplace=True)

advanced[['Age', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr','ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%','Unnamed: 19', 'OWS', 'DWS', 'Win Shares', 'WS/48', 'Unnamed: 24', 'OBPM','DBPM', 'Avg. Box +/-', 'VORP']] = advanced[['Age', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr','ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%','Unnamed: 19', 'OWS', 'DWS', 'Win Shares', 'WS/48', 'Unnamed: 24', 'OBPM','DBPM', 'Avg. Box +/-', 'VORP']].apply(pd.to_numeric)
advanced.drop(['Player','Pos','Age','Tm','G','MP','3PAr','FTr','ORB%','DRB%','TRB%','AST%','STL%','BLK%','TOV%','USG%','OWS','DWS','WS/48','OBPM','DBPM','TS%','VORP','Unnamed: 19','Unnamed: 24'], axis=1, inplace=True)
shorter_advanced = advanced
shorter_advanced
# Out:
#       PER  Win Shares  Avg. Box +/-
# 0    11.9         1.2          -3.3
# 1    16.6         3.8           1.0
# 2    19.9         3.1           2.8
# 3     8.6         0.1          -6.7
# 4    20.2         2.5           0.8
# ..    ...         ...           ...
# 676  19.0         1.0           2.3
# 677  25.1         5.4           4.4
# 678  18.1         1.7          -0.7
# 679  17.7         1.2          -1.9
# 680  18.7         4.7           1.0
#
# [562 rows x 3 columns]

# %%
nba = nba.loc[~nba.index.duplicated(keep='first')]
shorter_advanced = shorter_advanced.loc[~shorter_advanced.index.duplicated(keep='first')]
full = pd.concat([nba, shorter_advanced], axis=1)
full
# Out:
#                 Player Pos Age   Tm   G  GS    MP   FG   FGA    FGP  ...  \
# 0     Precious Achiuwa   C  22  TOR  42  22  24.1  3.3   7.7  0.425  ...
# 1         Steven Adams   C  28  MEM  50  49  26.2  2.5   4.9  0.514  ...
# 2          Bam Adebayo   C  24  MIA  28  28  33.3  6.8  13.0  0.525  ...
# 3         Santi Aldama  PF  21  MEM  27   0  10.3  1.4   3.6  0.381  ...
# 4    LaMarcus Aldridge   C  36  BRK  36  11  22.9  5.8  10.4  0.555  ...
# ..                 ...  ..  ..  ...  ..  ..   ...  ...   ...    ...  ...
# 676     Thaddeus Young  PF  33  SAS  26   1  14.2  2.8   4.9  0.578  ...
# 677         Trae Young  PG  23  ATL  47  47  34.6  9.4  20.6  0.457  ...
# 678     Omer Yurtseven   C  23  MIA  37  10  14.8  2.7   5.1  0.524  ...
# 679        Cody Zeller   C  29  POR  27   0  13.1  1.9   3.3  0.567  ...
# 680        Ivica Zubac   C  24  LAC  48  48  24.3  3.7   5.6  0.652  ...
#
#       TRB  AST  STL  BLK  TOV   PF   PTS   PER  Win Shares  Avg. Box +/-
# 0     7.2  1.2  0.5  0.6  1.0  2.1   7.8  11.9         1.2          -3.3
# 1     9.5  3.0  1.0  0.7  1.6  1.7   6.5  16.6         3.8           1.0
# 2    10.0  3.5  1.5  0.6  3.0  3.3  18.1  19.9         3.1           2.8
# 3     2.4  0.5  0.1  0.3  0.3  1.0   3.3   8.6         0.1          -6.7
# 4     5.6  0.9  0.4  1.1  0.9  1.8  13.4  20.2         2.5           0.8
# ..    ...  ...  ...  ...  ...  ...   ...   ...         ...           ...
# 676   3.6  2.3  0.9  0.3  1.2  1.5   6.1  19.0         1.0           2.3
# 677   4.0  9.3  1.0  0.1  4.1  1.6  27.9  25.1         5.4           4.4
# 678   6.2  1.1  0.4  0.5  0.9  1.8   6.2  18.1         1.7          -0.7
# 679   4.6  0.8  0.3  0.2  0.7  2.1   5.2  17.7         1.2          -1.9
# 680   8.0  1.3  0.5  1.0  1.4  2.5   9.6  18.7         4.7           1.0
#
# [562 rows x 32 columns]

# %%
full['Conf'] = full['Tm'].apply(lambda x: 'West' if x in ['DAL','DEN','GSW','HOU','LAC','LAL','MEM','MIN','NOP','OKC','PHO','POR','SAC','SAS','UTA'] else 'East')
full
# Out:
#                 Player Pos Age   Tm   G  GS    MP   FG   FGA    FGP  ...  AST  \
# 0     Precious Achiuwa   C  22  TOR  42  22  24.1  3.3   7.7  0.425  ...  1.2
# 1         Steven Adams   C  28  MEM  50  49  26.2  2.5   4.9  0.514  ...  3.0
# 2          Bam Adebayo   C  24  MIA  28  28  33.3  6.8  13.0  0.525  ...  3.5
# 3         Santi Aldama  PF  21  MEM  27   0  10.3  1.4   3.6  0.381  ...  0.5
# 4    LaMarcus Aldridge   C  36  BRK  36  11  22.9  5.8  10.4  0.555  ...  0.9
# ..                 ...  ..  ..  ...  ..  ..   ...  ...   ...    ...  ...  ...
# 676     Thaddeus Young  PF  33  SAS  26   1  14.2  2.8   4.9  0.578  ...  2.3
# 677         Trae Young  PG  23  ATL  47  47  34.6  9.4  20.6  0.457  ...  9.3
# 678     Omer Yurtseven   C  23  MIA  37  10  14.8  2.7   5.1  0.524  ...  1.1
# 679        Cody Zeller   C  29  POR  27   0  13.1  1.9   3.3  0.567  ...  0.8
# 680        Ivica Zubac   C  24  LAC  48  48  24.3  3.7   5.6  0.652  ...  1.3
#
#      STL  BLK  TOV   PF   PTS   PER  Win Shares  Avg. Box +/-  Conf
# 0    0.5  0.6  1.0  2.1   7.8  11.9         1.2          -3.3  East
# 1    1.0  0.7  1.6  1.7   6.5  16.6         3.8           1.0  West
# 2    1.5  0.6  3.0  3.3  18.1  19.9         3.1           2.8  East
# 3    0.1  0.3  0.3  1.0   3.3   8.6         0.1          -6.7  West
# 4    0.4  1.1  0.9  1.8  13.4  20.2         2.5           0.8  East
# ..   ...  ...  ...  ...   ...   ...         ...           ...   ...
# 676  0.9  0.3  1.2  1.5   6.1  19.0         1.0           2.3  West
# 677  1.0  0.1  4.1  1.6  27.9  25.1         5.4           4.4  East
# 678  0.4  0.5  0.9  1.8   6.2  18.1         1.7          -0.7  East
# 679  0.3  0.2  0.7  2.1   5.2  17.7         1.2          -1.9  West
# 680  0.5  1.0  1.4  2.5   9.6  18.7         4.7           1.0  West
#
# [562 rows x 33 columns]

# %% [markdown]
# #### Filtering DataFrame ####

# %% [markdown]
# ###### Filtering Normal Stats ######

# %%
full.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FGP', 'TP',
#        'TPA', 'TPP', 'TWOP', 'TWOPA', 'TWOPP', 'eFGP', 'FT', 'FTA', 'FTP',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'PER',
#        'Win Shares', 'Avg. Box +/-', 'Conf'],
#       dtype='object')

# %%
full[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]] = nba[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]].apply(pd.to_numeric)

# %%
full.drop(full[full['G'] <= 10].index, inplace = True)
full.drop(full[full['TP'] <= 0.1].index, inplace = True)
full.drop(full[full['TPA'] <= 0.1].index, inplace = True)
full.drop(full[full['TPP'] <= 0.1].index, inplace = True)
full.drop(full[full['PTS'] <= 14].index, inplace = True)

# %%
west = full[full["Conf"].str.contains("West")]
east = full[full["Conf"].str.contains("East")]

# %%
west[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]] = west[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]].apply(pd.to_numeric)
# Out:
# C:\Users\Home\anaconda3\lib\site-packages\pandas\core\frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
east[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]] = east[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]].apply(pd.to_numeric)

# %% [markdown]
# #### Processing the Data ####

# %%
for index, row in full.iterrows():
    west.loc[index, "Score"] = (((row['FGP']*row['TPP']*row['FTP'])*(row['PTS']+row['TRB']+row['STL']+row['AST']+row['BLK']-row['TOV']-(row['FGA']-row['FG']))*(1-row['eFGP']))*(row['PTS']+row['TRB']+row['STL']+(0.5*row['AST'])+(0.5*row['BLK'])-row['FGA']-row['TOV']-(0.5*row['FTA'])-(0.5*row['PF'])))
# Out:
# C:\Users\Home\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
west.sort_values(by=['Score'], ascending=False, inplace=True)
west.drop(['GS','MP','FG','FGA','TP','TPA','TWOP','TWOPA','TWOPP','eFGP','FT','FTA','FTP','ORB','DRB','STL','BLK','TOV','PF','Avg. Box +/-'], axis=1, inplace=True)
west['Advanced Score'] = (west['PER']*west['Win Shares'])/100
west['ASG Score'] = round(west['Score']*west['Advanced Score'],2)
west.drop(['Score', 'Advanced Score'], axis=1, inplace=True)
west.sort_values(by=['ASG Score'], ascending=False, inplace=True)
west = west.rename({'FGP': 'FG%', 'TPP': '3P%', 'TRB': 'REB'}, axis='columns')
west = west.dropna()

# %%
for index, row in full.iterrows():
    east.loc[index, "Score"] = (((row['FGP']*row['TPP']*row['FTP'])*(row['PTS']+row['TRB']+row['STL']+row['AST']+row['BLK']-row['TOV']-(row['FGA']-row['FG']))*(1-row['eFGP']))*(row['PTS']+row['TRB']+row['STL']+(0.5*row['AST'])+(0.5*row['BLK'])-row['FGA']-row['TOV']-(0.5*row['FTA'])-(0.5*row['PF'])))
# Out:
# C:\Users\Home\anaconda3\lib\site-packages\pandas\core\indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\Home\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\Home\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
east.sort_values(by=['Score'], ascending=False, inplace=True)
east.drop(['GS','MP','FG','FGA','TP','TPA','TWOP','TWOPA','TWOPP','eFGP','FT','FTA','FTP','ORB','DRB','STL','BLK','TOV','PF','Avg. Box +/-'], axis=1, inplace=True)
east['Advanced Score'] = (east['PER']*east['Win Shares'])/100
east['ASG Score'] = round(east['Score']*east['Advanced Score'],2)
east.drop(['Score', 'Advanced Score'], axis=1, inplace=True)
east.sort_values(by=['ASG Score'], ascending=False, inplace=True)
east = east.rename({'FGP': 'FG%', 'TPP': '3P%', 'TRB': 'REB'}, axis='columns')
east = east.dropna()

# %%
westpg = west[west['Pos'].str.contains('PG')]
westsg = west[west['Pos'].str.contains('SG')]
westsf = west[west['Pos'].str.contains('SF')]
westpf = west[west['Pos'].str.contains('PF')]
westc = west[west['Pos'].str.contains('C')]

# %%
eastpg = east[east['Pos'].str.contains('PG')]
eastsg = east[east['Pos'].str.contains('SG')]
eastsf = east[east['Pos'].str.contains('SF')]
eastpf = east[east['Pos'].str.contains('PF')]
eastc = east[east['Pos'].str.contains('C')]

# %%
westbc = pd.concat([westpg, westsg], axis=0)
westbc.sort_values(by=['ASG Score'], ascending=False, inplace=True)
westbc.head(15)
# Out:
#                       Player Pos Age   Tm     G    FG%    3P%  REB   AST  \
# 489               Chris Paul  PG  36  PHO  51.0  0.489  0.340  4.5  10.5
# 137            Stephen Curry  PG  33  GSW  48.0  0.421  0.381  5.4   6.3
# 450          Dejounte Murray  PG  25  SAS  47.0  0.454  0.316  8.4   9.2
# 440                Ja Morant  PG  22  MEM  41.0  0.486  0.342  5.9   6.9
# 152              Luka Dončić  PG  22  DAL  38.0  0.446  0.309  8.9   9.1
# 430         Donovan Mitchell  SG  25  UTA  41.0  0.455  0.348  3.9   5.2
# 61              Devin Booker  SG  25  PHO  44.0  0.447  0.373  5.3   4.3
# 236        Tyrese Haliburton  SG  21  SAC  50.0  0.459  0.416  3.9   7.2
# 121              Mike Conley  PG  34  UTA  47.0  0.455  0.431  3.0   5.2
# 87             Jalen Brunson  PG  25  DAL  52.0  0.502  0.336  3.8   5.5
# 213  Shai Gilgeous-Alexander  PG  23  OKC  43.0  0.424  0.278  4.7   5.5
# 169          Anthony Edwards  SG  20  MIN  46.0  0.442  0.360  5.0   3.6
# 378           Damian Lillard  PG  31  POR  29.0  0.402  0.324  4.1   7.3
# 653            Derrick White  SG  27  SAS  48.0  0.425  0.312  3.5   5.6
# 548         D'Angelo Russell  PG  25  MIN  38.0  0.410  0.352  3.6   6.9
#
#       PTS   PER  Win Shares  Conf  ASG Score
# 489  14.9  21.2         7.8  West      25.99
# 137  25.9  21.8         6.6  West      22.81
# 450  19.6  21.7         4.8  West      18.66
# 440  26.3  24.5         4.7  West      17.64
# 152  26.2  23.3         3.7  West      14.10
# 430  25.5  22.3         4.4  West       9.84
# 61   25.5  19.9         4.1  West       9.00
# 236  14.3  17.5         4.1  West       8.41
# 121  14.3  18.6         4.9  West       6.97
# 87   15.9  17.6         5.0  West       6.68
# 213  22.7  19.4         3.4  West       4.68
# 169  22.3  17.3         3.0  West       4.34
# 378  24.0  19.2         2.3  West       3.98
# 653  14.4  16.2         3.4  West       3.20
# 548  18.8  16.9         2.7  West       2.71

# %%
westfc = pd.concat([westsf, westpf, westc], axis=0)
westfc.sort_values(by=['ASG Score'], ascending=False, inplace=True)
westfc.head(15)
# Out:
#                  Player Pos Age   Tm     G    FG%    3P%   REB  AST   PTS  \
# 328        Nikola Jokić   C  26  DEN  46.0  0.574  0.385  13.7  7.8  25.9
# 307        LeBron James  SF  37  LAL  36.0  0.522  0.352   7.7  6.3  29.1
# 615  Karl-Anthony Towns   C  26  MIN  45.0  0.515  0.402   9.6  3.9  24.3
# 620   Jonas Valančiūnas   C  29  NOP  46.0  0.527  0.400  11.8  2.5  18.2
# 138       Anthony Davis   C  28  LAL  32.0  0.524  0.175   9.9  2.8  23.6
# 509  Kristaps Porziņģis  PF  26  DAL  34.0  0.451  0.283   7.7  2.0  19.2
# 466        Jusuf Nurkić   C  27  POR  50.0  0.534  0.245  10.8  2.7  14.6
# 671      Christian Wood   C  26  HOU  49.0  0.485  0.371  10.3  2.1  17.6
# 29         Desmond Bane  SF  23  MEM  50.0  0.465  0.418   4.4  2.4  18.0
# 32      Harrison Barnes  PF  29  SAC  49.0  0.456  0.407   6.0  2.4  16.6
# 657      Andrew Wiggins  SF  26  GSW  48.0  0.486  0.418   4.3  2.1  18.2
# 295      Brandon Ingram  SF  24  NOP  38.0  0.442  0.341   5.9  5.4  22.6
# 57     Bojan Bogdanović  PF  32  UTA  51.0  0.460  0.383   4.3  1.8  17.9
# 301   Jaren Jackson Jr.  PF  22  MEM  53.0  0.421  0.320   5.9  1.1  16.6
# 219        Aaron Gordon  PF  26  DEN  47.0  0.519  0.325   5.6  2.5  14.5
#
#       PER  Win Shares  Conf  ASG Score
# 328  33.2         9.7  West     174.16
# 307  27.2         5.7  West      40.93
# 615  23.8         6.3  West      38.97
# 620  21.2         4.4  West      22.67
# 138  23.8         3.8  West      10.53
# 509  22.1         3.5  West       8.42
# 466  20.3         3.7  West       7.74
# 671  18.5         3.1  West       7.41
# 29   17.2         4.3  West       6.52
# 32   16.0         3.8  West       6.40
# 657  16.8         4.5  West       5.19
# 295  18.4         2.4  West       4.52
# 57   15.9         3.9  West       3.88
# 301  17.3         3.6  West       3.62
# 219  15.4         3.3  West       3.32

# %%
eastbc = pd.concat([eastpg, eastsg], axis=0)
eastbc.sort_values(by=['ASG Score'], ascending=False, inplace=True)
eastbc.head(15)
# Out:
#               Player Pos Age   Tm     G    FG%    3P%  REB   AST   PTS   PER  \
# 677       Trae Young  PG  23  ATL  47.0  0.457  0.378  4.0   9.3  27.9  25.1
# 240     James Harden  PG  32  BRK  44.0  0.414  0.332  8.0  10.2  22.5  21.0
# 626    Fred VanVleet  PG  27  TOR  46.0  0.416  0.393  4.7   7.2  21.6  19.1
# 26       LaMelo Ball  PG  20  CHO  46.0  0.424  0.361  7.2   7.6  19.8  20.2
# 272     Jrue Holiday  PG  31  MIL  40.0  0.495  0.392  4.7   6.5  18.0  19.6
# 204   Darius Garland  PG  22  CLE  44.0  0.467  0.369  3.3   8.2  19.8  18.1
# 404     Tyrese Maxey  PG  21  PHI  45.0  0.472  0.399  3.5   4.8  16.9  16.1
# 72   Malcolm Brogdon  PG  29  IND  28.0  0.448  0.307  5.1   5.9  18.5  18.4
# 546     Terry Rozier  SG  27  CHO  44.0  0.431  0.369  4.1   4.0  18.4  16.8
# 136       Seth Curry  SG  31  PHI  43.0  0.496  0.406  3.3   4.1  15.4  14.4
# 616   Gary Trent Jr.  SG  23  TOR  42.0  0.430  0.399  2.7   2.0  18.1  15.4
# 42      Bradley Beal  SG  28  WAS  40.0  0.451  0.300  4.7   6.6  23.2  18.1
# 375     Caris LeVert  SG  27  IND  39.0  0.447  0.323  3.8   4.4  18.7  17.0
# 261      Tyler Herro  SG  22  MIA  44.0  0.426  0.371  4.8   4.0  20.1  14.7
# 296     Kyrie Irving  PG  29  BRK  11.0  0.464  0.371  4.7   4.8  22.8  18.1
#
#      Win Shares  Conf  ASG Score
# 677         5.4  East      23.02
# 240         4.7  East      19.43
# 626         5.6  East      14.22
# 26          3.8  East      11.48
# 272         4.0  East       9.08
# 204         4.0  East       7.11
# 404         4.1  East       5.72
# 72          2.4  East       4.01
# 546         3.0  East       3.92
# 136         3.2  East       3.24
# 616         3.5  East       2.85
# 42          1.9  East       2.51
# 375         2.0  East       1.67
# 261         1.7  East       1.48
# 296         0.7  East       1.41

# %%
eastbc = pd.concat([eastsf, eastpf, eastc], axis=0)
eastbc.sort_values(by=['ASG Score'], ascending=False, inplace=True)
eastbc.head(15)
# Out:
#                     Player Pos Age   Tm     G    FG%    3P%   REB  AST   PTS  \
# 174            Joel Embiid   C  27  PHI  40.0  0.493  0.360  10.9  4.4  29.0
# 13   Giannis Antetokounmpo  PF  27  MIL  43.0  0.536  0.277  11.3  6.0  28.9
# 167           Kevin Durant  PF  33  BRK  36.0  0.520  0.372   7.4  5.8  29.3
# 549       Domantas Sabonis   C  25  IND  46.0  0.581  0.324  12.1  5.0  19.1
# 95            Jimmy Butler  SF  32  MIA  34.0  0.483  0.215   6.3  6.3  21.7
# 145          DeMar DeRozan  PF  32  CHI  48.0  0.501  0.337   5.1  5.1  26.6
# 118           John Collins  PF  24  ATL  47.0  0.540  0.397   7.9  1.9  16.9
# 592           Jayson Tatum  SF  23  BOS  50.0  0.430  0.329   8.5  4.1  25.9
# 563          Pascal Siakam  PF  27  TOR  38.0  0.477  0.350   8.6  5.1  21.4
# 629         Nikola Vučević   C  31  CHI  45.0  0.464  0.335  11.7  3.6  17.5
# 369            Zach LaVine  SF  26  CHI  44.0  0.486  0.397   4.8  4.3  24.7
# 385             Kevin Love  PF  33  CLE  45.0  0.434  0.396   7.5  2.1  14.5
# 70           Miles Bridges  PF  23  CHO  51.0  0.487  0.315   7.2  3.5  19.8
# 246          Tobias Harris  PF  29  PHI  43.0  0.478  0.344   7.3  3.8  18.8
# 508           Bobby Portis   C  26  MIL  44.0  0.476  0.399   9.2  1.2  14.9
#
#       PER  Win Shares  Conf  ASG Score
# 174  31.4         7.1  East      77.64
# 13   31.1         8.0  East      66.64
# 167  26.1         5.6  East      44.95
# 549  23.1         6.5  East      37.09
# 95   25.9         6.4  East      24.41
# 145  23.5         6.2  East      23.89
# 118  19.9         5.1  East      16.34
# 592  20.1         4.9  East      14.72
# 563  19.7         4.1  East      12.72
# 629  19.0         3.5  East      11.54
# 369  20.7         4.0  East      11.43
# 385  22.2         4.4  East      10.65
# 70   17.7         4.5  East       9.73
# 246  17.7         3.7  East       8.92
# 508  17.7         3.5  East       7.42
