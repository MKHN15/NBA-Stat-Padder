# %% [markdown]
# # DPOY Predictions #

# %%
# -*- coding: utf-8 -*-#
"""
Created by MinhKhang Nguyen
July 27 2021 7:37 PM - August 6 2021 2:08 AM
"""
# Out:
# '\nCreated by MinhKhang Nguyen\nJuly 27 2021 7:37 PM - August 6 2021 2:08 AM\n'

# %%
import pandas as pd 
import random as rnd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Importing Data ####

# %% [markdown]
# ###### Importing Normal Stats ######

# %%
html_url = "https://www.basketball-reference.com/leagues/NBA_2021_per_game.html"
nba_tables = pd.read_html(html_url)
len(nba_tables)
nba = nba_tables[0]
nba.head(30)
# Out:
#     Rk                    Player  Pos  Age   Tm   G  GS    MP    FG   FGA  \
# 0    1          Precious Achiuwa   PF   21  MIA  61   4  12.1   2.0   3.7
# 1    2              Jaylen Adams   PG   24  MIL   7   0   2.6   0.1   1.1
# 2    3              Steven Adams    C   27  NOP  58  58  27.7   3.3   5.3
# 3    4               Bam Adebayo    C   23  MIA  64  64  33.5   7.1  12.5
# 4    5         LaMarcus Aldridge    C   35  TOT  26  23  25.9   5.4  11.4
# 5    5         LaMarcus Aldridge    C   35  SAS  21  18  25.9   5.5  11.8
# 6    5         LaMarcus Aldridge    C   35  BRK   5   5  26.0   5.0   9.6
# 7    6         Ty-Shon Alexander   SG   22  PHO  15   0   3.1   0.2   0.8
# 8    7  Nickeil Alexander-Walker   SG   22  NOP  46  13  21.9   4.2  10.0
# 9    8             Grayson Allen   SG   25  MEM  50  38  25.2   3.5   8.3
# 10   9             Jarrett Allen    C   22  TOT  63  45  29.6   4.7   7.7
# 11   9             Jarrett Allen    C   22  BRK  12   5  26.7   3.7   5.4
# 12   9             Jarrett Allen    C   22  CLE  51  40  30.3   5.0   8.2
# 13  10           Al-Farouq Aminu   PF   30  TOT  23  14  18.9   1.7   4.3
# 14  10           Al-Farouq Aminu   PF   30  ORL  17  14  21.6   2.1   5.2
# 15  10           Al-Farouq Aminu   PF   30  CHI   6   0  11.2   0.3   1.7
# 16  11             Kyle Anderson   PF   27  MEM  69  69  27.3   4.5   9.5
# 17  12     Giannis Antetokounmpo   PF   26  MIL  61  61  33.0  10.3  18.0
# 18  13      Kostas Antetokounmpo   PF   23  LAL  15   0   3.7   0.2   0.7
# 19  14    Thanasis Antetokounmpo   SF   28  MIL  57   3   9.7   1.2   2.4
# 20  15           Carmelo Anthony   PF   36  POR  69   3  24.5   4.7  11.3
# 21  16              Cole Anthony   PG   20  ORL  47  34  27.1   4.7  11.7
# 22  17                OG Anunoby   SF   23  TOR  43  43  33.3   5.8  12.1
# 23  18          Ryan Arcidiacono   PG   26  CHI  44   0  10.2   1.1   2.7
# 24  19              Trevor Ariza   SF   35  MIA  30  27  28.0   3.3   8.0
# 25  20             D.J. Augustin   PG   33  TOT  57  12  19.8   2.4   6.0
# 26  20             D.J. Augustin   PG   33  MIL  37   6  19.3   1.9   5.2
# 27  20             D.J. Augustin   PG   33  HOU  20   6  20.8   3.2   7.6
# 28  Rk                    Player  Pos  Age   Tm   G  GS    MP    FG   FGA
# 29  21               Deni Avdija   SF   20  WAS  54  32  23.3   2.4   5.8
#
#     ...    FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0   ...   .509  1.2  2.2   3.4  0.5  0.3  0.5  0.7  1.5   5.0
# 1   ...    NaN  0.0  0.4   0.4  0.3  0.0  0.0  0.0  0.1   0.3
# 2   ...   .444  3.7  5.2   8.9  1.9  0.9  0.7  1.3  1.9   7.6
# 3   ...   .799  2.2  6.7   9.0  5.4  1.2  1.0  2.6  2.3  18.7
# 4   ...   .872  0.7  3.8   4.5  1.9  0.4  1.1  1.0  1.8  13.5
# 5   ...   .838  0.8  3.7   4.5  1.7  0.4  0.9  1.0  1.7  13.7
# 6   ...  1.000  0.4  4.4   4.8  2.6  0.6  2.2  1.4  2.2  12.8
# 7   ...   .500  0.1  0.5   0.7  0.4  0.0  0.1  0.2  0.1   0.6
# 8   ...   .727  0.3  2.8   3.1  2.2  1.0  0.5  1.5  1.9  11.0
# 9   ...   .868  0.4  2.8   3.2  2.2  0.9  0.2  1.0  1.4  10.6
# 10  ...   .703  3.1  6.9  10.0  1.7  0.5  1.4  1.6  1.5  12.8
# 11  ...   .754  3.2  7.3  10.4  1.7  0.6  1.6  1.8  1.8  11.2
# 12  ...   .690  3.1  6.8   9.9  1.7  0.5  1.4  1.5  1.5  13.2
# 13  ...   .818  1.0  3.8   4.8  1.3  0.8  0.4  1.2  1.3   4.4
# 14  ...   .824  1.2  4.2   5.4  1.7  1.0  0.5  1.5  1.3   5.5
# 15  ...   .800  0.3  2.8   3.2  0.3  0.3  0.0  0.5  1.2   1.5
# 16  ...   .783  0.8  5.0   5.7  3.6  1.2  0.8  1.2  1.7  12.4
# 17  ...   .685  1.6  9.4  11.0  5.9  1.2  1.2  3.4  2.8  28.1
# 18  ...   .462  0.3  1.0   1.3  0.1  0.1  0.3  0.7  0.5   0.8
# 19  ...   .510  0.9  1.2   2.2  0.8  0.4  0.2  0.8  1.3   2.9
# 20  ...   .890  0.5  2.6   3.1  1.5  0.7  0.6  0.9  2.1  13.4
# 21  ...   .832  0.8  3.9   4.7  4.1  0.6  0.4  2.3  2.1  12.9
# 22  ...   .784  1.3  4.3   5.5  2.2  1.5  0.7  1.7  2.7  15.9
# 23  ...   .650  0.1  1.4   1.5  1.3  0.2  0.0  0.2  1.1   3.1
# 24  ...   .773  0.9  3.9   4.8  1.8  1.0  0.6  0.7  1.8   9.4
# 25  ...   .904  0.4  1.3   1.6  3.3  0.5  0.0  1.1  1.0   7.7
# 26  ...   .900  0.3  1.1   1.4  3.0  0.5  0.0  0.9  0.9   6.1
# 27  ...   .907  0.5  1.8   2.2  3.9  0.4  0.0  1.6  1.2  10.6
# 28  ...    FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 29  ...   .644  0.4  4.4   4.9  1.2  0.6  0.3  0.6  2.6   6.3
#
# [30 rows x 30 columns]

# %%
nba.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %% [markdown]
# ###### Importing Advanced Stats ######

# %%
html_url = "https://www.basketball-reference.com/leagues/NBA_2021_advanced.html"
advanced_tables = pd.read_html(html_url)
len(advanced_tables)
advanced = advanced_tables[0]
advanced.head(30)
# Out:
#     Rk                    Player  Pos  Age   Tm   G    MP   PER   TS%  3PAr  \
# 0    1          Precious Achiuwa   PF   21  MIA  61   737  14.2  .550  .004
# 1    2              Jaylen Adams   PG   24  MIL   7    18  -6.5  .125  .250
# 2    3              Steven Adams    C   27  NOP  58  1605  15.1  .596  .010
# 3    4               Bam Adebayo    C   23  MIA  64  2143  22.7  .626  .010
# 4    5         LaMarcus Aldridge    C   35  TOT  26   674  15.7  .556  .270
# 5    5         LaMarcus Aldridge    C   35  SAS  21   544  15.1  .545  .302
# 6    5         LaMarcus Aldridge    C   35  BRK   5   130  18.2  .611  .104
# 7    6         Ty-Shon Alexander   SG   22  PHO  15    47   4.2  .349  .750
# 8    7  Nickeil Alexander-Walker   SG   22  NOP  46  1007  12.5  .522  .478
# 9    8             Grayson Allen   SG   25  MEM  50  1259  12.8  .586  .662
# 10   9             Jarrett Allen    C   22  TOT  63  1864  20.1  .661  .039
# 11   9             Jarrett Allen    C   22  BRK  12   320  21.5  .730  .000
# 12   9             Jarrett Allen    C   22  CLE  51  1544  19.8  .649  .046
# 13  10           Al-Farouq Aminu   PF   30  TOT  23   434   8.9  .469  .374
# 14  10           Al-Farouq Aminu   PF   30  ORL  17   367   9.9  .482  .348
# 15  10           Al-Farouq Aminu   PF   30  CHI   6    67   3.0  .369  .600
# 16  11             Kyle Anderson   PF   27  MEM  69  1887  17.2  .578  .397
# 17  12     Giannis Antetokounmpo   PF   26  MIL  61  2013  29.2  .633  .201
# 18  13      Kostas Antetokounmpo   PF   23  LAL  15    56   0.0  .382  .000
# 19  14    Thanasis Antetokounmpo   SF   28  MIL  57   551  10.3  .523  .212
# 20  15           Carmelo Anthony   PF   36  POR  69  1690  14.6  .547  .418
# 21  16              Cole Anthony   PG   20  ORL  47  1273  12.1  .496  .312
# 22  17                OG Anunoby   SF   23  TOR  43  1433  15.4  .605  .503
# 23  18          Ryan Arcidiacono   PG   26  CHI  44   450   9.8  .541  .573
# 24  19              Trevor Ariza   SF   35  MIA  30   841  11.9  .542  .593
# 25  20             D.J. Augustin   PG   33  TOT  57  1129  12.1  .570  .633
# 26  20             D.J. Augustin   PG   33  MIL  37   713  10.2  .542  .672
# 27  20             D.J. Augustin   PG   33  HOU  20   416  15.5  .604  .583
# 28  Rk                    Player  Pos  Age   Tm   G    MP   PER   TS%  3PAr
# 29  21               Deni Avdija   SF   20  WAS  54  1257   7.6  .515  .538
#
#     ... Unnamed: 19   OWS  DWS    WS   WS/48 Unnamed: 24   OBPM  DBPM    BPM  \
# 0   ...         NaN   0.3  1.0   1.3    .085         NaN   -3.5  -0.9   -4.5
# 1   ...         NaN  -0.1  0.0  -0.1  -0.252         NaN  -14.9  -5.0  -19.8
# 2   ...         NaN   2.3  1.7   4.0    .119         NaN   -0.3  -0.5   -0.8
# 3   ...         NaN   5.6  3.2   8.8    .197         NaN    2.9   1.9    4.7
# 4   ...         NaN   0.5  0.6   1.1    .080         NaN   -0.2  -0.4   -0.6
# 5   ...         NaN   0.3  0.5   0.8    .067         NaN   -0.2  -1.0   -1.2
# 6   ...         NaN   0.2  0.2   0.4    .135         NaN   -0.2   1.9    1.7
# 7   ...         NaN  -0.1  0.0   0.0  -0.048         NaN   -5.3  -1.6   -6.8
# 8   ...         NaN  -0.3  1.0   0.7    .035         NaN   -1.4  -0.2   -1.6
# 9   ...         NaN   1.5  1.2   2.7    .101         NaN   -0.4  -0.1   -0.5
# 10  ...         NaN   4.3  2.1   6.4    .166         NaN    1.4  -0.4    0.9
# 11  ...         NaN   1.0  0.5   1.4    .216         NaN    1.3   0.6    1.9
# 12  ...         NaN   3.4  1.6   5.0    .155         NaN    1.4  -0.7    0.7
# 13  ...         NaN  -0.4  0.5   0.1    .010         NaN   -5.0   1.0   -4.0
# 14  ...         NaN  -0.3  0.4   0.1    .014         NaN   -4.4   1.2   -3.3
# 15  ...         NaN  -0.1  0.1   0.0  -0.013         NaN   -7.9   0.0   -7.9
# 16  ...         NaN   2.9  2.7   5.6    .143         NaN    1.4   1.7    3.1
# 17  ...         NaN   6.9  3.3  10.2    .244         NaN    6.2   2.6    8.8
# 18  ...         NaN  -0.3  0.1  -0.2  -0.174         NaN  -13.2   0.2  -13.0
# 19  ...         NaN   0.0  0.6   0.7    .057         NaN   -3.6  -0.3   -3.9
# 20  ...         NaN   1.7  0.8   2.6    .073         NaN    0.1  -1.6   -1.5
# 21  ...         NaN  -0.9  0.9   0.0  -0.001         NaN   -2.0  -1.3   -3.3
# 22  ...         NaN   1.5  1.6   3.1    .104         NaN    0.6   0.3    1.0
# 23  ...         NaN   0.5  0.4   0.9    .093         NaN   -2.7   0.2   -2.5
# 24  ...         NaN   0.5  1.0   1.6    .091         NaN   -1.5   0.2   -1.3
# 25  ...         NaN   1.5  0.5   2.1    .088         NaN   -0.5  -1.6   -2.1
# 26  ...         NaN   0.8  0.4   1.2    .080         NaN   -1.0  -1.1   -2.1
# 27  ...         NaN   0.8  0.1   0.9    .103         NaN    0.3  -2.5   -2.2
# 28  ...         NaN   OWS  DWS    WS   WS/48         NaN   OBPM  DBPM    BPM
# 29  ...         NaN   0.0  1.2   1.2    .046         NaN   -3.6  -0.3   -3.9
#
#     VORP
# 0   -0.5
# 1   -0.1
# 2    0.5
# 3    3.6
# 4    0.2
# 5    0.1
# 6    0.1
# 7   -0.1
# 8    0.1
# 9    0.5
# 10   1.4
# 11   0.3
# 12   1.1
# 13  -0.2
# 14  -0.1
# 15  -0.1
# 16   2.4
# 17   5.5
# 18  -0.2
# 19  -0.3
# 20   0.2
# 21  -0.4
# 22   1.1
# 23  -0.1
# 24   0.2
# 25   0.0
# 26   0.0
# 27   0.0
# 28  VORP
# 29  -0.6
#
# [30 rows x 29 columns]

# %%
advanced.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr',
#        'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
#        'Unnamed: 19', 'OWS', 'DWS', 'WS', 'WS/48', 'Unnamed: 24', 'OBPM',
#        'DBPM', 'BPM', 'VORP'],
#       dtype='object')

# %% [markdown]
# ###### Importing Per 100 Possession Stats ######

# %%
html_url = "https://www.basketball-reference.com/leagues/NBA_2021_per_poss.html"
poss_tables = pd.read_html(html_url)
len(poss_tables)
poss = poss_tables[0]
poss.head(30)
# Out:
#     Rk                    Player  Pos  Age   Tm   G  GS    MP    FG   FGA  \
# 0    1          Precious Achiuwa   PF   21  MIA  61   4   737   8.4  15.4
# 1    2              Jaylen Adams   PG   24  MIL   7   0    18   2.6  20.9
# 2    3              Steven Adams    C   27  NOP  58  58  1605   5.6   9.2
# 3    4               Bam Adebayo    C   23  MIA  64  64  2143  10.6  18.5
# 4    5         LaMarcus Aldridge    C   35  TOT  26  23   674  10.1  21.3
# 5    5         LaMarcus Aldridge    C   35  SAS  21  18   544  10.3  22.1
# 6    5         LaMarcus Aldridge    C   35  BRK   5   5   130   9.3  17.8
# 7    6         Ty-Shon Alexander   SG   22  PHO  15   0    47   3.2  12.6
# 8    7  Nickeil Alexander-Walker   SG   22  NOP  46  13  1007   9.1  21.8
# 9    8             Grayson Allen   SG   25  MEM  50  38  1259   6.6  15.7
# 10   9             Jarrett Allen    C   22  TOT  63  45  1864   7.9  12.7
# 11   9             Jarrett Allen    C   22  BRK  12   5   320   6.6   9.8
# 12   9             Jarrett Allen    C   22  CLE  51  40  1544   8.1  13.3
# 13  10           Al-Farouq Aminu   PF   30  TOT  23  14   434   4.3  11.1
# 14  10           Al-Farouq Aminu   PF   30  ORL  17  14   367   4.8  11.8
# 15  10           Al-Farouq Aminu   PF   30  CHI   6   0    67   1.4   7.2
# 16  11             Kyle Anderson   PF   27  MEM  69  69  1887   7.8  16.7
# 17  12     Giannis Antetokounmpo   PF   26  MIL  61  61  2013  14.6  25.7
# 18  13      Kostas Antetokounmpo   PF   23  LAL  15   0    56   2.6   8.7
# 19  14    Thanasis Antetokounmpo   SF   28  MIL  57   3   551   5.7  11.7
# 20  15           Carmelo Anthony   PF   36  POR  69   3  1690   9.4  22.4
# 21  16              Cole Anthony   PG   20  ORL  47  34  1273   8.4  21.1
# 22  17                OG Anunoby   SF   23  TOR  43  43  1433   8.4  17.5
# 23  18          Ryan Arcidiacono   PG   26  CHI  44   0   450   5.3  12.6
# 24  19              Trevor Ariza   SF   35  MIA  30  27   841   5.8  14.2
# 25  20             D.J. Augustin   PG   33  TOT  57  12  1129   5.6  14.3
# 26  20             D.J. Augustin   PG   33  MIL  37   6   713   4.7  12.6
# 27  20             D.J. Augustin   PG   33  HOU  20   6   416   7.3  17.2
# 28  Rk                    Player  Pos  Age   Tm   G  GS    MP    FG   FGA
# 29  21               Deni Avdija   SF   20  WAS  54  32  1257   4.8  11.4
#
#     ...   TRB  AST  STL  BLK  TOV   PF   PTS Unnamed: 29  ORtg  DRtg
# 0   ...  14.0  2.0  1.3  1.9  2.9  6.1  20.5         NaN   107   109
# 1   ...   7.8  5.2  0.0  0.0  0.0  2.6   5.2         NaN    45   116
# 2   ...  15.4  3.3  1.6  1.1  2.3  3.4  13.1         NaN   122   112
# 3   ...  13.3  8.0  1.7  1.5  3.9  3.4  27.7         NaN   122   108
# 4   ...   8.5  3.5  0.8  2.1  1.9  3.4  25.3         NaN   109   113
# 5   ...   8.4  3.2  0.7  1.6  1.8  3.2  25.7         NaN   108   114
# 6   ...   8.9  4.8  1.1  4.1  2.6  4.1  23.7         NaN   117   110
# 7   ...  10.5  6.3  0.0  1.1  3.2  2.1   9.5         NaN    84   114
# 8   ...   6.9  4.9  2.2  1.0  3.3  4.2  24.2         NaN   101   112
# 9   ...   6.1  4.1  1.7  0.3  1.8  2.7  20.2         NaN   116   113
# 10  ...  16.6  2.8  0.8  2.4  2.6  2.5  21.2         NaN   127   112
# 11  ...  18.8  3.0  1.1  2.9  3.3  3.2  20.2         NaN   135   109
# 12  ...  16.2  2.7  0.8  2.3  2.5  2.4  21.5         NaN   125   112
# 13  ...  12.3  3.5  2.1  1.0  3.1  3.2  11.4         NaN    91   111
# 14  ...  12.1  3.8  2.3  1.2  3.3  2.9  12.3         NaN    93   111
# 15  ...  13.7  1.4  1.4  0.0  2.2  5.1   6.5         NaN    77   111
# 16  ...  10.0  6.3  2.1  1.4  2.2  3.0  21.6         NaN   118   109
# 17  ...  15.7  8.3  1.7  1.7  4.8  3.9  40.1         NaN   122   107
# 18  ...  16.5  0.9  1.7  3.5  9.6  6.9  10.4         NaN    56   100
# 19  ...  10.6  3.9  1.9  0.9  3.7  6.3  14.1         NaN   104   112
# 20  ...   6.2  3.0  1.3  1.1  1.8  4.2  26.7         NaN   112   117
# 21  ...   8.4  7.3  1.1  0.7  4.1  3.7  23.1         NaN    98   116
# 22  ...   8.0  3.2  2.2  1.1  2.5  3.9  23.0         NaN   113   112
# 23  ...   7.2  6.0  1.0  0.0  1.1  5.1  14.7         NaN   118   114
# 24  ...   8.5  3.2  1.8  1.1  1.2  3.2  16.7         NaN   111   111
# 25  ...   3.9  7.8  1.2  0.0  2.7  2.3  18.3         NaN   117   117
# 26  ...   3.3  7.2  1.3  0.1  2.2  2.2  15.0         NaN   115   116
# 27  ...   5.0  8.9  0.9  0.0  3.5  2.6  24.0         NaN   118   119
# 28  ...   TRB  AST  STL  BLK  TOV   PF   PTS         NaN  ORtg  DRtg
# 29  ...   9.6  2.3  1.2  0.6  1.2  5.1  12.5         NaN   103   113
#
# [30 rows x 32 columns]

# %%
poss.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Unnamed: 29',
#        'ORtg', 'DRtg'],
#       dtype='object')

# %% [markdown]
# #### Cleaning DataFrame ####

# %% [markdown]
# ###### Cleaning Normal Stats ######

# %%
#renames columns to strings only#
nba.rename(
    columns={
        'FG%': 'FGP',
        '3P': 'TP',
        '3PA': 'TPA',
        '3P%': 'TPP',
        '2P': 'TWOP',
        '2PA': 'TWOPA',
        '2P%': 'TWOPP',
        'eFG%': 'eFGP',
        'FT%': 'FTP'
    }, inplace=True)

#removing duplicate players (stats of players that played on different teams)#
nba.drop_duplicates(subset=['Player'], keep=False, inplace=True)
#Dropping "Rk" Column#
nba.drop('Rk', axis=1, inplace=True)

#replacing NaN with 0#
nba.fillna(0, inplace=True)

nba[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]] = nba[["G", "GS","MP","FG","FGA","FGP","TP","TPA","TPP","TWOP","TWOPA","TWOPP","eFGP","FT","FTA","FTP","ORB","DRB","TRB","AST","STL","BLK","TOV","PF","PTS"]].apply(pd.to_numeric)
nba
# Out:
#                 Player Pos Age   Tm   G  GS    MP   FG   FGA    FGP  ...  \
# 0     Precious Achiuwa  PF  21  MIA  61   4  12.1  2.0   3.7  0.544  ...
# 1         Jaylen Adams  PG  24  MIL   7   0   2.6  0.1   1.1  0.125  ...
# 2         Steven Adams   C  27  NOP  58  58  27.7  3.3   5.3  0.614  ...
# 3          Bam Adebayo   C  23  MIA  64  64  33.5  7.1  12.5  0.570  ...
# 7    Ty-Shon Alexander  SG  22  PHO  15   0   3.1  0.2   0.8  0.250  ...
# ..                 ...  ..  ..  ...  ..  ..   ...  ...   ...    ...  ...
# 723     Robert Woodard  SF  21  SAC  13   0   3.5  0.6   1.5  0.400  ...
# 727     Thaddeus Young  PF  32  CHI  68  23  24.3  5.4   9.7  0.559  ...
# 728         Trae Young  PG  22  ATL  63  63  33.7  7.7  17.7  0.438  ...
# 729        Cody Zeller   C  28  CHO  48  21  20.9  3.8   6.8  0.559  ...
# 730        Ivica Zubac   C  23  LAC  72  33  22.3  3.6   5.5  0.652  ...
#
#        FTP  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0    0.509  1.2  2.2  3.4  0.5  0.3  0.5  0.7  1.5   5.0
# 1    0.000  0.0  0.4  0.4  0.3  0.0  0.0  0.0  0.1   0.3
# 2    0.444  3.7  5.2  8.9  1.9  0.9  0.7  1.3  1.9   7.6
# 3    0.799  2.2  6.7  9.0  5.4  1.2  1.0  2.6  2.3  18.7
# 7    0.500  0.1  0.5  0.7  0.4  0.0  0.1  0.2  0.1   0.6
# ..     ...  ...  ...  ...  ...  ...  ...  ...  ...   ...
# 723  0.375  0.3  0.9  1.2  0.2  0.0  0.2  0.1  0.3   1.5
# 727  0.628  2.5  3.8  6.2  4.3  1.1  0.6  2.0  2.2  12.1
# 728  0.886  0.6  3.3  3.9  9.4  0.8  0.2  4.1  1.8  25.3
# 729  0.714  2.5  4.4  6.8  1.8  0.6  0.4  1.1  2.5   9.4
# 730  0.789  2.6  4.6  7.2  1.3  0.3  0.9  1.1  2.6   9.0
#
# [461 rows x 29 columns]

# %% [markdown]
# ###### Cleaning Advanced Stats ######

# %%
#removing duplicate players (stats of players that played on different teams)#
advanced.drop_duplicates(subset=['Player'], keep=False, inplace=True)
#Dropping "Rk" Column#
advanced.drop('Rk', axis=1, inplace=True)

#replacing NaN with 0#
advanced.fillna(0, inplace=True)

advanced[['Age', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr','ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%','Unnamed: 19', 'OWS', 'DWS', 'WS', 'WS/48', 'Unnamed: 24', 'OBPM','DBPM', 'BPM', 'VORP']] = advanced[['Age', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr','ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%','Unnamed: 19', 'OWS', 'DWS', 'WS', 'WS/48', 'Unnamed: 24', 'OBPM','DBPM', 'BPM', 'VORP']].apply(pd.to_numeric)
advanced.drop(['Player','Pos','Age','Tm','G','MP','TS%','3PAr','FTr','ORB%','AST%','TOV%','USG%','OWS','WS/48','OBPM','VORP','Unnamed: 19','Unnamed: 24','PER','WS','BPM'], axis=1, inplace=True)

shorter_advanced = advanced
shorter_advanced
# Out:
#      DRB%  TRB%  STL%  BLK%  DWS  DBPM
# 0    20.6  16.1   1.3   4.0  1.0  -0.9
# 1    16.9   8.8   0.0   0.0  0.0  -5.0
# 2    20.4  17.4   1.6   2.2  1.7  -0.5
# 3    22.6  15.3   1.7   3.2  3.2   1.9
# 7    19.0  12.1   0.0   1.9  0.0  -1.6
# ..    ...   ...   ...   ...  ...   ...
# 723  30.0  19.7   0.0   5.6  0.0  -2.7
# 727  16.9  14.2   2.2   2.1  2.2   1.2
# 728  10.5   6.3   1.2   0.5  1.3  -1.7
# 729  22.9  17.7   1.3   1.7  1.1  -0.1
# 730  22.4  18.1   0.7   3.4  2.1   0.0
#
# [461 rows x 6 columns]

# %% [markdown]
# ###### Cleaning Per 100 Possession Stats ######

# %%
#removing duplicate players (stats of players that played on different teams)#
poss.drop_duplicates(subset=['Player'], keep=False, inplace=True)
#Dropping "Rk" Column#
poss.drop('Rk', axis=1, inplace=True)

#replacing NaN with 0#
poss.fillna(0, inplace=True)

poss.drop(['Player','Pos','Age','Tm','G','GS','MP','FG','FGA','FG%','3P','3PA','3P%','2P','2PA','2P%','FT','FTA','FT%','ORB','DRB','TRB','AST','STL','BLK','TOV','PF','PTS','ORtg','Unnamed: 29'], axis=1, inplace=True)
poss[['DRtg']] = poss[['DRtg']].apply(pd.to_numeric)
shorter_poss = poss
shorter_poss
# Out:
#      DRtg
# 0     109
# 1     116
# 2     112
# 3     108
# 7     114
# ..    ...
# 723   114
# 727   110
# 728   116
# 729   112
# 730   110
#
# [461 rows x 1 columns]

# %%
nba = nba.loc[~nba.index.duplicated(keep='first')]
shorter_advanced = shorter_advanced.loc[~shorter_advanced.index.duplicated(keep='first')]
shorter_poss = shorter_poss.loc[~shorter_poss.index.duplicated(keep='first')]
full = pd.concat([nba, shorter_advanced, shorter_poss], axis=1)
full
# Out:
#                 Player Pos Age   Tm   G  GS    MP   FG   FGA    FGP  ...  TOV  \
# 0     Precious Achiuwa  PF  21  MIA  61   4  12.1  2.0   3.7  0.544  ...  0.7
# 1         Jaylen Adams  PG  24  MIL   7   0   2.6  0.1   1.1  0.125  ...  0.0
# 2         Steven Adams   C  27  NOP  58  58  27.7  3.3   5.3  0.614  ...  1.3
# 3          Bam Adebayo   C  23  MIA  64  64  33.5  7.1  12.5  0.570  ...  2.6
# 7    Ty-Shon Alexander  SG  22  PHO  15   0   3.1  0.2   0.8  0.250  ...  0.2
# ..                 ...  ..  ..  ...  ..  ..   ...  ...   ...    ...  ...  ...
# 723     Robert Woodard  SF  21  SAC  13   0   3.5  0.6   1.5  0.400  ...  0.1
# 727     Thaddeus Young  PF  32  CHI  68  23  24.3  5.4   9.7  0.559  ...  2.0
# 728         Trae Young  PG  22  ATL  63  63  33.7  7.7  17.7  0.438  ...  4.1
# 729        Cody Zeller   C  28  CHO  48  21  20.9  3.8   6.8  0.559  ...  1.1
# 730        Ivica Zubac   C  23  LAC  72  33  22.3  3.6   5.5  0.652  ...  1.1
#
#       PF   PTS  DRB%  TRB%  STL%  BLK%  DWS  DBPM  DRtg
# 0    1.5   5.0  20.6  16.1   1.3   4.0  1.0  -0.9   109
# 1    0.1   0.3  16.9   8.8   0.0   0.0  0.0  -5.0   116
# 2    1.9   7.6  20.4  17.4   1.6   2.2  1.7  -0.5   112
# 3    2.3  18.7  22.6  15.3   1.7   3.2  3.2   1.9   108
# 7    0.1   0.6  19.0  12.1   0.0   1.9  0.0  -1.6   114
# ..   ...   ...   ...   ...   ...   ...  ...   ...   ...
# 723  0.3   1.5  30.0  19.7   0.0   5.6  0.0  -2.7   114
# 727  2.2  12.1  16.9  14.2   2.2   2.1  2.2   1.2   110
# 728  1.8  25.3  10.5   6.3   1.2   0.5  1.3  -1.7   116
# 729  2.5   9.4  22.9  17.7   1.3   1.7  1.1  -0.1   112
# 730  2.6   9.0  22.4  18.1   0.7   3.4  2.1   0.0   110
#
# [461 rows x 36 columns]

# %% [markdown]
# #### Filtering DataFrame ####

# %% [markdown]
# ###### Filtering Normal Stats ######

# %%
full.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FGP', 'TP',
#        'TPA', 'TPP', 'TWOP', 'TWOPA', 'TWOPP', 'eFGP', 'FT', 'FTA', 'FTP',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'DRB%',
#        'TRB%', 'STL%', 'BLK%', 'DWS', 'DBPM', 'DRtg'],
#       dtype='object')

# %%
full.drop(['GS','MP','FG','FGA','FGP','TP','TPA','TPP','TWOP','TWOPA','TWOPP','eFGP','FT','FTA','FTP','ORB','AST','TOV','PTS'], axis=1, inplace=True)

# %%
full.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'DRB', 'TRB', 'STL', 'BLK', 'PF',
#        'DRB%', 'TRB%', 'STL%', 'BLK%', 'DWS', 'DBPM', 'DRtg'],
#       dtype='object')

# %%
full[['Age','G','DRB','TRB','STL','BLK','PF','DRB%','TRB%','STL%','BLK%','DWS','DBPM','DRtg']] = full[['Age','G','DRB','TRB','STL','BLK','PF','DRB%','TRB%','STL%','BLK%','DWS','DBPM','DRtg']].apply(pd.to_numeric)

# %%
full.drop(full[full['G'] <= 30].index, inplace = True)
full.drop(full[full['STL'] <= 0.1].index, inplace = True)
full.drop(full[full['BLK'] <= 0.1].index, inplace = True)
full.drop(full[full['DRB'] <= 1].index, inplace = True)
full.drop(full[full['DBPM'] <= 0.01].index, inplace = True)

# %%
full
# Out:
#                     Player Pos  Age   Tm   G  DRB   TRB  STL  BLK   PF  DRB%  \
# 3              Bam Adebayo   C   23  MIA  64  6.7   9.0  1.2  1.0  2.3  22.6
# 16           Kyle Anderson  PF   27  MEM  69  5.0   5.7  1.2  0.8  1.7  19.5
# 17   Giannis Antetokounmpo  PF   26  MIL  61  9.4  11.0  1.2  1.2  2.8  28.9
# 22              OG Anunoby  SF   23  TOR  43  4.3   5.5  1.5  0.7  2.7  14.6
# 34             LaMelo Ball  PG   19  CHO  51  4.7   5.9  1.6  0.4  2.7  17.9
# ..                     ...  ..  ...  ...  ..  ...   ...  ...  ...  ...   ...
# 700      Russell Westbrook  PG   32  WAS  65  9.9  11.5  1.4  0.4  2.9  28.6
# 708       Kenrich Williams  PF   26  OKC  66  2.9   4.1  0.8  0.3  2.2  14.0
# 713        Robert Williams   C   23  BOS  52  4.3   6.9  0.8  1.8  2.0  25.6
# 718          Dylan Windler  SF   24  CLE  31  2.8   3.5  0.6  0.4  1.2  19.5
# 727         Thaddeus Young  PF   32  CHI  68  3.8   6.2  1.1  0.6  2.2  16.9
#
#      TRB%  STL%  BLK%  DWS  DBPM  DRtg
# 3    15.3   1.7   3.2  3.2   1.9   108
# 16   11.1   2.1   2.7  2.7   1.7   109
# 17   17.5   1.7   3.2  3.3   2.6   107
# 22    9.1   2.2   2.2  1.6   0.3   112
# 34   11.1   2.7   1.2  1.9   0.6   110
# ..    ...   ...   ...  ...   ...   ...
# 700  16.8   1.7   0.8  3.2   0.8   110
# 708  10.0   1.8   1.1  1.2   0.7   114
# 713  20.2   2.1   8.6  1.9   3.1   104
# 718  11.7   1.8   2.1  0.5   0.1   113
# 727  14.2   2.2   2.1  2.2   1.2   110
#
# [104 rows x 17 columns]

# %% [markdown]
# #### Processing the Data ####

# %%
for index, row in full.iterrows():
    full.loc[index, "DPOY Score"] = ((((((((2*row['STL'])+row['BLK'])**2)+((row['DRB']/row['DRB%'])*row['TRB']))*(row['STL%']+row['BLK%']*(row['DRB%']/row['TRB%'])))*row['DWS'])/(row['DRtg']-100)))*(row['DWS']**2)/100
    
#((row['DRB%']*(row['DRB']/row['TRB']))+(row['STL']*(1+(row['STL%'])))+(row['BLK']*(1+(row['BLK%'])))-(row['PF']**4))*(((row['DWS']**3)*(row['DBPM']*2))*row['DRtg']))/((row['DBPM']-100)/row['DWS'])*-1#

# %%
full.sort_values(by=['DPOY Score'], ascending=False, inplace=True)
#full.drop(['G','GS','MP','FG','FGA','FGP','TP','TPA','TPP','TWOP','TWOPA','TWOPP','eFGP','FT','FTA','FTP','ORB','DRB','TRB','AST','STL','BLK','TOV','PF','PTS','Avg. Box +/-'], axis=1, inplace=True)#
dpoy['DPOY Score'] = round(dpoy['DPOY Score'],2)
dpoy = dpoy.head(15)
dpoy = dpoy.copy()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DPOY Score'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-428-9a7ee27c7f52> in <module>
#       1 full.sort_values(by=['DPOY Score'], ascending=False, inplace=True)
#       2 #full.drop(['G','GS','MP','FG','FGA','FGP','TP','TPA','TPP','TWOP','TWOPA','TWOPP','eFGP','FT','FTA','FTP','ORB','DRB','TRB','AST','STL','BLK','TOV','PF','PTS','Avg. Box +/-'], axis=1, inplace=True)#
# ----> 3 dpoy['DPOY Score'] = round(dpoy['DPOY Score'],2)
#       4 dpoy = dpoy.head(15)
#       5 dpoy = dpoy.copy()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'DPOY Score'

# %%
dpoy
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Rudy Gobert, C, 28, UTA, 10.1, 13.5, 0.6, 2.7, 5.2, 2.5, 101, 297.24), (Nerlens Noel, C, 26, NYK, 4.2, 6.4, 1.1, 2.2, 3.6, 3.5, 101, 131.09), (Matisse Thybulle, SG, 23, PHI, 1.4, 1.9, 1.6, 1.1, 2.7, 4.3, 103, 13.73), (Joel Embiid, C, 26, PHI, 8.4, 10.6, 1.0, 1.4, 3.2, 1.0, 104, 9.07), (Draymond Green, PF, 30, GSW, 6.3, 7.1, 1.7, 0.8, 3.4, 3.3, 106, 8.39), (Anthony Davis, PF, 27, LAL, 6.2, 7.9, 1.3, 1.6, 2.4, 1.6, 104, 6.13), (Giannis Antetokounmpo, PF, 26, MIL, 9.4, 11.0, 1.2, 1.2, 3.3, 2.6, 107, 5.93), (Myles Turner, C, 24, IND, 5.2, 6.5, 0.9, 3.4, 2.2, 1.7, 108, 5.85), (Ben Simmons, PG, 24, PHI, 5.6, 7.2, 1.6, 0.6, 3.3, 1.9, 106, 4.98), (Bam Adebayo, C, 23, MIA, 6.7, 9.0, 1.2, 1.0, 3.2, 1.9, 108, 3.75), (Danny Green, SF, 33, PHI, 3.0, 3.8, 1.3, 0.8, 3.1, 1.2, 108, 2.96), (Nikola Jokić, C, 25, DEN, 8.0, 10.8, 1.3, 0.7, 3.4, 2.5, 109, 2.91), (Robert Williams, C, 23, BOS, 4.3, 6.9, 0.8, 1.8, 1.9, 3.1, 104, 2.84), (Dwight Howard, C, 35, PHI, 5.7, 8.4, 0.4, 0.9, 2.6, 0.3, 102, 2.77), (Jimmy Butler, SF, 31, MIA, 5.1, 6.9, 2.1, 0.3, 2.7, 2.5, 108, 2.58)]

# %% [markdown]
# #### Visualization ####

# %% [markdown]
# ###### Defensive Win Shares vs DPOY Score Plot ######

# %%
x = dpoy['DWS']
y = dpoy['DPOY Score']

plt.scatter(x, y)
plt.title('Defensive Win Shares vs. DPOY Score', fontdict={'fontsize':16, 'fontweight':'bold'})
plt.xlabel('DWS of Player', fontdict={'fontweight':'bold'})
plt.ylabel('DPOY Score', fontdict={'fontweight':'bold'})
plt.show()

# %%
#plt.savefig('DWS vs. DPOY Score.png')

# %%
x = dpoy['DRtg']
y = dpoy['DPOY Score']

plt.scatter(x, y)
plt.title('Defensive Rating vs. DPOY Score', fontdict={'fontsize':16, 'fontweight':'bold'})
plt.xlabel('DRtg of Player', fontdict={'fontweight':'bold'})
plt.ylabel('DPOY Score', fontdict={'fontweight':'bold'})
plt.show()

# %%
#plt.savefig('DRtg vs. DPOY Score.png')

# %%
dpoy.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'DRB', 'TRB', 'STL', 'BLK', 'PF',
#        'DRB%', 'TRB%', 'STL%', 'BLK%', 'DWS', 'DBPM', 'DRtg', 'DPOY Score'],
#       dtype='object')

# %%
dpoy.drop(['G', 'PF','DRB%','TRB%','STL%','BLK%'], axis=1, inplace=True)
dpoy.set_index(['Player', 'Pos', 'Age', 'Tm', 'DRB','TRB','STL','BLK','DWS','DBPM','DRtg','DPOY Score'], inplace=True)
dpoy
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-405-3a11e63b53d7> in <module>
#       1 dpoy.drop(['G', 'PF','DRB%','TRB%','STL%','BLK%'], axis=1, inplace=True)
# ----> 2 dpoy.set_index(['Player', 'Pos', 'Age', 'Tm', 'DRB','TRB','STL','BLK','DWS','DBPM','DRtg','DPOY Score'], inplace=True)
#       3 dpoy
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4725
#    4726         if missing:
# -> 4727             raise KeyError(f"None of {missing} are in the columns")
#    4728
#    4729         if inplace:
#
# KeyError: "None of ['Player', 'Pos', 'Age', 'Tm', 'DRB', 'TRB', 'STL', 'BLK', 'DWS', 'DBPM', 'DRtg', 'DPOY Score'] are in the columns"

# %% [markdown]
# #### Exporting ####

# %% [markdown]
# ###### MVP Table to CSV ######

# %%
#mvp.to_csv("MVP Predictions.csv")#
